# %%
import numpy as np
import tensorflow as tf
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from matplotlib import pyplot as plt
import seaborn as sns
import scipy as sp
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input,Conv2D,MaxPooling2D,UpSampling2D, Dense
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras import regularizers
from tensorflow.keras import layers
from scipy.misc import derivative
import scipy.integrate as intg
import scipy as sp

# %% [markdown]
# ### In this notebook, we use a compressed version of JLA compilation
# #### First, we need to read the data. In this case, we use the covariance matrix of systematic errors

# %%
syscov = np.loadtxt('/home/isidro/Documents/gitHub/misRepos/neuralCosmoReconstruction/data/cov_jla_binned_distances_31nodes_v1.txt',skiprows=1).reshape((31,31))
# syscov = np.loadtxt('data/jla_v0_covmatrix.dat',skiprows=1).reshape((740,740))

# %% [markdown]
# ### Visualization of the covariance matrix:

# %%
sns.heatmap(pd.DataFrame(syscov), annot=False, fmt='g', xticklabels=False, yticklabels=False, 
            cmap = 'inferno')
plt.savefig("original_cov_binned_JLA.png", dpi=200)

# %% [markdown]
# ### Generate a data set with covariance matrix from the original plus gaussian noise

# %%
numMatrix = 1000
covset = np.zeros((numMatrix, 31, 31))
covset_noise = np.zeros((numMatrix, 31, 31))

for i in range(numMatrix): 
    print("\r Generating {} matrix".format(i+1), end=" ")
    err = np.random.normal(size=syscov.shape) 
    covset[i] = syscov + 0.001 * err
    covset_noise[i] = syscov + 0.05 * err
# Out:
#  Generating 905 matrix
#  Generating 1000 matrix

# %%
sns.heatmap(pd.DataFrame(covset[1]), 
        fmt='g', xticklabels=False, yticklabels=False, 
        cmap = 'inferno', cbar=True,
        robust=False)

# %%
split = 0.8
ntrain = int(split * numMatrix)
indx = [ntrain]

# Split data in training set and test sets
covset_train, covset_test = np.split(covset, indx, axis=0)
covset_noise_train, covset_noise_test = np.split(covset_noise, indx, axis=0)

# Reshape arrays
covset_train = covset_train.reshape((len(covset_train), np.prod(covset_train.shape[1:])))
covset_test = covset_test.reshape((len(covset_test), np.prod(covset_test.shape[1:])))
covset_noise_train = covset_noise_train.reshape((len(covset_noise_train), np.prod(covset_noise_train.shape[1:])))
covset_noise_test = covset_noise_test.reshape((len(covset_noise_test), np.prod(covset_noise_test.shape[1:])))

# %%
original_dim = 31 * 31
intermediate_dim = 200
latent_dim = 31

inputs = tf.keras.Input(shape=(original_dim,))
h = layers.Dense(intermediate_dim, activation='tanh')(inputs)
z_mean = layers.Dense(latent_dim)(h)
z_log_sigma = layers.Dense(latent_dim)(h)


def sampling(args):
    z_mean, z_log_sigma = args
    epsilon = tf.keras.backend.random_normal(shape=(tf.keras.backend.shape(z_mean)[0], latent_dim),
                              mean=0., stddev=0.1)
    return z_mean + tf.keras.backend.exp(z_log_sigma) * epsilon

z = layers.Lambda(sampling)([z_mean, z_log_sigma])

# Create encoder
encoder = tf.keras.Model(inputs, [z_mean, z_log_sigma, z], name='encoder')

# Create decoder
latent_inputs = tf.keras.Input(shape=(latent_dim,), name='z_sampling')
x = layers.Dense(intermediate_dim, activation='tanh')(latent_inputs)
outputs = layers.Dense(original_dim, activation='linear')(x)

decoder = tf.keras.Model(latent_inputs, outputs, name='decoder')

# instantiate VAE model
outputs = decoder(encoder(inputs)[2])
vae = tf.keras.Model(inputs, outputs, name='vae_mlp')

# %%
reconstruction_loss = tf.keras.losses.binary_crossentropy(inputs, outputs)
reconstruction_loss *= original_dim
kl_loss = 1 + z_log_sigma - tf.keras.backend.square(z_mean) - tf.keras.backend.exp(z_log_sigma)
kl_loss = tf.keras.backend.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = tf.keras.backend.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')
vae.summary()
# Out:
# Model: "vae_mlp"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 961)]        0
# __________________________________________________________________________________________________
# encoder (Functional)            [(None, 31), (None,  204862      input_1[0][0]
# __________________________________________________________________________________________________
# decoder (Functional)            (None, 961)          199561      encoder[0][2]
# __________________________________________________________________________________________________
# tf_op_layer_Minimum (TensorFlow [(None, 961)]        0           decoder[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum (TensorFlow [(None, 961)]        0           tf_op_layer_Minimum[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_1 (TensorFlowOp [(None, 961)]        0           tf_op_layer_Maximum[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2 (TensorFlowOp [(None, 961)]        0           tf_op_layer_Maximum[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_1 (TensorFlow [(None, 961)]        0           tf_op_layer_Sub_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 200)          192400      input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Log (TensorFlowOpLa [(None, 961)]        0           tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub (TensorFlowOpLa [(None, 961)]        0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Log_1 (TensorFlowOp [(None, 961)]        0           tf_op_layer_AddV2_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 31)           6231        dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 31)           6231        dense[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [(None, 961)]        0           input_1[0][0]
#                                                                  tf_op_layer_Log[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1 (TensorFlowOp [(None, 961)]        0           tf_op_layer_Sub[0][0]
#                                                                  tf_op_layer_Log_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_3 (TensorFlow [(None, 31)]         0           dense_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Square (TensorFlowO [(None, 31)]         0           dense_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_2 (TensorFlow [(None, 961)]        0           tf_op_layer_Mul[0][0]
#                                                                  tf_op_layer_Mul_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_2 (TensorFlowOp [(None, 31)]         0           tf_op_layer_AddV2_3[0][0]
#                                                                  tf_op_layer_Square[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp (TensorFlowOpLa [(None, 31)]         0           dense_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Neg (TensorFlowOpLa [(None, 961)]        0           tf_op_layer_AddV2_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_3 (TensorFlowOp [(None, 31)]         0           tf_op_layer_Sub_2[0][0]
#                                                                  tf_op_layer_Exp[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean (TensorFlowOpL [(None,)]            0           tf_op_layer_Neg[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum (TensorFlowOpLa [(None,)]            0           tf_op_layer_Sub_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_2 (TensorFlowOp [(None,)]            0           tf_op_layer_Mean[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_3 (TensorFlowOp [(None,)]            0           tf_op_layer_Sum[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_4 (TensorFlow [(None,)]            0           tf_op_layer_Mul_2[0][0]
#                                                                  tf_op_layer_Mul_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_1 (TensorFlowO [()]                 0           tf_op_layer_AddV2_4[0][0]
# __________________________________________________________________________________________________
# add_loss (AddLoss)              ()                   0           tf_op_layer_Mean_1[0][0]
# ==================================================================================================
# Total params: 404,423
# Trainable params: 404,423
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
autoencoder_train = vae.fit(covset_noise_train, covset_train,
                epochs=100,
#                 batch_size=,
#                 shuffle=True,
                validation_data=(covset_noise_test, covset_test))
# Out:
# Epoch 1/100
# 25/25 [==============================] - 0s 16ms/step - loss: 17.1114 - val_loss: 14.9803
# Epoch 2/100
# 25/25 [==============================] - 0s 6ms/step - loss: 12.5407 - val_loss: 14.2447
# Epoch 3/100
# 25/25 [==============================] - 0s 5ms/step - loss: 11.3780 - val_loss: 11.7447
# Epoch 4/100
# 25/25 [==============================] - 0s 5ms/step - loss: 10.2778 - val_loss: 12.3058
# Epoch 5/100
# 25/25 [==============================] - 0s 6ms/step - loss: 9.7683 - val_loss: 11.7097
# Epoch 6/100
# 25/25 [==============================] - 0s 7ms/step - loss: 9.8177 - val_loss: 12.8717
# Epoch 7/100
# 25/25 [==============================] - 0s 6ms/step - loss: 8.7610 - val_loss: 11.6410
# Epoch 8/100
# 25/25 [==============================] - 0s 7ms/step - loss: 8.8599 - val_loss: 11.9049
# Epoch 9/100
# 25/25 [==============================] - 0s 5ms/step - loss: 9.9429 - val_loss: 14.0613
# Epoch 10/100
# 25/25 [==============================] - 0s 5ms/step - loss: 10.5091 - val_loss: 12.7969
# Epoch 11/100
# 25/25 [==============================] - 0s 5ms/step - loss: 10.0967 - val_loss: 13.9946
# Epoch 12/100
# 25/25 [==============================] - 0s 6ms/step - loss: 9.6874 - val_loss: 14.2140
# Epoch 13/100
# 25/25 [==============================] - 0s 6ms/step - loss: 9.3347 - val_loss: 13.9457
# Epoch 14/100
# 25/25 [==============================] - 0s 6ms/step - loss: 8.9865 - val_loss: 12.7411
# Epoch 15/100
# 25/25 [==============================] - 0s 5ms/step - loss: 8.4897 - val_loss: 12.4649
# Epoch 16/100
# 25/25 [==============================] - 0s 5ms/step - loss: 8.2450 - val_loss: 13.2878
# Epoch 17/100
# 25/25 [==============================] - 0s 5ms/step - loss: 9.0327 - val_loss: 14.2005
# Epoch 18/100
# 25/25 [==============================] - 0s 5ms/step - loss: 9.7407 - val_loss: 13.8090
# Epoch 19/100
# 25/25 [==============================] - 0s 5ms/step - loss: 10.2838 - val_loss: 13.6332
# Epoch 20/100
# 25/25 [==============================] - 0s 6ms/step - loss: 10.2072 - val_loss: 13.2019
# Epoch 21/100
# 25/25 [==============================] - 0s 5ms/step - loss: 10.4561 - val_loss: 13.4752
# Epoch 22/100
# 25/25 [==============================] - 0s 6ms/step - loss: 11.1123 - val_loss: 13.0744
# Epoch 23/100
# 25/25 [==============================] - 0s 7ms/step - loss: 10.2402 - val_loss: 13.0343
# Epoch 24/100
# 25/25 [==============================] - 0s 6ms/step - loss: 10.6416 - val_loss: 12.6672
# Epoch 25/100
# 25/25 [==============================] - 0s 6ms/step - loss: 10.2313 - val_loss: 13.3175
# Epoch 26/100
# 25/25 [==============================] - 0s 5ms/step - loss: 10.0501 - val_loss: 12.1746
# Epoch 27/100
# 25/25 [==============================] - 0s 5ms/step - loss: 10.0504 - val_loss: 12.9050
# Epoch 28/100
# 25/25 [==============================] - 0s 5ms/step - loss: 11.1530 - val_loss: 13.0710
# Epoch 29/100
# 25/25 [==============================] - 0s 6ms/step - loss: 11.6394 - val_loss: 13.6001
# Epoch 30/100
# 25/25 [==============================] - 0s 6ms/step - loss: 11.3878 - val_loss: 12.8550
# Epoch 31/100
# 25/25 [==============================] - 0s 7ms/step - loss: 11.9367 - val_loss: 14.6970
# Epoch 32/100
# 25/25 [==============================] - 0s 6ms/step - loss: 14.1586 - val_loss: 14.5702
# Epoch 33/100
# 25/25 [==============================] - 0s 6ms/step - loss: 15.8134 - val_loss: 15.1740
# Epoch 34/100
# 25/25 [==============================] - 0s 7ms/step - loss: 16.0671 - val_loss: 14.9992
# Epoch 35/100
# 25/25 [==============================] - 0s 7ms/step - loss: 17.1532 - val_loss: 15.4227
# Epoch 36/100
# 25/25 [==============================] - 0s 8ms/step - loss: 16.8676 - val_loss: 14.3382
# Epoch 37/100
# 25/25 [==============================] - 0s 6ms/step - loss: 15.4403 - val_loss: 14.2814
# Epoch 38/100
# 25/25 [==============================] - 0s 6ms/step - loss: 15.6756 - val_loss: 14.7656
# Epoch 39/100
# 25/25 [==============================] - 0s 6ms/step - loss: 16.8936 - val_loss: 15.0560
# Epoch 40/100
# 25/25 [==============================] - 0s 5ms/step - loss: 16.3488 - val_loss: 14.8345
# Epoch 41/100
# 25/25 [==============================] - 0s 5ms/step - loss: 16.4121 - val_loss: 14.6580
# Epoch 42/100
# 25/25 [==============================] - 0s 5ms/step - loss: 15.9743 - val_loss: 14.8903
# Epoch 43/100
# 25/25 [==============================] - 0s 6ms/step - loss: 16.6200 - val_loss: 16.9342
# Epoch 44/100
# 25/25 [==============================] - 0s 6ms/step - loss: 18.8752 - val_loss: 16.3873
# Epoch 45/100
# 25/25 [==============================] - 0s 5ms/step - loss: 18.1869 - val_loss: 16.0886
# Epoch 46/100
# 25/25 [==============================] - 0s 6ms/step - loss: 18.0455 - val_loss: 16.3817
# Epoch 47/100
# 25/25 [==============================] - 0s 6ms/step - loss: 17.4233 - val_loss: 14.9886
# Epoch 48/100
# 25/25 [==============================] - 0s 5ms/step - loss: 16.8226 - val_loss: 14.6028
# Epoch 49/100
# 25/25 [==============================] - 0s 5ms/step - loss: 16.5014 - val_loss: 15.0417
# Epoch 50/100
# 25/25 [==============================] - 0s 4ms/step - loss: 15.9260 - val_loss: 13.9371
# Epoch 51/100
# 25/25 [==============================] - 0s 5ms/step - loss: 14.8450 - val_loss: 13.9079
# Epoch 52/100
# 25/25 [==============================] - 0s 5ms/step - loss: 15.0332 - val_loss: 13.8313
# Epoch 53/100
# 25/25 [==============================] - 0s 5ms/step - loss: 16.9085 - val_loss: 15.6409
# Epoch 54/100
# 25/25 [==============================] - 0s 4ms/step - loss: 19.0472 - val_loss: 16.1881
# Epoch 55/100
# 25/25 [==============================] - 0s 4ms/step - loss: 19.5161 - val_loss: 14.9330
# Epoch 56/100
# 25/25 [==============================] - 0s 5ms/step - loss: 19.5840 - val_loss: 15.2396
# Epoch 57/100
# 25/25 [==============================] - 0s 4ms/step - loss: 19.3812 - val_loss: 14.7697
# Epoch 58/100
# 25/25 [==============================] - 0s 4ms/step - loss: 18.3270 - val_loss: 14.0860
# Epoch 59/100
# 25/25 [==============================] - 0s 5ms/step - loss: 17.8031 - val_loss: 14.7501
# Epoch 60/100
# 25/25 [==============================] - 0s 5ms/step - loss: 18.3324 - val_loss: 14.2357
# Epoch 61/100
# 25/25 [==============================] - 0s 5ms/step - loss: 17.0653 - val_loss: 13.1837
# Epoch 62/100
# 25/25 [==============================] - 0s 5ms/step - loss: 15.7488 - val_loss: 12.6777
# Epoch 63/100
# 25/25 [==============================] - 0s 6ms/step - loss: 14.9443 - val_loss: 12.7796
# Epoch 64/100
# 25/25 [==============================] - 0s 5ms/step - loss: 15.7669 - val_loss: 11.7576
# Epoch 65/100
# 25/25 [==============================] - 0s 4ms/step - loss: 14.8198 - val_loss: 13.5166
# Epoch 66/100
# 25/25 [==============================] - 0s 5ms/step - loss: 16.6299 - val_loss: 13.3471
# Epoch 67/100
# 25/25 [==============================] - 0s 4ms/step - loss: 17.0496 - val_loss: 14.3311
# Epoch 68/100
# 25/25 [==============================] - 0s 5ms/step - loss: 18.0332 - val_loss: 13.8352
# Epoch 69/100
# 25/25 [==============================] - 0s 4ms/step - loss: 16.9835 - val_loss: 13.2665
# Epoch 70/100
# 25/25 [==============================] - 0s 5ms/step - loss: 15.5616 - val_loss: 13.0153
# Epoch 71/100
# 25/25 [==============================] - 0s 5ms/step - loss: 15.2463 - val_loss: 12.0245
# Epoch 72/100
# 25/25 [==============================] - 0s 5ms/step - loss: 14.3007 - val_loss: 12.4136
# Epoch 73/100
# 25/25 [==============================] - 0s 4ms/step - loss: 14.8348 - val_loss: 13.4124
# Epoch 74/100
# 25/25 [==============================] - 0s 4ms/step - loss: 16.5811 - val_loss: 13.0502
# Epoch 75/100
# 25/25 [==============================] - 0s 4ms/step - loss: 16.6231 - val_loss: 13.1797
# Epoch 76/100
# 25/25 [==============================] - 0s 5ms/step - loss: 16.8789 - val_loss: 13.2278
# Epoch 77/100
# 25/25 [==============================] - 0s 5ms/step - loss: 16.3119 - val_loss: 13.4209
# Epoch 78/100
# 25/25 [==============================] - 0s 6ms/step - loss: 16.2106 - val_loss: 12.9814
# Epoch 79/100
# 25/25 [==============================] - 0s 5ms/step - loss: 18.2082 - val_loss: 20.3307
# Epoch 80/100
# 25/25 [==============================] - 0s 5ms/step - loss: 27.6370 - val_loss: 22.7052
# Epoch 81/100
# 25/25 [==============================] - 0s 4ms/step - loss: 25.7179 - val_loss: 20.8272
# Epoch 82/100
# 25/25 [==============================] - 0s 6ms/step - loss: 23.0301 - val_loss: 18.3797
# Epoch 83/100
# 25/25 [==============================] - 0s 6ms/step - loss: 20.8942 - val_loss: 17.1423
# Epoch 84/100
# 25/25 [==============================] - 0s 5ms/step - loss: 19.4702 - val_loss: 16.1419
# Epoch 85/100
# 25/25 [==============================] - 0s 4ms/step - loss: 17.4705 - val_loss: 13.2100
# Epoch 86/100
# 25/25 [==============================] - 0s 4ms/step - loss: 21.5035 - val_loss: 15.8481
# Epoch 87/100
# 25/25 [==============================] - 0s 4ms/step - loss: 20.8234 - val_loss: 14.4625
# Epoch 88/100
# 25/25 [==============================] - 0s 4ms/step - loss: 18.4311 - val_loss: 13.5364
# Epoch 89/100
# 25/25 [==============================] - 0s 4ms/step - loss: 19.3775 - val_loss: 13.7974
# Epoch 90/100
# 25/25 [==============================] - 0s 4ms/step - loss: 18.2968 - val_loss: 12.6105
# Epoch 91/100
# 25/25 [==============================] - 0s 4ms/step - loss: 16.7260 - val_loss: 12.1194
# Epoch 92/100
# 25/25 [==============================] - 0s 5ms/step - loss: 16.8106 - val_loss: 12.5146
# Epoch 93/100
# 25/25 [==============================] - 0s 4ms/step - loss: 16.2099 - val_loss: 11.3579
# Epoch 94/100
# 25/25 [==============================] - 0s 6ms/step - loss: 14.5543 - val_loss: 10.9160
# Epoch 95/100
# 25/25 [==============================] - 0s 6ms/step - loss: 14.0169 - val_loss: 10.7956
# Epoch 96/100
# 25/25 [==============================] - 0s 5ms/step - loss: 15.1260 - val_loss: 11.0656
# Epoch 97/100
# 25/25 [==============================] - 0s 5ms/step - loss: 15.4566 - val_loss: 11.3698
# Epoch 98/100
# 25/25 [==============================] - 0s 4ms/step - loss: 14.7950 - val_loss: 10.8058
# Epoch 99/100
# 25/25 [==============================] - 0s 4ms/step - loss: 14.4686 - val_loss: 10.4054
# Epoch 100/100
# 25/25 [==============================] - 0s 4ms/step - loss: 13.3363 - val_loss: 10.6201

# %%
encoded_data = encoder.predict(covset_test)
decoded_data = decoder.predict(encoded_data)
print(np.shape(encoded_data))
# Out:
# (3, 200, 31)

# %%
# # This is the size of our encoded representations
# encoding_dim = 31  

# # This is our input image
# input_img = tf.keras.Input(shape=(31*31,))

# # begin encoder
# x = layers.Dense(100, activation='relu')(input_img)
# x = layers.Dropout(0.2)(x)
# x = layers.Dense(100, activation='relu')(x)
# x = layers.Dropout(0.2)(x)
# encoded = layers.Dense(encoding_dim, activation='relu')(x)
# x = layers.Dropout(0.2)(encoded)
# #begin decoder
# x = layers.Dense(100, activation='relu')(x)
# x = layers.Dropout(0.2)(x)
# x = layers.Dense(100, activation='relu')(x)
# x = layers.Dropout(0.2)(x)
# decoded = layers.Dense(31*31, activation='linear')(x)


# # This model maps an input to its reconstruction
# autoencoder = tf.keras.Model(input_img, decoded)
# autoencoder.compile(optimizer='adam', loss='mean_squared_error')
# autoencoder.summary()

# %%
# encoder = tf.keras.Model(input_img, encoded)

# # This is our encoded (31-dimensional) input
# encoded_input = tf.keras.Input(shape=(encoding_dim,))

# decoder_layer1 = autoencoder.layers[-5]
# decoder_layer2 = autoencoder.layers[-4]
# decoder_layer3 = autoencoder.layers[-3]
# decoder_layer4 = autoencoder.layers[-2]
# decoder_layer5 = autoencoder.layers[-1]

# # create the decoder model
# decoder = Model(encoded_input, 
#                 decoder_layer5(decoder_layer4(
#                     decoder_layer3(decoder_layer2(
#                         decoder_layer1(encoded_input))))))

# %%
# callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min',
#                                    min_delta=0.0,
#                                    patience=10, 
#                                    restore_best_weights=True)]

# autoencoder_train = autoencoder.fit(covset_noise_train, covset_train,
#                 epochs=100,
#                 batch_size=1,
#                 shuffle=True,
#                 validation_data=(covset_noise_test, covset_test),
#                 callbacks=callbacks, verbose=0)

# %%
plt.plot(autoencoder_train.history['loss'], color='r', )
plt.plot(autoencoder_train.history['val_loss'], color='g')
# plt.title('model loss function')
plt.ylabel('MSE')
plt.xlabel('Epochs')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig('loss_binned_JLA.png', dpi=50)

# %%
unet = np.sqrt(np.min(autoencoder_train.history['val_loss']))
print(unet**2)
# Out:
# 10.405378341674805

# %%
encoded_imgs = encoder.predict(covset_test)
decoded_imgs = decoder.predict(encoded_imgs)

# %%
sns.heatmap(pd.DataFrame(decoded_imgs[0].reshape(31,31)), 
            fmt='g', xticklabels=False, yticklabels=False, 
            cmap = 'inferno', 
            robust=False)


# this cov matrix work well within Bayesian inference
# np.savetxt("test.dat", decoded_imgs[0].reshape(31,31), delimiter= " ", header="#fake COV")

# %%
n = 10 
plt.figure(figsize=(20, 4))

for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    sns.heatmap(covset_test[i].reshape(31, 31), cbar=False, 
                fmt='g', xticklabels=False, yticklabels=False, 
                cmap = 'inferno')

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    sns.heatmap(decoded_imgs[i].reshape(31, 31), cbar=False, 
                fmt='g', xticklabels=False, yticklabels=False, 
                cmap = 'inferno')
    
# plt.savefig('predicted_covs_binned_jla.png', dpi=200)

# %% [markdown]
# ### Now we train another neural network for z and $D_L(z)$

# %%
file2 = '/home/isidro/Documents/gitHub/misRepos/neuralCosmoReconstruction/data/jla_binned_distances_31nodes_v1.txt'
data = pd.read_csv(file2, names=['z', '$D_L$'], sep = " ", skiprows=3)
sns.pairplot(data, diag_kind="kde")
# plt.savefig("DistbinnedJLA.png")

# %%
shuffle = [x for x in range(len(data.values)) if x%2 == 0]
comp = [x for x in range(len(data.values)) if x%2 ==1]
shuffle.extend(comp)
data = data.values[shuffle]
z = data[:,0]
dl = data[:,1:]

# %%
split = 0.8
ntrain = int(split * len(z))
indx = [ntrain]
# scalerz = StandardScaler()
# scalerz.fit(z.reshape(-1, 1))
# zz = scalerz.transform(z.reshape((-1,1)))
z_train, z_test = np.split(z, indx)
dl_train, dl_test = np.split(dl, indx)

# %%
callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min',
                                   min_delta=0.0,
                                   patience=20,
                                   restore_best_weights=True)]

# %%
def model(input_z):
    efirst = Dense(50, activation='relu', input_shape=(1,))(input_z)
    x = Dense(50, activation='relu')(efirst)
    x = Dense(50, activation='relu')(x)
    x = Dense(30, activation='relu')(x)
    elast = Dense(1, activation='linear')(x)
    return elast

input_z = Input(shape = (1,))
neural_model = Model(input_z, model(input_z))
neural_model.compile(loss='mean_squared_error', optimizer = "adam")
neural_model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 1)]               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                100
# _________________________________________________________________
# dense_6 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_7 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_8 (Dense)              (None, 30)                1530
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 6,761
# Trainable params: 6,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_train = neural_model.fit(z_train, dl_train, batch_size=1,
                                    epochs=500,verbose=1,
                                    validation_data=(z_test, dl_test))
#                                     callbacks=callbacks)
# Out:
# Epoch 1/500
# 24/24 [==============================] - 0s 7ms/step - loss: 1427.8427 - val_loss: 1691.6357
# Epoch 2/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1358.7620 - val_loss: 1507.9270
# Epoch 3/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1115.1776 - val_loss: 957.7380
# Epoch 4/500
# 24/24 [==============================] - 0s 2ms/step - loss: 540.2072 - val_loss: 96.5303
# Epoch 5/500
# 24/24 [==============================] - 0s 2ms/step - loss: 88.9182 - val_loss: 149.0741
# Epoch 6/500
# 24/24 [==============================] - 0s 2ms/step - loss: 84.6835 - val_loss: 59.9125
# Epoch 7/500
# 24/24 [==============================] - 0s 2ms/step - loss: 55.5565 - val_loss: 67.8536
# Epoch 8/500
# 24/24 [==============================] - 0s 2ms/step - loss: 51.4125 - val_loss: 54.8306
# Epoch 9/500
# 24/24 [==============================] - 0s 2ms/step - loss: 40.1493 - val_loss: 37.4386
# Epoch 10/500
# 24/24 [==============================] - 0s 2ms/step - loss: 32.7474 - val_loss: 36.0146
# Epoch 11/500
# 24/24 [==============================] - 0s 2ms/step - loss: 26.9683 - val_loss: 31.0785
# Epoch 12/500
# 24/24 [==============================] - 0s 2ms/step - loss: 21.9929 - val_loss: 30.3414
# Epoch 13/500
# 24/24 [==============================] - 0s 2ms/step - loss: 21.3801 - val_loss: 22.0459
# Epoch 14/500
# 24/24 [==============================] - 0s 2ms/step - loss: 15.5158 - val_loss: 17.6508
# Epoch 15/500
# 24/24 [==============================] - 0s 2ms/step - loss: 12.7218 - val_loss: 16.4321
# Epoch 16/500
# 24/24 [==============================] - 0s 2ms/step - loss: 13.0119 - val_loss: 11.4254
# Epoch 17/500
# 24/24 [==============================] - 0s 2ms/step - loss: 10.4952 - val_loss: 9.7507
# Epoch 18/500
# 24/24 [==============================] - 0s 2ms/step - loss: 6.8336 - val_loss: 7.8084
# Epoch 19/500
# 24/24 [==============================] - 0s 2ms/step - loss: 5.5986 - val_loss: 6.7065
# Epoch 20/500
# 24/24 [==============================] - 0s 2ms/step - loss: 4.9824 - val_loss: 5.1674
# Epoch 21/500
# 24/24 [==============================] - 0s 2ms/step - loss: 4.1221 - val_loss: 4.5794
# Epoch 22/500
# 24/24 [==============================] - 0s 1ms/step - loss: 3.3465 - val_loss: 3.6315
# Epoch 23/500
# 24/24 [==============================] - 0s 1ms/step - loss: 3.1300 - val_loss: 3.0773
# Epoch 24/500
# 24/24 [==============================] - 0s 1ms/step - loss: 2.7923 - val_loss: 3.1964
# Epoch 25/500
# 24/24 [==============================] - 0s 2ms/step - loss: 2.4113 - val_loss: 2.3430
# Epoch 26/500
# 24/24 [==============================] - 0s 1ms/step - loss: 2.3308 - val_loss: 2.3093
# Epoch 27/500
# 24/24 [==============================] - 0s 2ms/step - loss: 2.0956 - val_loss: 2.3077
# Epoch 28/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.9658 - val_loss: 1.8215
# Epoch 29/500
# 24/24 [==============================] - 0s 2ms/step - loss: 2.0237 - val_loss: 2.5534
# Epoch 30/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.7541 - val_loss: 1.3752
# Epoch 31/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.7874 - val_loss: 1.5636
# Epoch 32/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.7097 - val_loss: 1.4865
# Epoch 33/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.7229 - val_loss: 0.8089
# Epoch 34/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.8040 - val_loss: 1.1895
# Epoch 35/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.5633 - val_loss: 0.7670
# Epoch 36/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.7246 - val_loss: 0.8084
# Epoch 37/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.6780 - val_loss: 0.7484
# Epoch 38/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.4564 - val_loss: 0.7922
# Epoch 39/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.4571 - val_loss: 0.8583
# Epoch 40/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.4135 - val_loss: 0.8522
# Epoch 41/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.4362 - val_loss: 0.6629
# Epoch 42/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.5522 - val_loss: 0.5016
# Epoch 43/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.4828 - val_loss: 0.5738
# Epoch 44/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.3866 - val_loss: 1.1081
# Epoch 45/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.6441 - val_loss: 0.2999
# Epoch 46/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.4333 - val_loss: 0.6607
# Epoch 47/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.7889 - val_loss: 1.2471
# Epoch 48/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.5709 - val_loss: 0.5900
# Epoch 49/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.3736 - val_loss: 0.3253
# Epoch 50/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.3589 - val_loss: 0.8373
# Epoch 51/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.3612 - val_loss: 0.2807
# Epoch 52/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.4541 - val_loss: 0.2486
# Epoch 53/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.2543 - val_loss: 0.4823
# Epoch 54/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.2462 - val_loss: 0.6322
# Epoch 55/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1908 - val_loss: 0.4192
# Epoch 56/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.2488 - val_loss: 0.7553
# Epoch 57/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.2864 - val_loss: 0.4811
# Epoch 58/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.2001 - val_loss: 0.2195
# Epoch 59/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1965 - val_loss: 0.5221
# Epoch 60/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1884 - val_loss: 0.4715
# Epoch 61/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.1511 - val_loss: 0.2501
# Epoch 62/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.2238 - val_loss: 0.9482
# Epoch 63/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.3304 - val_loss: 0.3884
# Epoch 64/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1329 - val_loss: 0.4614
# Epoch 65/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1717 - val_loss: 0.3464
# Epoch 66/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.2399 - val_loss: 0.9071
# Epoch 67/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1844 - val_loss: 0.4557
# Epoch 68/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1891 - val_loss: 0.2829
# Epoch 69/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0517 - val_loss: 1.2140
# Epoch 70/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.2449 - val_loss: 0.3603
# Epoch 71/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1646 - val_loss: 0.3779
# Epoch 72/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1164 - val_loss: 0.1954
# Epoch 73/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.2057 - val_loss: 0.2375
# Epoch 74/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1840 - val_loss: 0.4659
# Epoch 75/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1690 - val_loss: 0.2727
# Epoch 76/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.1440 - val_loss: 0.2883
# Epoch 77/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1362 - val_loss: 0.2283
# Epoch 78/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.1593 - val_loss: 0.3596
# Epoch 79/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0538 - val_loss: 0.2780
# Epoch 80/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0469 - val_loss: 1.0528
# Epoch 81/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1463 - val_loss: 0.2892
# Epoch 82/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1814 - val_loss: 0.3310
# Epoch 83/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.3788 - val_loss: 0.3986
# Epoch 84/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0460 - val_loss: 0.3034
# Epoch 85/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0833 - val_loss: 0.4707
# Epoch 86/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1681 - val_loss: 0.6228
# Epoch 87/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.4715 - val_loss: 0.4486
# Epoch 88/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.3256 - val_loss: 0.3926
# Epoch 89/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.3722 - val_loss: 0.7292
# Epoch 90/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0569 - val_loss: 0.2486
# Epoch 91/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0201 - val_loss: 0.4381
# Epoch 92/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9585 - val_loss: 0.5768
# Epoch 93/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.3327 - val_loss: 0.1510
# Epoch 94/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0478 - val_loss: 0.1939
# Epoch 95/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9704 - val_loss: 0.2581
# Epoch 96/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9790 - val_loss: 0.2337
# Epoch 97/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.2683 - val_loss: 0.5730
# Epoch 98/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0278 - val_loss: 0.1935
# Epoch 99/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0414 - val_loss: 0.2526
# Epoch 100/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9729 - val_loss: 0.1658
# Epoch 101/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9782 - val_loss: 0.2163
# Epoch 102/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0166 - val_loss: 1.0020
# Epoch 103/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1574 - val_loss: 0.4659
# Epoch 104/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.3760 - val_loss: 0.1696
# Epoch 105/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9672 - val_loss: 0.4292
# Epoch 106/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.2483 - val_loss: 1.5712
# Epoch 107/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9780 - val_loss: 0.1382
# Epoch 108/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1781 - val_loss: 0.3330
# Epoch 109/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1346 - val_loss: 0.1706
# Epoch 110/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1899 - val_loss: 0.3179
# Epoch 111/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9584 - val_loss: 0.4601
# Epoch 112/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1400 - val_loss: 0.3486
# Epoch 113/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0837 - val_loss: 0.5394
# Epoch 114/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0439 - val_loss: 0.5713
# Epoch 115/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0227 - val_loss: 0.2514
# Epoch 116/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0553 - val_loss: 0.1273
# Epoch 117/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9278 - val_loss: 0.2003
# Epoch 118/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9820 - val_loss: 0.6185
# Epoch 119/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0071 - val_loss: 0.2787
# Epoch 120/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1236 - val_loss: 0.7453
# Epoch 121/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.5746 - val_loss: 0.2704
# Epoch 122/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9449 - val_loss: 0.1048
# Epoch 123/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9176 - val_loss: 0.1277
# Epoch 124/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.2094 - val_loss: 0.9593
# Epoch 125/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.3452 - val_loss: 0.4192
# Epoch 126/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8965 - val_loss: 0.2308
# Epoch 127/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0507 - val_loss: 1.0245
# Epoch 128/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1884 - val_loss: 0.7870
# Epoch 129/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9479 - val_loss: 0.3739
# Epoch 130/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0778 - val_loss: 0.2374
# Epoch 131/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1406 - val_loss: 0.1863
# Epoch 132/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9478 - val_loss: 1.1880
# Epoch 133/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9181 - val_loss: 0.1133
# Epoch 134/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0066 - val_loss: 0.5926
# Epoch 135/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0878 - val_loss: 0.1474
# Epoch 136/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8364 - val_loss: 0.4826
# Epoch 137/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9166 - val_loss: 0.2633
# Epoch 138/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1200 - val_loss: 0.1773
# Epoch 139/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0896 - val_loss: 0.2065
# Epoch 140/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9369 - val_loss: 1.0870
# Epoch 141/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.1303 - val_loss: 0.0962
# Epoch 142/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9005 - val_loss: 0.1940
# Epoch 143/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7298 - val_loss: 0.1376
# Epoch 144/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0953 - val_loss: 1.4629
# Epoch 145/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.2695 - val_loss: 4.9053
# Epoch 146/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.6690 - val_loss: 0.2465
# Epoch 147/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8685 - val_loss: 0.1948
# Epoch 148/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0059 - val_loss: 1.6361
# Epoch 149/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.4300 - val_loss: 0.1683
# Epoch 150/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8897 - val_loss: 0.3021
# Epoch 151/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8334 - val_loss: 0.1634
# Epoch 152/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8617 - val_loss: 0.1515
# Epoch 153/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8684 - val_loss: 0.1175
# Epoch 154/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.3282 - val_loss: 0.1994
# Epoch 155/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.7239 - val_loss: 0.2101
# Epoch 156/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9679 - val_loss: 0.1132
# Epoch 157/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9979 - val_loss: 0.1097
# Epoch 158/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7680 - val_loss: 0.6624
# Epoch 159/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7906 - val_loss: 0.5119
# Epoch 160/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1357 - val_loss: 0.0988
# Epoch 161/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0556 - val_loss: 0.1156
# Epoch 162/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7542 - val_loss: 0.0893
# Epoch 163/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7946 - val_loss: 0.1969
# Epoch 164/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7445 - val_loss: 0.4606
# Epoch 165/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8624 - val_loss: 0.2516
# Epoch 166/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6805 - val_loss: 0.7621
# Epoch 167/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9485 - val_loss: 0.2419
# Epoch 168/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8154 - val_loss: 0.3668
# Epoch 169/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8018 - val_loss: 0.9330
# Epoch 170/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.1271 - val_loss: 1.7912
# Epoch 171/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1004 - val_loss: 0.0513
# Epoch 172/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6334 - val_loss: 0.3243
# Epoch 173/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7559 - val_loss: 0.1390
# Epoch 174/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8077 - val_loss: 0.0508
# Epoch 175/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7382 - val_loss: 0.1149
# Epoch 176/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8467 - val_loss: 1.3482
# Epoch 177/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8844 - val_loss: 0.1168
# Epoch 178/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6553 - val_loss: 0.1164
# Epoch 179/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9111 - val_loss: 3.1606
# Epoch 180/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.2211 - val_loss: 0.1339
# Epoch 181/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6954 - val_loss: 0.2407
# Epoch 182/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6481 - val_loss: 0.1635
# Epoch 183/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7193 - val_loss: 0.4144
# Epoch 184/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0398 - val_loss: 0.3447
# Epoch 185/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8890 - val_loss: 0.4664
# Epoch 186/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8403 - val_loss: 0.2285
# Epoch 187/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6913 - val_loss: 0.0852
# Epoch 188/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6384 - val_loss: 0.4441
# Epoch 189/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8888 - val_loss: 0.1073
# Epoch 190/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6164 - val_loss: 0.1538
# Epoch 191/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8408 - val_loss: 0.4314
# Epoch 192/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7520 - val_loss: 0.0486
# Epoch 193/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6856 - val_loss: 0.0405
# Epoch 194/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6300 - val_loss: 0.0658
# Epoch 195/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6658 - val_loss: 0.1419
# Epoch 196/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9223 - val_loss: 0.1935
# Epoch 197/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7951 - val_loss: 0.3418
# Epoch 198/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.2070 - val_loss: 0.1018
# Epoch 199/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5974 - val_loss: 0.6392
# Epoch 200/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6788 - val_loss: 0.5454
# Epoch 201/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0063 - val_loss: 0.2756
# Epoch 202/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8075 - val_loss: 0.1664
# Epoch 203/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.1208 - val_loss: 0.7596
# Epoch 204/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7424 - val_loss: 0.4208
# Epoch 205/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8535 - val_loss: 0.4551
# Epoch 206/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.2057 - val_loss: 2.4020
# Epoch 207/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.2205 - val_loss: 2.7698
# Epoch 208/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.1836 - val_loss: 0.0762
# Epoch 209/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.2642 - val_loss: 0.6815
# Epoch 210/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.2280 - val_loss: 0.5179
# Epoch 211/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7999 - val_loss: 0.1893
# Epoch 212/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6196 - val_loss: 0.3432
# Epoch 213/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6645 - val_loss: 0.0500
# Epoch 214/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6101 - val_loss: 0.8616
# Epoch 215/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9687 - val_loss: 1.1262
# Epoch 216/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9473 - val_loss: 0.0413
# Epoch 217/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6695 - val_loss: 0.1412
# Epoch 218/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6079 - val_loss: 0.3606
# Epoch 219/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6321 - val_loss: 0.2203
# Epoch 220/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6030 - val_loss: 0.0334
# Epoch 221/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6300 - val_loss: 0.4737
# Epoch 222/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7546 - val_loss: 0.4098
# Epoch 223/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9088 - val_loss: 1.2081
# Epoch 224/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9542 - val_loss: 0.9557
# Epoch 225/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6526 - val_loss: 0.2623
# Epoch 226/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7929 - val_loss: 0.3056
# Epoch 227/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6007 - val_loss: 0.3900
# Epoch 228/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4886 - val_loss: 0.2024
# Epoch 229/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7672 - val_loss: 0.1238
# Epoch 230/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6222 - val_loss: 0.7913
# Epoch 231/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8645 - val_loss: 0.1499
# Epoch 232/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8780 - val_loss: 1.1027
# Epoch 233/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6051 - val_loss: 0.1245
# Epoch 234/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4531 - val_loss: 0.7111
# Epoch 235/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5444 - val_loss: 0.0658
# Epoch 236/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3993 - val_loss: 0.2635
# Epoch 237/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9334 - val_loss: 1.4651
# Epoch 238/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4783 - val_loss: 0.0576
# Epoch 239/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5027 - val_loss: 0.1077
# Epoch 240/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6630 - val_loss: 0.2894
# Epoch 241/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4641 - val_loss: 0.0494
# Epoch 242/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5876 - val_loss: 0.0916
# Epoch 243/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0206 - val_loss: 0.4125
# Epoch 244/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7962 - val_loss: 1.1433
# Epoch 245/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9914 - val_loss: 1.3026
# Epoch 246/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6925 - val_loss: 0.0556
# Epoch 247/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7268 - val_loss: 0.6321
# Epoch 248/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5158 - val_loss: 0.1206
# Epoch 249/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0595 - val_loss: 2.0724
# Epoch 250/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0763 - val_loss: 0.5746
# Epoch 251/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5278 - val_loss: 0.0872
# Epoch 252/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5808 - val_loss: 0.4805
# Epoch 253/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6180 - val_loss: 0.2252
# Epoch 254/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5273 - val_loss: 4.0071
# Epoch 255/500
# 24/24 [==============================] - 0s 1ms/step - loss: 2.0140 - val_loss: 2.0313
# Epoch 256/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.5169 - val_loss: 0.5930
# Epoch 257/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.1180 - val_loss: 2.5105
# Epoch 258/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7135 - val_loss: 0.1214
# Epoch 259/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.5963 - val_loss: 3.2259
# Epoch 260/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.9029 - val_loss: 3.7844
# Epoch 261/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.1006 - val_loss: 0.8611
# Epoch 262/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6455 - val_loss: 1.6730
# Epoch 263/500
# 24/24 [==============================] - 0s 2ms/step - loss: 1.4021 - val_loss: 5.5585
# Epoch 264/500
# 24/24 [==============================] - 0s 2ms/step - loss: 2.3184 - val_loss: 6.4690
# Epoch 265/500
# 24/24 [==============================] - 0s 2ms/step - loss: 4.3601 - val_loss: 0.5640
# Epoch 266/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.2239 - val_loss: 0.2459
# Epoch 267/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4862 - val_loss: 1.2483
# Epoch 268/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4901 - val_loss: 0.1609
# Epoch 269/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8215 - val_loss: 0.7186
# Epoch 270/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4427 - val_loss: 2.1757
# Epoch 271/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7832 - val_loss: 0.2921
# Epoch 272/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6566 - val_loss: 0.3178
# Epoch 273/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.2928 - val_loss: 2.9211
# Epoch 274/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7780 - val_loss: 0.1167
# Epoch 275/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4873 - val_loss: 0.1344
# Epoch 276/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4941 - val_loss: 0.0866
# Epoch 277/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5346 - val_loss: 0.4520
# Epoch 278/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7719 - val_loss: 0.8066
# Epoch 279/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6056 - val_loss: 0.0734
# Epoch 280/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4844 - val_loss: 0.2898
# Epoch 281/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5861 - val_loss: 1.1284
# Epoch 282/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6904 - val_loss: 0.0972
# Epoch 283/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5680 - val_loss: 0.1163
# Epoch 284/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4815 - val_loss: 0.1015
# Epoch 285/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6738 - val_loss: 0.5380
# Epoch 286/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3572 - val_loss: 0.1757
# Epoch 287/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4514 - val_loss: 0.0868
# Epoch 288/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4626 - val_loss: 0.1505
# Epoch 289/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4927 - val_loss: 0.7942
# Epoch 290/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4406 - val_loss: 0.7958
# Epoch 291/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7046 - val_loss: 0.2408
# Epoch 292/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5472 - val_loss: 0.1815
# Epoch 293/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4473 - val_loss: 0.2360
# Epoch 294/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3381 - val_loss: 0.1767
# Epoch 295/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3844 - val_loss: 0.2437
# Epoch 296/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5522 - val_loss: 0.3693
# Epoch 297/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0042 - val_loss: 1.3418
# Epoch 298/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7204 - val_loss: 0.0602
# Epoch 299/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6070 - val_loss: 0.5351
# Epoch 300/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4903 - val_loss: 0.1355
# Epoch 301/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4114 - val_loss: 0.2567
# Epoch 302/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5909 - val_loss: 0.1128
# Epoch 303/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5586 - val_loss: 0.3259
# Epoch 304/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4689 - val_loss: 0.0478
# Epoch 305/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7790 - val_loss: 0.2636
# Epoch 306/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5946 - val_loss: 0.1148
# Epoch 307/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3248 - val_loss: 0.4924
# Epoch 308/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6473 - val_loss: 0.2895
# Epoch 309/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6093 - val_loss: 0.0842
# Epoch 310/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3668 - val_loss: 0.3257
# Epoch 311/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5501 - val_loss: 0.3052
# Epoch 312/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6288 - val_loss: 1.1288
# Epoch 313/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6593 - val_loss: 0.2308
# Epoch 314/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7739 - val_loss: 0.4338
# Epoch 315/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6033 - val_loss: 0.2641
# Epoch 316/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4813 - val_loss: 0.7278
# Epoch 317/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6413 - val_loss: 0.1745
# Epoch 318/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3441 - val_loss: 0.4768
# Epoch 319/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4529 - val_loss: 0.0859
# Epoch 320/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6162 - val_loss: 0.0818
# Epoch 321/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4712 - val_loss: 0.1293
# Epoch 322/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4864 - val_loss: 0.7432
# Epoch 323/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4397 - val_loss: 1.4032
# Epoch 324/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8900 - val_loss: 0.0835
# Epoch 325/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5186 - val_loss: 0.0822
# Epoch 326/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5400 - val_loss: 2.2000
# Epoch 327/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.2977 - val_loss: 3.1925
# Epoch 328/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6870 - val_loss: 0.2387
# Epoch 329/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5027 - val_loss: 0.8266
# Epoch 330/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4326 - val_loss: 0.1809
# Epoch 331/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5056 - val_loss: 0.6165
# Epoch 332/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7233 - val_loss: 0.4306
# Epoch 333/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5724 - val_loss: 0.3475
# Epoch 334/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5561 - val_loss: 0.0524
# Epoch 335/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3373 - val_loss: 0.1648
# Epoch 336/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4683 - val_loss: 0.2417
# Epoch 337/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4826 - val_loss: 0.0556
# Epoch 338/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4719 - val_loss: 0.0497
# Epoch 339/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5883 - val_loss: 0.5960
# Epoch 340/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5804 - val_loss: 0.2588
# Epoch 341/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5438 - val_loss: 0.7781
# Epoch 342/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6570 - val_loss: 0.0892
# Epoch 343/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6149 - val_loss: 0.5239
# Epoch 344/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4108 - val_loss: 0.4442
# Epoch 345/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4178 - val_loss: 0.3179
# Epoch 346/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5382 - val_loss: 0.2934
# Epoch 347/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6514 - val_loss: 0.0769
# Epoch 348/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4490 - val_loss: 0.4550
# Epoch 349/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0561 - val_loss: 0.1205
# Epoch 350/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8425 - val_loss: 0.1070
# Epoch 351/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5009 - val_loss: 0.0915
# Epoch 352/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3544 - val_loss: 0.1007
# Epoch 353/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5274 - val_loss: 0.4735
# Epoch 354/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4845 - val_loss: 0.2774
# Epoch 355/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3159 - val_loss: 0.4830
# Epoch 356/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5319 - val_loss: 0.3008
# Epoch 357/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6053 - val_loss: 0.3606
# Epoch 358/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3677 - val_loss: 0.1501
# Epoch 359/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4673 - val_loss: 0.3232
# Epoch 360/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6780 - val_loss: 1.7000
# Epoch 361/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4862 - val_loss: 0.1714
# Epoch 362/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4474 - val_loss: 0.0919
# Epoch 363/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4844 - val_loss: 0.4681
# Epoch 364/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7624 - val_loss: 0.3269
# Epoch 365/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.1789 - val_loss: 0.7785
# Epoch 366/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5846 - val_loss: 0.2630
# Epoch 367/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3148 - val_loss: 0.7980
# Epoch 368/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6793 - val_loss: 2.3838
# Epoch 369/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8108 - val_loss: 0.8350
# Epoch 370/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3320 - val_loss: 0.2637
# Epoch 371/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3662 - val_loss: 0.4029
# Epoch 372/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5841 - val_loss: 0.5546
# Epoch 373/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3646 - val_loss: 0.3052
# Epoch 374/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2920 - val_loss: 0.3404
# Epoch 375/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4085 - val_loss: 0.1641
# Epoch 376/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2813 - val_loss: 0.3315
# Epoch 377/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7076 - val_loss: 0.5439
# Epoch 378/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8783 - val_loss: 0.5508
# Epoch 379/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3635 - val_loss: 0.2495
# Epoch 380/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4561 - val_loss: 0.3648
# Epoch 381/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4584 - val_loss: 0.8128
# Epoch 382/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5625 - val_loss: 0.3122
# Epoch 383/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4241 - val_loss: 0.3603
# Epoch 384/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4842 - val_loss: 0.9610
# Epoch 385/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9199 - val_loss: 0.3403
# Epoch 386/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4739 - val_loss: 0.2705
# Epoch 387/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4425 - val_loss: 0.1446
# Epoch 388/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3587 - val_loss: 0.0552
# Epoch 389/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4177 - val_loss: 0.1396
# Epoch 390/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3051 - val_loss: 0.0835
# Epoch 391/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5232 - val_loss: 1.0141
# Epoch 392/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3903 - val_loss: 0.0820
# Epoch 393/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3472 - val_loss: 0.0904
# Epoch 394/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2896 - val_loss: 0.0857
# Epoch 395/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3599 - val_loss: 1.4400
# Epoch 396/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4904 - val_loss: 0.3892
# Epoch 397/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3654 - val_loss: 0.1437
# Epoch 398/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3201 - val_loss: 0.0860
# Epoch 399/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4348 - val_loss: 0.2690
# Epoch 400/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6880 - val_loss: 0.2885
# Epoch 401/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4041 - val_loss: 1.8070
# Epoch 402/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7309 - val_loss: 0.2479
# Epoch 403/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4492 - val_loss: 0.4560
# Epoch 404/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.1108 - val_loss: 0.9692
# Epoch 405/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2760 - val_loss: 0.2973
# Epoch 406/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6184 - val_loss: 0.5158
# Epoch 407/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4126 - val_loss: 0.0948
# Epoch 408/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0865 - val_loss: 2.9082
# Epoch 409/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5591 - val_loss: 0.0511
# Epoch 410/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3527 - val_loss: 0.0572
# Epoch 411/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4317 - val_loss: 0.7372
# Epoch 412/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5156 - val_loss: 0.2543
# Epoch 413/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2945 - val_loss: 0.0416
# Epoch 414/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5792 - val_loss: 0.4600
# Epoch 415/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9816 - val_loss: 0.4157
# Epoch 416/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3814 - val_loss: 0.2886
# Epoch 417/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4861 - val_loss: 0.0749
# Epoch 418/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7730 - val_loss: 0.2560
# Epoch 419/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4056 - val_loss: 0.1370
# Epoch 420/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4466 - val_loss: 0.1761
# Epoch 421/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3188 - val_loss: 0.0969
# Epoch 422/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3286 - val_loss: 0.0792
# Epoch 423/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4085 - val_loss: 0.1046
# Epoch 424/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4735 - val_loss: 1.4088
# Epoch 425/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6410 - val_loss: 0.3046
# Epoch 426/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9225 - val_loss: 0.0530
# Epoch 427/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4411 - val_loss: 0.6548
# Epoch 428/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8156 - val_loss: 0.3717
# Epoch 429/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3006 - val_loss: 0.5938
# Epoch 430/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3587 - val_loss: 0.1768
# Epoch 431/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3219 - val_loss: 0.3964
# Epoch 432/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4217 - val_loss: 0.0372
# Epoch 433/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6096 - val_loss: 0.4915
# Epoch 434/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2698 - val_loss: 0.1427
# Epoch 435/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2570 - val_loss: 1.2692
# Epoch 436/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3842 - val_loss: 0.5613
# Epoch 437/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4465 - val_loss: 0.9777
# Epoch 438/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7062 - val_loss: 0.1934
# Epoch 439/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5413 - val_loss: 0.1756
# Epoch 440/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2631 - val_loss: 0.0316
# Epoch 441/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2716 - val_loss: 0.1540
# Epoch 442/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4992 - val_loss: 0.0634
# Epoch 443/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4590 - val_loss: 0.5861
# Epoch 444/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4447 - val_loss: 0.2301
# Epoch 445/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2860 - val_loss: 0.0383
# Epoch 446/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4690 - val_loss: 0.2032
# Epoch 447/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3247 - val_loss: 0.3355
# Epoch 448/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4285 - val_loss: 0.1574
# Epoch 449/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3684 - val_loss: 0.5062
# Epoch 450/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3545 - val_loss: 0.2040
# Epoch 451/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5629 - val_loss: 0.2889
# Epoch 452/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6220 - val_loss: 1.4102
# Epoch 453/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9992 - val_loss: 0.0369
# Epoch 454/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3262 - val_loss: 0.3901
# Epoch 455/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3859 - val_loss: 0.7076
# Epoch 456/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4911 - val_loss: 0.2032
# Epoch 457/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2314 - val_loss: 0.0507
# Epoch 458/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6452 - val_loss: 0.9602
# Epoch 459/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0760 - val_loss: 0.0996
# Epoch 460/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8144 - val_loss: 1.7329
# Epoch 461/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6567 - val_loss: 0.1497
# Epoch 462/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3624 - val_loss: 0.1659
# Epoch 463/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3282 - val_loss: 0.1937
# Epoch 464/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4304 - val_loss: 1.2884
# Epoch 465/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7421 - val_loss: 6.2501
# Epoch 466/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.3365 - val_loss: 0.7205
# Epoch 467/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.6070 - val_loss: 6.0434
# Epoch 468/500
# 24/24 [==============================] - 0s 1ms/step - loss: 2.2652 - val_loss: 0.6757
# Epoch 469/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8268 - val_loss: 0.0332
# Epoch 470/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2773 - val_loss: 0.0378
# Epoch 471/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2977 - val_loss: 0.0133
# Epoch 472/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3030 - val_loss: 0.0616
# Epoch 473/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4921 - val_loss: 0.1304
# Epoch 474/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3638 - val_loss: 1.1231
# Epoch 475/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6966 - val_loss: 0.0194
# Epoch 476/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3244 - val_loss: 0.0660
# Epoch 477/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4405 - val_loss: 0.0937
# Epoch 478/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3233 - val_loss: 0.1586
# Epoch 479/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7158 - val_loss: 0.6875
# Epoch 480/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5558 - val_loss: 0.1585
# Epoch 481/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2365 - val_loss: 0.0310
# Epoch 482/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2353 - val_loss: 0.1101
# Epoch 483/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2869 - val_loss: 0.0223
# Epoch 484/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2548 - val_loss: 0.3811
# Epoch 485/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3417 - val_loss: 0.6010
# Epoch 486/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2808 - val_loss: 0.0953
# Epoch 487/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2426 - val_loss: 0.0147
# Epoch 488/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2713 - val_loss: 0.5145
# Epoch 489/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3018 - val_loss: 0.6380
# Epoch 490/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3705 - val_loss: 0.0687
# Epoch 491/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5879 - val_loss: 1.5212
# Epoch 492/500
# 24/24 [==============================] - 0s 1ms/step - loss: 1.2875 - val_loss: 2.9454
# Epoch 493/500
# 24/24 [==============================] - 0s 1ms/step - loss: 3.7309 - val_loss: 11.8328
# Epoch 494/500
# 24/24 [==============================] - 0s 2ms/step - loss: 2.1096 - val_loss: 2.3428
# Epoch 495/500
# 24/24 [==============================] - 0s 2ms/step - loss: 2.1505 - val_loss: 1.6250
# Epoch 496/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6460 - val_loss: 0.0830
# Epoch 497/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3303 - val_loss: 0.0801
# Epoch 498/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2406 - val_loss: 0.0294
# Epoch 499/500
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2501 - val_loss: 0.0995
# Epoch 500/500
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3869 - val_loss: 0.2510

# %%
plt.plot(model_train.history['loss'], color='r', )
plt.plot(model_train.history['val_loss'], color='g')
plt.ylabel('MSE')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig("loss_dlbinnedJla.png", dpi=200)

# %%
unet = np.sqrt(np.min(model_train.history['val_loss']))
unet
# Out:
# 0.11539851234019882

# %%
# ranz = np.random.uniform(np.min(z), np.max(z), size=31)
ranz = np.linspace(np.min(z), np.max(z), 31)
# ranzz = scalerz.transform(ranz.reshape((-1,1)))
pred_random = neural_model.predict(ranz)
np.shape(pred_random), np.shape(z)
# Out:
# ((31, 1), (31,))

# %% [markdown]
# ### Now we use randz (fake z) as inpute of the decoder neural netkork. But it is worth to make a mapping
#
# $z_{original} \rightarrow encoded_{vals} \implies z_{original} \alpha =  encoded_{vals} \implies \alpha = \frac{encoded}{z_{original}}$
#
# So, for fake z:
#
# $encoded_{fake} = \alpha z_{fake}$

# %%
fake_encoded = np.zeros(31)
avg_encoded = np.mean(encoded_imgs[2], axis=0)
print('fake encoded', np.shape(fake_encoded))
print('encoded imgs', np.shape(encoded_imgs))
print('avg encoded', np.shape(avg_encoded))
print('randz', np.shape(ranz))

for i, avg in enumerate(avg_encoded):
    alpha = avg/z[i]
    fake_encoded[i] = alpha * ranz[i]
# Out:
# fake encoded (31,)
# encoded imgs (3, 200, 31)
# avg encoded (31,)
# randz (31,)

# %%
len(fake_encoded)
# Out:
# 31

# %%
decoded_fake = decoder.predict(fake_encoded.reshape(1,31))

sns.heatmap(pd.DataFrame(decoded_fake[0, :].reshape(31,31)), 
            fmt='g', xticklabels=False, yticklabels=False, 
            cmap = 'inferno',
            robust=False)

# clean_img = autoencoder.predict(decoded_fake[0, :].reshape(1,-1))
# plt.savefig('fake_cov_jla.png', dpi=200)
# np.min(np.abs(decoded_fake[0, :]))

# %%
# clean_img = autoencoder.predict(decoded_fake[0, :].reshape(1,-1))
clean_img = vae.predict(decoded_fake[0, :].reshape(1,-1))
# clean_img = vae.predict(clean_img[0, :].reshape(1,-1))
sns.heatmap(pd.DataFrame(clean_img[0, :].reshape(31,31)), 
            fmt='g', xticklabels=False, yticklabels=False, 
            cmap = 'inferno', 
            robust=False)
plt.savefig('fake_cov_clean_jla.png', dpi=200)

# %%
np.savetxt("fake_binned_JLA_COVdecoded.dat", decoded_fake[0, :].reshape(31,31), delimiter= " ", header="#fake COV")
np.savetxt("fake_binned_JLA_COVdecodedclean.dat", clean_img[0, :].reshape(31,31), delimiter= " ", header="#fake COV")

# %%
count = 0
new_cov =decoded_fake[0, :].reshape(31,31)

for i in range(len(new_cov)):
    for j in range(len(new_cov)):
        if np.iscomplex(new_cov[i,j]):
            print("COMPLEX")
        if new_cov[i,j] != new_cov[j,i]:
            count+=1
            new_cov[j,i] = new_cov[i, j]

count
# Out:
# 465

# %%
np.savetxt("fake_binned_JLA_COVdecodedsim.dat", new_cov, delimiter= " ", 
           header="#fake COV")

# %%
sns.heatmap(pd.DataFrame(new_cov), fmt='g', xticklabels=False, yticklabels=False, 
            cmap = 'inferno', 
            robust=False)

# %%
fake_data = np.concatenate((ranz.reshape(-1,1), pred_random), axis=1)
np.savetxt("fake_binned_JLA.dat",  fake_data, delimiter= " ", 
           header="#fake data\n# z\n# mu")
errors = np.sqrt(np.abs(np.diagonal(syscov)))
fakeerrors = np.sqrt(np.abs(np.diagonal(decoded_fake.reshape(31,31))))

# %%
plt.errorbar(z, dl, yerr=errors, fmt='g.', markersize=10, label='Observations')
plt.errorbar(ranz, pred_random, 
             yerr=fakeerrors, fmt='r.', markersize=10., label='Synthetic data with errors')

plt.xlabel("Redshift z")
plt.ylabel("$D_L(z)$")
plt.xlim(0, np.max(z))
plt.tight_layout()
plt.legend()
plt.savefig('fake_vs_binned_jla.png', dpi=50)

# %%
fake_datadf = pd.DataFrame(fake_data, columns=['z', '$D_L$'])
sns.pairplot(fake_datadf, diag_kind="kde")
plt.savefig('fake_binned_jla.png')

# %% [markdown]
# ### NOW we use dropout as uncertainty estimator

# %%
from astroNN.nn.layers import MCDropout

# %%
# This is the size of our encoded representations
encoding_dim = 31  

# This is our input image
input_img2 = tf.keras.Input(shape=(31*31,))

# begin encoder
x2 = layers.Dense(100, activation='tanh')(input_img2)
x2 = MCDropout(0.2)(x2)
x2 = layers.Dense(100, activation='tanh')(x2)
x2 = MCDropout(0.2)(x2)
encoded2 = layers.Dense(encoding_dim, activation='tanh')(x2)
x2 = MCDropout(0.2)(encoded2)

#begin decoder
x2 = layers.Dense(100, activation='tanh')(x2)
x2 = MCDropout(0.2)(x2)
x2 = layers.Dense(100, activation='tanh')(x2)

# x2 = MCDropout(0.2)(x2)
decoded2 = layers.Dense(31*31, activation='linear')(x2)


# This model maps an input to its reconstruction
autoencoder2 = tf.keras.Model(input_img2, decoded2)
autoencoder2.compile(optimizer='adam', loss='mean_squared_error')
autoencoder2.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 961)]             0
# _________________________________________________________________
# dense_10 (Dense)             (None, 100)               96200
# _________________________________________________________________
# MCDropout_1 (MCDropout)      (None, 100)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 100)               10100
# _________________________________________________________________
# MCDropout_2 (MCDropout)      (None, 100)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 31)                3131
# _________________________________________________________________
# MCDropout_3 (MCDropout)      (None, 31)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 100)               3200
# _________________________________________________________________
# MCDropout_4 (MCDropout)      (None, 100)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_15 (Dense)             (None, 961)               97061
# =================================================================
# Total params: 219,792
# Trainable params: 219,792
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder2_train = autoencoder2.fit(covset_noise_train, covset_train,
                    epochs=500,
                    batch_size=32,
                    shuffle=True,
                    validation_data=(covset_noise_test, covset_test),
                    callbacks=callbacks)
# Out:
# Epoch 1/500
# 25/25 [==============================] - 0s 7ms/step - loss: 6.9167e-04 - val_loss: 2.6863e-04
# Epoch 2/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4022e-04 - val_loss: 1.0655e-04
# Epoch 3/500
# 25/25 [==============================] - 0s 6ms/step - loss: 6.8959e-05 - val_loss: 6.5325e-05
# Epoch 4/500
# 25/25 [==============================] - 0s 3ms/step - loss: 4.4615e-05 - val_loss: 4.6642e-05
# Epoch 5/500
# 25/25 [==============================] - 0s 3ms/step - loss: 3.3789e-05 - val_loss: 3.8746e-05
# Epoch 6/500
# 25/25 [==============================] - 0s 3ms/step - loss: 2.6125e-05 - val_loss: 3.0642e-05
# Epoch 7/500
# 25/25 [==============================] - 0s 3ms/step - loss: 2.0920e-05 - val_loss: 2.5437e-05
# Epoch 8/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7521e-05 - val_loss: 2.2693e-05
# Epoch 9/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4651e-05 - val_loss: 1.8938e-05
# Epoch 10/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3055e-05 - val_loss: 1.5620e-05
# Epoch 11/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1156e-05 - val_loss: 1.4865e-05
# Epoch 12/500
# 25/25 [==============================] - 0s 3ms/step - loss: 9.9090e-06 - val_loss: 1.2170e-05
# Epoch 13/500
# 25/25 [==============================] - 0s 3ms/step - loss: 8.6573e-06 - val_loss: 1.1716e-05
# Epoch 14/500
# 25/25 [==============================] - 0s 3ms/step - loss: 7.9194e-06 - val_loss: 1.0307e-05
# Epoch 15/500
# 25/25 [==============================] - 0s 3ms/step - loss: 7.1116e-06 - val_loss: 9.4815e-06
# Epoch 16/500
# 25/25 [==============================] - 0s 3ms/step - loss: 6.5001e-06 - val_loss: 8.3617e-06
# Epoch 17/500
# 25/25 [==============================] - 0s 3ms/step - loss: 6.1324e-06 - val_loss: 7.9261e-06
# Epoch 18/500
# 25/25 [==============================] - 0s 3ms/step - loss: 5.4865e-06 - val_loss: 7.3054e-06
# Epoch 19/500
# 25/25 [==============================] - 0s 4ms/step - loss: 5.1082e-06 - val_loss: 6.9190e-06
# Epoch 20/500
# 25/25 [==============================] - 0s 4ms/step - loss: 4.8704e-06 - val_loss: 6.3101e-06
# Epoch 21/500
# 25/25 [==============================] - 0s 3ms/step - loss: 4.5246e-06 - val_loss: 6.0866e-06
# Epoch 22/500
# 25/25 [==============================] - 0s 3ms/step - loss: 4.2439e-06 - val_loss: 5.5621e-06
# Epoch 23/500
# 25/25 [==============================] - 0s 3ms/step - loss: 4.0042e-06 - val_loss: 5.5660e-06
# Epoch 24/500
# 25/25 [==============================] - 0s 3ms/step - loss: 3.7599e-06 - val_loss: 4.8977e-06
# Epoch 25/500
# 25/25 [==============================] - 0s 3ms/step - loss: 3.5449e-06 - val_loss: 4.6961e-06
# Epoch 26/500
# 25/25 [==============================] - 0s 3ms/step - loss: 3.3574e-06 - val_loss: 4.4718e-06
# Epoch 27/500
# 25/25 [==============================] - 0s 3ms/step - loss: 3.2370e-06 - val_loss: 4.3405e-06
# Epoch 28/500
# 25/25 [==============================] - 0s 4ms/step - loss: 3.0931e-06 - val_loss: 4.0861e-06
# Epoch 29/500
# 25/25 [==============================] - 0s 3ms/step - loss: 2.9510e-06 - val_loss: 3.8939e-06
# Epoch 30/500
# 25/25 [==============================] - 0s 3ms/step - loss: 2.8398e-06 - val_loss: 3.8670e-06
# Epoch 31/500
# 25/25 [==============================] - 0s 3ms/step - loss: 2.7134e-06 - val_loss: 3.7499e-06
# Epoch 32/500
# 25/25 [==============================] - 0s 3ms/step - loss: 2.6339e-06 - val_loss: 3.4267e-06
# Epoch 33/500
# 25/25 [==============================] - 0s 3ms/step - loss: 2.5738e-06 - val_loss: 3.4197e-06
# Epoch 34/500
# 25/25 [==============================] - 0s 3ms/step - loss: 2.4438e-06 - val_loss: 3.3219e-06
# Epoch 35/500
# 25/25 [==============================] - 0s 3ms/step - loss: 2.4246e-06 - val_loss: 3.0709e-06
# Epoch 36/500
# 25/25 [==============================] - 0s 3ms/step - loss: 2.3167e-06 - val_loss: 3.0420e-06
# Epoch 37/500
# 25/25 [==============================] - 0s 3ms/step - loss: 2.2787e-06 - val_loss: 2.9798e-06
# Epoch 38/500
# 25/25 [==============================] - 0s 4ms/step - loss: 2.1740e-06 - val_loss: 2.8169e-06
# Epoch 39/500
# 25/25 [==============================] - 0s 3ms/step - loss: 2.1573e-06 - val_loss: 2.7708e-06
# Epoch 40/500
# 25/25 [==============================] - 0s 3ms/step - loss: 2.0880e-06 - val_loss: 2.6583e-06
# Epoch 41/500
# 25/25 [==============================] - 0s 3ms/step - loss: 2.0175e-06 - val_loss: 2.5439e-06
# Epoch 42/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.9914e-06 - val_loss: 2.5124e-06
# Epoch 43/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.9486e-06 - val_loss: 2.4426e-06
# Epoch 44/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8921e-06 - val_loss: 2.3636e-06
# Epoch 45/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8583e-06 - val_loss: 2.2945e-06
# Epoch 46/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.8277e-06 - val_loss: 2.2824e-06
# Epoch 47/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7850e-06 - val_loss: 2.2110e-06
# Epoch 48/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7535e-06 - val_loss: 2.2330e-06
# Epoch 49/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.7272e-06 - val_loss: 2.1381e-06
# Epoch 50/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6930e-06 - val_loss: 2.0863e-06
# Epoch 51/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6531e-06 - val_loss: 2.0428e-06
# Epoch 52/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6383e-06 - val_loss: 2.0292e-06
# Epoch 53/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6250e-06 - val_loss: 1.9736e-06
# Epoch 54/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5951e-06 - val_loss: 1.9164e-06
# Epoch 55/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5792e-06 - val_loss: 1.8973e-06
# Epoch 56/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5485e-06 - val_loss: 1.8705e-06
# Epoch 57/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5412e-06 - val_loss: 1.8278e-06
# Epoch 58/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5147e-06 - val_loss: 1.8392e-06
# Epoch 59/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4944e-06 - val_loss: 1.7628e-06
# Epoch 60/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4860e-06 - val_loss: 1.7393e-06
# Epoch 61/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4630e-06 - val_loss: 1.7417e-06
# Epoch 62/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4478e-06 - val_loss: 1.7242e-06
# Epoch 63/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4286e-06 - val_loss: 1.7000e-06
# Epoch 64/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4324e-06 - val_loss: 1.6828e-06
# Epoch 65/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4046e-06 - val_loss: 1.6628e-06
# Epoch 66/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4035e-06 - val_loss: 1.5992e-06
# Epoch 67/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3792e-06 - val_loss: 1.5987e-06
# Epoch 68/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3741e-06 - val_loss: 1.5636e-06
# Epoch 69/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3592e-06 - val_loss: 1.5643e-06
# Epoch 70/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3461e-06 - val_loss: 1.5456e-06
# Epoch 71/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3411e-06 - val_loss: 1.5266e-06
# Epoch 72/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3371e-06 - val_loss: 1.5149e-06
# Epoch 73/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3139e-06 - val_loss: 1.4754e-06
# Epoch 74/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3076e-06 - val_loss: 1.4928e-06
# Epoch 75/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3044e-06 - val_loss: 1.4705e-06
# Epoch 76/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2921e-06 - val_loss: 1.4713e-06
# Epoch 77/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2876e-06 - val_loss: 1.4517e-06
# Epoch 78/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2779e-06 - val_loss: 1.4517e-06
# Epoch 79/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2746e-06 - val_loss: 1.4445e-06
# Epoch 80/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2702e-06 - val_loss: 1.4209e-06
# Epoch 81/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2594e-06 - val_loss: 1.4180e-06
# Epoch 82/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2594e-06 - val_loss: 1.3889e-06
# Epoch 83/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2428e-06 - val_loss: 1.3874e-06
# Epoch 84/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2396e-06 - val_loss: 1.3716e-06
# Epoch 85/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2347e-06 - val_loss: 1.3567e-06
# Epoch 86/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2284e-06 - val_loss: 1.3700e-06
# Epoch 87/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.2196e-06 - val_loss: 1.3483e-06
# Epoch 88/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2199e-06 - val_loss: 1.3252e-06
# Epoch 89/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2146e-06 - val_loss: 1.3245e-06
# Epoch 90/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.2086e-06 - val_loss: 1.3110e-06
# Epoch 91/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1994e-06 - val_loss: 1.3121e-06
# Epoch 92/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2000e-06 - val_loss: 1.3140e-06
# Epoch 93/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.2013e-06 - val_loss: 1.3276e-06
# Epoch 94/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1894e-06 - val_loss: 1.2948e-06
# Epoch 95/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.1909e-06 - val_loss: 1.2877e-06
# Epoch 96/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1826e-06 - val_loss: 1.2884e-06
# Epoch 97/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1815e-06 - val_loss: 1.2688e-06
# Epoch 98/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1720e-06 - val_loss: 1.2795e-06
# Epoch 99/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1745e-06 - val_loss: 1.2673e-06
# Epoch 100/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1687e-06 - val_loss: 1.2546e-06
# Epoch 101/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1688e-06 - val_loss: 1.2548e-06
# Epoch 102/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1668e-06 - val_loss: 1.2573e-06
# Epoch 103/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1655e-06 - val_loss: 1.2491e-06
# Epoch 104/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1605e-06 - val_loss: 1.2398e-06
# Epoch 105/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1564e-06 - val_loss: 1.2403e-06
# Epoch 106/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1571e-06 - val_loss: 1.2288e-06
# Epoch 107/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1496e-06 - val_loss: 1.2244e-06
# Epoch 108/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1479e-06 - val_loss: 1.2298e-06
# Epoch 109/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1464e-06 - val_loss: 1.2206e-06
# Epoch 110/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1433e-06 - val_loss: 1.2121e-06
# Epoch 111/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1366e-06 - val_loss: 1.2002e-06
# Epoch 112/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1378e-06 - val_loss: 1.2064e-06
# Epoch 113/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1320e-06 - val_loss: 1.1997e-06
# Epoch 114/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1335e-06 - val_loss: 1.2050e-06
# Epoch 115/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1317e-06 - val_loss: 1.1991e-06
# Epoch 116/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1289e-06 - val_loss: 1.1960e-06
# Epoch 117/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1318e-06 - val_loss: 1.1859e-06
# Epoch 118/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1258e-06 - val_loss: 1.1915e-06
# Epoch 119/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1273e-06 - val_loss: 1.1856e-06
# Epoch 120/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1249e-06 - val_loss: 1.1838e-06
# Epoch 121/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1208e-06 - val_loss: 1.1807e-06
# Epoch 122/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1216e-06 - val_loss: 1.1719e-06
# Epoch 123/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1167e-06 - val_loss: 1.1783e-06
# Epoch 124/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1163e-06 - val_loss: 1.1668e-06
# Epoch 125/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1174e-06 - val_loss: 1.1668e-06
# Epoch 126/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1122e-06 - val_loss: 1.1725e-06
# Epoch 127/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1128e-06 - val_loss: 1.1644e-06
# Epoch 128/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1106e-06 - val_loss: 1.1549e-06
# Epoch 129/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1095e-06 - val_loss: 1.1575e-06
# Epoch 130/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1096e-06 - val_loss: 1.1670e-06
# Epoch 131/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1077e-06 - val_loss: 1.1540e-06
# Epoch 132/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1085e-06 - val_loss: 1.1559e-06
# Epoch 133/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1038e-06 - val_loss: 1.1495e-06
# Epoch 134/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1024e-06 - val_loss: 1.1546e-06
# Epoch 135/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1076e-06 - val_loss: 1.1509e-06
# Epoch 136/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1037e-06 - val_loss: 1.1519e-06
# Epoch 137/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1002e-06 - val_loss: 1.1476e-06
# Epoch 138/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0972e-06 - val_loss: 1.1481e-06
# Epoch 139/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0977e-06 - val_loss: 1.1387e-06
# Epoch 140/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0986e-06 - val_loss: 1.1453e-06
# Epoch 141/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0959e-06 - val_loss: 1.1365e-06
# Epoch 142/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0967e-06 - val_loss: 1.1376e-06
# Epoch 143/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0960e-06 - val_loss: 1.1350e-06
# Epoch 144/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0936e-06 - val_loss: 1.1299e-06
# Epoch 145/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0934e-06 - val_loss: 1.1275e-06
# Epoch 146/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0881e-06 - val_loss: 1.1339e-06
# Epoch 147/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0917e-06 - val_loss: 1.1274e-06
# Epoch 148/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0931e-06 - val_loss: 1.1222e-06
# Epoch 149/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0884e-06 - val_loss: 1.1235e-06
# Epoch 150/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0876e-06 - val_loss: 1.1218e-06
# Epoch 151/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0875e-06 - val_loss: 1.1214e-06
# Epoch 152/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0884e-06 - val_loss: 1.1219e-06
# Epoch 153/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0886e-06 - val_loss: 1.1196e-06
# Epoch 154/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0847e-06 - val_loss: 1.1177e-06
# Epoch 155/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0851e-06 - val_loss: 1.1162e-06
# Epoch 156/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0857e-06 - val_loss: 1.1135e-06
# Epoch 157/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0847e-06 - val_loss: 1.1127e-06
# Epoch 158/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0843e-06 - val_loss: 1.1119e-06
# Epoch 159/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0819e-06 - val_loss: 1.1157e-06
# Epoch 160/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0879e-06 - val_loss: 1.1176e-06
# Epoch 161/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0815e-06 - val_loss: 1.1178e-06
# Epoch 162/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0827e-06 - val_loss: 1.1101e-06
# Epoch 163/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0794e-06 - val_loss: 1.1010e-06
# Epoch 164/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0813e-06 - val_loss: 1.1157e-06
# Epoch 165/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0830e-06 - val_loss: 1.1114e-06
# Epoch 166/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0822e-06 - val_loss: 1.1098e-06
# Epoch 167/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0803e-06 - val_loss: 1.1092e-06
# Epoch 168/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0805e-06 - val_loss: 1.1118e-06
# Epoch 169/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0830e-06 - val_loss: 1.1068e-06
# Epoch 170/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0786e-06 - val_loss: 1.1003e-06
# Epoch 171/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0766e-06 - val_loss: 1.1008e-06
# Epoch 172/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0771e-06 - val_loss: 1.0977e-06
# Epoch 173/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0767e-06 - val_loss: 1.1095e-06
# Epoch 174/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0762e-06 - val_loss: 1.0996e-06
# Epoch 175/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0759e-06 - val_loss: 1.0977e-06
# Epoch 176/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0757e-06 - val_loss: 1.1021e-06
# Epoch 177/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0708e-06 - val_loss: 1.0971e-06
# Epoch 178/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0731e-06 - val_loss: 1.0959e-06
# Epoch 179/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0725e-06 - val_loss: 1.0942e-06
# Epoch 180/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0732e-06 - val_loss: 1.0936e-06
# Epoch 181/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0755e-06 - val_loss: 1.0994e-06
# Epoch 182/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0757e-06 - val_loss: 1.0978e-06
# Epoch 183/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0752e-06 - val_loss: 1.0971e-06
# Epoch 184/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0739e-06 - val_loss: 1.0948e-06
# Epoch 185/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0710e-06 - val_loss: 1.0940e-06
# Epoch 186/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0714e-06 - val_loss: 1.0967e-06
# Epoch 187/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0754e-06 - val_loss: 1.0947e-06
# Epoch 188/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0700e-06 - val_loss: 1.0931e-06
# Epoch 189/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0706e-06 - val_loss: 1.0951e-06
# Epoch 190/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0722e-06 - val_loss: 1.0925e-06
# Epoch 191/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0731e-06 - val_loss: 1.0911e-06
# Epoch 192/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0728e-06 - val_loss: 1.0926e-06
# Epoch 193/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0699e-06 - val_loss: 1.0859e-06
# Epoch 194/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0684e-06 - val_loss: 1.0867e-06
# Epoch 195/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0684e-06 - val_loss: 1.0807e-06
# Epoch 196/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0678e-06 - val_loss: 1.0920e-06
# Epoch 197/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0676e-06 - val_loss: 1.0970e-06
# Epoch 198/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0694e-06 - val_loss: 1.0876e-06
# Epoch 199/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0704e-06 - val_loss: 1.0882e-06
# Epoch 200/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0682e-06 - val_loss: 1.0864e-06
# Epoch 201/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0677e-06 - val_loss: 1.0870e-06
# Epoch 202/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0653e-06 - val_loss: 1.0852e-06
# Epoch 203/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0663e-06 - val_loss: 1.0899e-06
# Epoch 204/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0667e-06 - val_loss: 1.0848e-06
# Epoch 205/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0659e-06 - val_loss: 1.0845e-06
# Epoch 206/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0673e-06 - val_loss: 1.0872e-06
# Epoch 207/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0679e-06 - val_loss: 1.0890e-06
# Epoch 208/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0655e-06 - val_loss: 1.0803e-06
# Epoch 209/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0628e-06 - val_loss: 1.0813e-06
# Epoch 210/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0642e-06 - val_loss: 1.0798e-06
# Epoch 211/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0648e-06 - val_loss: 1.0797e-06
# Epoch 212/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0655e-06 - val_loss: 1.0866e-06
# Epoch 213/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0652e-06 - val_loss: 1.0823e-06
# Epoch 214/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0676e-06 - val_loss: 1.0884e-06
# Epoch 215/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0660e-06 - val_loss: 1.0762e-06
# Epoch 216/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0641e-06 - val_loss: 1.0804e-06
# Epoch 217/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0627e-06 - val_loss: 1.0797e-06
# Epoch 218/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0644e-06 - val_loss: 1.0832e-06
# Epoch 219/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0657e-06 - val_loss: 1.0749e-06
# Epoch 220/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0611e-06 - val_loss: 1.0828e-06
# Epoch 221/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0624e-06 - val_loss: 1.0779e-06
# Epoch 222/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0611e-06 - val_loss: 1.0754e-06
# Epoch 223/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0654e-06 - val_loss: 1.0858e-06
# Epoch 224/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0624e-06 - val_loss: 1.0813e-06
# Epoch 225/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0630e-06 - val_loss: 1.0822e-06
# Epoch 226/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0675e-06 - val_loss: 1.0782e-06
# Epoch 227/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0629e-06 - val_loss: 1.0739e-06
# Epoch 228/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0621e-06 - val_loss: 1.0712e-06
# Epoch 229/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0621e-06 - val_loss: 1.0757e-06
# Epoch 230/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0627e-06 - val_loss: 1.0733e-06
# Epoch 231/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0627e-06 - val_loss: 1.0722e-06
# Epoch 232/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0612e-06 - val_loss: 1.0734e-06
# Epoch 233/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0642e-06 - val_loss: 1.0763e-06
# Epoch 234/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0631e-06 - val_loss: 1.0751e-06
# Epoch 235/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0614e-06 - val_loss: 1.0737e-06
# Epoch 236/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0640e-06 - val_loss: 1.0800e-06
# Epoch 237/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0621e-06 - val_loss: 1.0748e-06
# Epoch 238/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0612e-06 - val_loss: 1.0753e-06
# Epoch 239/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0643e-06 - val_loss: 1.0786e-06
# Epoch 240/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0584e-06 - val_loss: 1.0756e-06
# Epoch 241/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0607e-06 - val_loss: 1.0700e-06
# Epoch 242/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0592e-06 - val_loss: 1.0721e-06
# Epoch 243/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0594e-06 - val_loss: 1.0777e-06
# Epoch 244/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0583e-06 - val_loss: 1.0717e-06
# Epoch 245/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0587e-06 - val_loss: 1.0746e-06
# Epoch 246/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0605e-06 - val_loss: 1.0764e-06
# Epoch 247/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0605e-06 - val_loss: 1.0790e-06
# Epoch 248/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0609e-06 - val_loss: 1.0722e-06
# Epoch 249/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0594e-06 - val_loss: 1.0779e-06
# Epoch 250/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0600e-06 - val_loss: 1.0733e-06
# Epoch 251/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0597e-06 - val_loss: 1.0746e-06
# Epoch 252/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0567e-06 - val_loss: 1.0704e-06
# Epoch 253/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0624e-06 - val_loss: 1.0800e-06
# Epoch 254/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0655e-06 - val_loss: 1.0735e-06
# Epoch 255/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0629e-06 - val_loss: 1.0737e-06
# Epoch 256/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0606e-06 - val_loss: 1.0771e-06
# Epoch 257/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0608e-06 - val_loss: 1.0804e-06
# Epoch 258/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0613e-06 - val_loss: 1.0743e-06
# Epoch 259/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0588e-06 - val_loss: 1.0753e-06
# Epoch 260/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0577e-06 - val_loss: 1.0676e-06
# Epoch 261/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0591e-06 - val_loss: 1.0720e-06
# Epoch 262/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0573e-06 - val_loss: 1.0695e-06
# Epoch 263/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0601e-06 - val_loss: 1.0717e-06
# Epoch 264/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0597e-06 - val_loss: 1.0681e-06
# Epoch 265/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0577e-06 - val_loss: 1.0699e-06
# Epoch 266/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0599e-06 - val_loss: 1.0724e-06
# Epoch 267/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0594e-06 - val_loss: 1.0764e-06
# Epoch 268/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0573e-06 - val_loss: 1.0752e-06
# Epoch 269/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0581e-06 - val_loss: 1.0668e-06
# Epoch 270/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0555e-06 - val_loss: 1.0665e-06
# Epoch 271/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0578e-06 - val_loss: 1.0739e-06
# Epoch 272/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0575e-06 - val_loss: 1.0701e-06
# Epoch 273/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0556e-06 - val_loss: 1.0763e-06
# Epoch 274/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0559e-06 - val_loss: 1.0650e-06
# Epoch 275/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0579e-06 - val_loss: 1.0705e-06
# Epoch 276/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0574e-06 - val_loss: 1.0689e-06
# Epoch 277/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0587e-06 - val_loss: 1.0779e-06
# Epoch 278/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0581e-06 - val_loss: 1.0676e-06
# Epoch 279/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0530e-06 - val_loss: 1.0649e-06
# Epoch 280/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0548e-06 - val_loss: 1.0723e-06
# Epoch 281/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0562e-06 - val_loss: 1.0707e-06
# Epoch 282/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0579e-06 - val_loss: 1.0711e-06
# Epoch 283/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0577e-06 - val_loss: 1.0676e-06
# Epoch 284/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0591e-06 - val_loss: 1.0680e-06
# Epoch 285/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0568e-06 - val_loss: 1.0686e-06
# Epoch 286/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0554e-06 - val_loss: 1.0640e-06
# Epoch 287/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0549e-06 - val_loss: 1.0704e-06
# Epoch 288/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0580e-06 - val_loss: 1.0745e-06
# Epoch 289/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0554e-06 - val_loss: 1.0692e-06
# Epoch 290/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0554e-06 - val_loss: 1.0652e-06
# Epoch 291/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0541e-06 - val_loss: 1.0680e-06
# Epoch 292/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0550e-06 - val_loss: 1.0661e-06
# Epoch 293/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0564e-06 - val_loss: 1.0657e-06
# Epoch 294/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0536e-06 - val_loss: 1.0563e-06
# Epoch 295/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0541e-06 - val_loss: 1.0647e-06
# Epoch 296/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0568e-06 - val_loss: 1.0677e-06
# Epoch 297/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0585e-06 - val_loss: 1.0739e-06
# Epoch 298/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0580e-06 - val_loss: 1.0716e-06
# Epoch 299/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0554e-06 - val_loss: 1.0686e-06
# Epoch 300/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0566e-06 - val_loss: 1.0710e-06
# Epoch 301/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0577e-06 - val_loss: 1.0701e-06
# Epoch 302/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0553e-06 - val_loss: 1.0700e-06
# Epoch 303/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0571e-06 - val_loss: 1.0692e-06
# Epoch 304/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0539e-06 - val_loss: 1.0646e-06
# Epoch 305/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0541e-06 - val_loss: 1.0705e-06
# Epoch 306/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0565e-06 - val_loss: 1.0673e-06
# Epoch 307/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0558e-06 - val_loss: 1.0642e-06
# Epoch 308/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0559e-06 - val_loss: 1.0684e-06
# Epoch 309/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0563e-06 - val_loss: 1.0719e-06
# Epoch 310/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0554e-06 - val_loss: 1.0700e-06
# Epoch 311/500
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0569e-06 - val_loss: 1.0679e-06
# Epoch 312/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0531e-06 - val_loss: 1.0666e-06
# Epoch 313/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0528e-06 - val_loss: 1.0727e-06
# Epoch 314/500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0541e-06 - val_loss: 1.0644e-06

# %%
plt.plot(autoencoder2_train.history['loss'], color='r', )
plt.plot(autoencoder2_train.history['val_loss'], color='g')

plt.ylabel('MSE')
plt.xlabel('Epochs')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig('loss_binned_JLAdropout.png', dpi=50)

# %%
encoder2 = tf.keras.Model(input_img2, encoded2)

# This is our encoded (32-dimensional) input
encoded2_input = tf.keras.Input(shape=(encoding_dim,))

decoder2_layer1 = autoencoder2.layers[-5]
decoder2_layer2 = autoencoder2.layers[-4]
decoder2_layer3 = autoencoder2.layers[-3]
decoder2_layer4 = autoencoder2.layers[-2]
decoder2_layer5 = autoencoder2.layers[-1]

# create the decoder model
decoder2 = Model(encoded2_input, 
                decoder2_layer5(decoder2_layer4(
                    decoder2_layer3(decoder2_layer2(
                        decoder2_layer1(encoded2_input))))))
decoder2.summary()
# Out:
# Model: "functional_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 31)]              0
# _________________________________________________________________
# MCDropout_3 (MCDropout)      (None, 31)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 100)               3200
# _________________________________________________________________
# MCDropout_4 (MCDropout)      (None, 100)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_15 (Dense)             (None, 961)               97061
# =================================================================
# Total params: 110,361
# Trainable params: 110,361
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Generate test data
test_batch_size = 31*31
# x_test = np.random.uniform(0, np.max(z), test_batch_size)
# x_test = np.linspace(0, 2., test_batch_size)
print(np.shape(fake_encoded))
mc_dropout_num = 100  # Run Dropout 100 times
predictions_dec = np.zeros((mc_dropout_num, 1, test_batch_size))
uncertainty = np.zeros((mc_dropout_num, 1, test_batch_size))
for i in range(mc_dropout_num):
    predictions_dec[i] = decoder2.predict(fake_encoded)
    
# get mean results and its varience
prediction_mc_dropout_dec = np.mean(predictions_dec, axis=0)
std_mc_dropout_dec = np.std(predictions_dec, axis=0)
np.shape(prediction_mc_dropout_dec), np.shape(std_mc_dropout_dec)
# Out:
# (31,)
# WARNING:tensorflow:Model was constructed with shape (None, 31) for input Tensor("input_4:0", shape=(None, 31), dtype=float32), but it was called on an input with incompatible shape (None, 1).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-e37b1c616c20> in <module>
#       8 uncertainty = np.zeros((mc_dropout_num, 1, test_batch_size))
#       9 for i in range(mc_dropout_num):
# ---> 10     predictions_dec[i] = decoder2.predict(fake_encoded)
#      11
#      12 # get mean results and its varience
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     128       raise ValueError('{} is not supported in multi-worker mode.'.format(
#     129           method.__name__))
# --> 130     return method(self, *args, **kwargs)
#     131
#     132   return tf_decorator.make_decorator(
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1597           for step in data_handler.steps():
#    1598             callbacks.on_predict_batch_begin(step)
# -> 1599             tmp_batch_outputs = predict_function(iterator)
#    1600             if data_handler.should_sync:
#    1601               context.async_wait()
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     821       # This is the first call of __call__, so we have to initialize.
#     822       initializers = []
# --> 823       self._initialize(args, kwds, add_initializers_to=initializers)
#     824     finally:
#     825       # At this point we know that the initialization is complete (or less
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     695     self._concrete_stateful_fn = (
#     696         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
# --> 697             *args, **kwds))
#     698
#     699     def invalid_creator_scope(*unused_args, **unused_kwds):
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2853       args, kwargs = None, None
#    2854     with self._lock:
# -> 2855       graph_function, _, _ = self._maybe_define_function(args, kwargs)
#    2856     return graph_function
#    2857
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3211
#    3212       self._function_cache.missed.add(call_context_key)
# -> 3213       graph_function = self._create_graph_function(args, kwargs)
#    3214       self._function_cache.primary[cache_key] = graph_function
#    3215       return graph_function, args, kwargs
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3073             arg_names=arg_names,
#    3074             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3075             capture_by_value=self._capture_by_value),
#    3076         self._function_attributes,
#    3077         function_spec=self.function_spec,
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     984         _, original_func = tf_decorator.unwrap(python_func)
#     985
# --> 986       func_outputs = python_func(*func_args, **func_kwargs)
#     987
#     988       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     598         # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     599         # the function a weak reference to itself to avoid a reference cycle.
# --> 600         return weak_wrapped_fn().__wrapped__(*args, **kwds)
#     601     weak_wrapped_fn = weakref.ref(wrapped_fn)
#     602
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     971           except Exception as e:  # pylint:disable=broad-except
#     972             if hasattr(e, "ag_error_metadata"):
# --> 973               raise e.ag_error_metadata.to_exception(e)
#     974             else:
#     975               raise
#
# ValueError: in user code:
#
#     /home/isidro/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py:1462 predict_function  *
#         return step_function(self, iterator)
#     /home/isidro/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py:1452 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /home/isidro/.local/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py:1211 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /home/isidro/.local/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py:2585 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /home/isidro/.local/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py:2945 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /home/isidro/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py:1445 run_step  **
#         outputs = model.predict_step(data)
#     /home/isidro/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py:1418 predict_step
#         return self(x, training=False)
#     /home/isidro/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py:985 __call__
#         outputs = call_fn(inputs, *args, **kwargs)
#     /home/isidro/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/functional.py:386 call
#         inputs, training=training, mask=mask)
#     /home/isidro/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/functional.py:508 _run_internal_graph
#         outputs = node.layer(*args, **kwargs)
#     /home/isidro/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py:976 __call__
#         self.name)
#     /home/isidro/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/input_spec.py:216 assert_input_compatibility
#         ' but received input with shape ' + str(shape))
#
#     ValueError: Input 0 of layer dense_13 is incompatible with the layer: expected axis -1 of input shape to have value 31 but received input with shape [None, 1]

# %%
np.mean(std_mc_dropout_dec), np.shape(std_mc_dropout_dec)

# %%
def model2_dropout(input_z):
    efirst = Dense(50, activation='relu', input_shape=(1,))(input_z)
    x = MCDropout(0.02)(efirst)
    x = Dense(50, activation='relu')(x)
    x = MCDropout(0.02)(x)
    x = Dense(50, activation='relu')(x)
    x = MCDropout(0.02)(x)
    x = Dense(30, activation='relu')(x)
    x = MCDropout(0.02)(x)
    elast = Dense(1, activation='linear')(x)
    return elast

input_z = Input(shape = (1,))
neural_model2 = Model(input_z, model2_dropout(input_z))
neural_model2.compile(loss='mean_squared_error', optimizer = "adam")
neural_model2.summary()

# %%
model2_train = neural_model2.fit(z_train, dl_train, batch_size=32,
                                    epochs=1000, verbose=0,
                                    validation_data=(z_test, dl_test))

# %%
# Generate test data
test_batch_size = 31
x_test = np.random.uniform(0, np.max(z), test_batch_size)
# x_test = np.linspace(0.01, np.max(z), test_batch_size)

mc_dropout_num = 100  # Run Dropout 100 times
predictions = np.zeros((mc_dropout_num, test_batch_size, 1))
uncertainty = np.zeros((mc_dropout_num, test_batch_size, 1))
for i in range(mc_dropout_num):
    predictions[i] = neural_model2.predict(scalerz.transform(x_test.reshape(-1,1)))
#     print(predictions[i])

# get mean results and its varience
prediction_mc_dropout = np.mean(predictions, axis=0)
std_mc_dropout = np.std(predictions, axis=0)

# %%
plt.plot(model2_train.history['loss'], color='r', )
plt.plot(model2_train.history['val_loss'], color='g')
plt.ylabel('MSE')
plt.xlabel('Epoch')
# plt.xscale('log')
plt.xlim(0)
plt.legend(['train', 'val'], loc='upper left')
plt.savefig('loss_dropoutJLA.png', dpi=100)

# %%
Om = 0.27
w0 = -1

def RHSquared_a_lcdm(a):
    return Om*(1/a)**3 + 1 - Om

def RHSquared_a_owacdm(a, w0, wa):
    rhow = a**(-3*(1.0+w0+wa))*np.exp(-3*wa*(1-a))
    return (Om/a**3+(1.0-Om)*rhow)

def DistIntegrand_a(a, model, w0, wa):
        if model == 'lcdm':
            return 1./np.sqrt(RHSquared_a_lcdm(a))/a**2
        elif model == 'owacdm':
            return 1./np.sqrt(RHSquared_a_owacdm(a, w0, wa))/a**2
    
def Da_z(z, model, w0, wa):
        r = intg.quad(DistIntegrand_a, 1./(1+z), 1, args=(model, w0, wa))
        r = r[0]    
        return r
    
def distance_modulus(z, model='lcdm', w0=-1, wa=0.5):
    return 5*np.log10(Da_z(z, model, w0, wa)*(1+z))+43

# %%
zmodel = np.linspace(0.01, 1.5, 100)
flcdm = []
# fowacdm1 = []
# fowacdm2 = []
# fowacdm3 = []

# flcdm = []
for zzz in zmodel:
    flcdm.append(distance_modulus(zzz))
#     fowacdm1.append(distance_modulus(zz, model='owacdm', w0=-1, wa=0.5))
#     fowacdm2.append(distance_modulus(zz, model='owacdm', w0=-1, wa=-0.5))
#     fowacdm3.append(distance_modulus(zz, model='owacdm', w0=-1, wa=0.0))
    
flcdm = np.array(flcdm)
# fowacdm1 = np.array(fowacdm1)
# fowacdm2 = np.array(fowacdm2)
# fowacdm3 = np.array(fowacdm3)

# %%
# Plotting
plt.figure(figsize=(10, 7), dpi=100)
# plt.figure(figsize=(5, 4), dpi=100)

fakeerrors2 = np.sqrt(np.abs(np.diagonal(prediction_mc_dropout_dec .reshape(31,31))))

std_dropout_diag = np.sqrt(np.abs(np.diagonal(std_mc_dropout_dec.reshape(31,31))))

sigma = np.sqrt(std_mc_dropout.reshape(31,)**2 + fakeerrors2 + std_dropout_diag**2)

plt.errorbar(x_test, prediction_mc_dropout, yerr=sigma
             , markersize=10, fmt='.', 
             ecolor='blue', capthick=2, elinewidth=0.9, alpha=0.8, c='b',
             label='Synthetic data with $\sigma$')

# plt.scatter(scalerz.inverse_transform(zz), yy, color='k', label='Original cosmic chronometers')
plt.errorbar(z, dl, errors, fmt='g.', markersize=10, label='Observations')
plt.plot(zmodel, flcdm, label='$\Lambda CDM$', c='r')
# plt.plot(zmodel, fowacdm1, label='$\omega_0\omega_aCDM \;\; \omega_a=0.5$', c='m')
# plt.plot(zmodel, fowacdm2, label='$\omega_0\omega_aCDM \;\; \omega_a=-0.5$', c='y')
# plt.plot(zmodel, Hlcdm(zmodel), label='$\Lambda CDM$ $H_0 = 73.24$', c='k')
# plt.plot(zmodel, Hlcdm(zmodel, H0=67.4), label='$\Lambda CDM$ $H_0 = 67.4$', c='b')
plt.xlim(0, np.max(z)+0.05)
plt.xlabel('Redshift')
plt.ylabel('$D_L(z)$')
# plt.legend(loc='best')
plt.legend(loc='upper right')
# plt.show()
plt.savefig('DL_dropout5.png', dpi=50)

# %%
np.savetxt("fake_binned_JLA_COVdecodedDO.dat", prediction_mc_dropout_dec[0, :].reshape(31,31), delimiter= " ", header="#fake COV")
fake_data2 = np.concatenate((x_test.reshape(-1,1), prediction_mc_dropout), axis=1)
np.savetxt("fake_binned_JLADO.dat",  fake_data2, delimiter= " ", header="#fake data\n# z\n# mu")

sns.heatmap(pd.DataFrame(prediction_mc_dropout_dec[0, :].reshape(31,31)), annot=False, fmt='g', xticklabels=False, yticklabels=False, 
            cmap = 'inferno')
plt.savefig("fake_cov_binned_JLA_DO.png", dpi=200)

# %%
fake_datadf2 = pd.DataFrame(fake_data2, columns=['z', '$D_L$'])
sns.pairplot(fake_datadf2, diag_kind="kde")
plt.savefig('fake_binned_jla22DO.png')

# %%
# clean_img = autoencoder2.predict(prediction_mc_dropout_dec[0, :].reshape(1,-1))

# %%
np.savetxt("fake_binned_JLA_COVdecodedDO.dat", clean_img.reshape(31,31), delimiter= " ", header="#fake COV")
fake_data2 = np.concatenate((x_test.reshape(-1,1), prediction_mc_dropout), axis=1)
np.savetxt("fake_binned_JLADO.dat",  fake_data2, delimiter= " ", header="#fake data\n# z\n# mu")
