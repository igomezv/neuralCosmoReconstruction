# %%
import matplotlib.pyplot as plt
from getdist import plots, MCSamples
from getdist import *

# import planckStyle
import pylab
import numpy as np
import matplotlib
import tkinter

matplotlib.use('TkAgg')


# %matplotlib inline

# %% [markdown]
# ## Using CPL
#
# $ \frac{H(z)^2}{H_0^2} = \Omega_{m,0}(1+z)^3 + (1-\Omega_{m,0})(1+z)^{3(1+\omega_0+\omega_a)} e^{-\frac{3\omega_a z}{1+z}}$
#
# #### Defining file names for MCMC chains for posterior pdf sampling

# %%
dir_name = '/home/isidro/SimpleMC/chains/'


roots_fs8_planck = [
          'waCDM_phy_fs8+Planck_nested_dynesty_multi',
          'waCDM_phy_fs8+Planck_nested_dynesty_multi_new',
          'waCDM_phy_fs8+Planck_nested_dynesty_multi_new_new']

roots_fs8 = [
          'waCDM_phy_fs8_nested_dynesty_multi',
          'waCDM_phy_fs8_nested_dynesty_multi_new',
          'waCDM_phy_fs8_nested_dynesty_multi_new_new']


roots_HD = [
          'waCDM_phy_HD_nested_dynesty_multi',
          'waCDM_phy_HD_nested_dynesty_multi_new',
          'waCDM_phy_HD_nested_dynesty_multi_new_new']

roots_HD_planck = [
                  'waCDM_phy_HD+Planck_nested_dynesty_multi',
                  'waCDM_phy_HD+Planck_nested_dynesty_multi_new',
                   'waCDM_phy_HD+Planck_nested_dynesty_multi_new_new'
                   ]

roots_SN = [
                  'waCDM_phy_SN_nested_dynesty_multi',
                  'waCDM_phy_SN_nested_dynesty_multi_new',
                  'waCDM_phy_SN_nested_dynesty_multi_new_new'
                  ]


roots_SN_planck = [
                  'waCDM_phy_SN+Planck_nested_dynesty_multi',
                  'waCDM_phy_SN+Planck_nested_dynesty_multi_new',
                  'waCDM_phy_SN+Planck_nested_dynesty_multi_new_new',]

roots_cc_sn = [
                  'waCDM_phy_SN+HD_nested_dynesty_multi',
                  'waCDM_phy_SN+HD_nested_dynesty_multi_new',
                  'waCDM_phy_SN+HD_nested_dynesty_multi_new_new']

roots_cc_sn_planck = [
                      'waCDM_phy_SN+HD+Planck_nested_dynesty_multi',
                      'waCDM_phy_SN+HD+Planck_nested_dynesty_multi_new',
                      'waCDM_phy_SN+HD+Planck_nested_dynesty_multi_new_new']

roots_all = [
                  'waCDM_phy_SN+HD+fs8_nested_dynesty_multi',
                  'waCDM_phy_SN+HD+fs8_nested_dynesty_multi_new',
                  'waCDM_phy_SN+HD+fs8_nested_dynesty_multi_new_new_new']

roots_all_planck = [
                  'waCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi',
                  'waCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi_new',
                  'waCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi_new_new_new']

roots_polycdm = [
                'PolyCDM_phy_SN+HD+fs8_nested_dynesty_multi',
                'PolyCDM_phy_SN+HD+fs8_nested_dynesty_multi_new',
                'PolyCDM_phy_SN+HD+fs8_nested_dynesty_multi_new_new'
                ]

# %% [markdown]
# # Cosmic chronometers
#
# ### Only HD data

# %%
g = plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.9, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})

# %% [markdown]
# ### Full triangle plot

# %%
#g.settings.axes_fontsize = 5
g.settings.lab_fontsize = 15
g.settings.x_label_rotation= 45
#g.settings.alpha_filled_add = 0.9
g.settings.legend_fontsize = 15
g.settings.axes_fontsize = 15   
# g.settings.lw1 = 0.5

g.triangle_plot(roots_HD, ['Om', 'Obh2', 'h', 'w', 'wa'],
# g.triangle_plot(roots, ['Om', 'Obh2', 'h'],
                diag1d_kwargs={'colors':['black', 'red','blue','black', 'yellow'], 
                               'alphas':[1.0,1.0,1.0]},
                colors=['black', 'red','blue',  'black', 'yellow'],
#                 alphas = [1.0, 0.7, 0.5],
                legend_labels=['31 original cc ', '50 synthetic cc from FFNN',
                               '50 synthetic data points from FFNN+MC dropout'],
#                 legend_labels=['31 original data points ', '31 synthetic data points from AE+FFNN',
#                                '31 synthetic data points from AE+FFNN+dropout'],
                legend_loc='upper right',
                filled = False,
                normalized=False, shaded=False)
        
#plt.show()
plt.savefig('TrianglewaCDMHz', dpi=80)

# %% [markdown]
# ### Posteriors pdf for only $\omega_0$ and $\omega_a$ :

# %%
#g.settings.axes_fontsize = 5
g.settings.lab_fontsize = 20
g.settings.x_label_rotation= 45
g.settings.legend_fontsize = 20
g.settings.axes_fontsize = 20

g.triangle_plot(roots_HD, ['w', 'wa'],
# g.triangle_plot(roots, ['Om', 'Obh2', 'h'],
                diag1d_kwargs={'colors':['black', 'red','blue','black', 'yellow'], 
                               'alphas':[1.0,1.0,1.0]},
                colors=['black', 'red','blue',  'black', 'yellow'],
#                 alphas = [1.0, 0.7, 0.5],

                legend_labels=['original data points ', 'points from FFNN',
                               'points from FFNN+dropout'],
                legend_loc='upper right',
                filled = False)
# plt.savefig('TriangleowaCDMfs8_b.png', dpi=50)

# %% [markdown]
# ### HD + Planck point

# %%
g.settings.lab_fontsize = 20
g.settings.x_label_rotation= 45
g.settings.legend_fontsize = 12
g.settings.axes_fontsize = 20     

g.triangle_plot(roots_HD_planck, ['Om', 'Obh2', 'h', 'w', 'wa'],
                diag1d_kwargs={'colors':['black', 'red','blue','black', 'yellow'], 
                               'alphas':[1.0,1.0,1.0]},
                colors=['black', 'red','blue',  'black', 'yellow'],
                legend_labels=['31 original cc ', '50 synthetic cc from FFNN',
                               '50 synthetic data points from FFNN+dropout'],
                legend_loc='upper right',
                filled = False,
                normalized=False, shaded=False)
        
#plt.show()
plt.savefig('TriangleLCDMHz+Planck', dpi=100)

# %%
#g.settings.axes_fontsize = 5
g.settings.lab_fontsize = 20
g.settings.x_label_rotation= 45
g.settings.legend_fontsize = 10
g.settings.axes_fontsize = 15  

g.triangle_plot(roots_HD_planck, ['w', 'wa'],
                diag1d_kwargs={'colors':['black', 'red','blue','black', 'yellow'], 
                               'alphas':[1.0,1.0,1.0]},
                colors=['black', 'red','blue',  'black', 'yellow'],

                legend_labels=['22 original data points ', '50 synthetic data points from FFNN',
                               '50 synthetic data points from FFNN+dropout'],
                legend_loc='upper right',
                filled = False)
# plt.savefig('TriangleowaCDMfs8_b.png', dpi=50)

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})

gg.settings.lab_fontsize = 25
gg.settings.x_label_rotation= 45
gg.settings.legend_fontsize = 25
gg.settings.axes_fontsize = 25 

# plt.figure(figsize=(10,8))
gg.plot_2d(roots_HD, 'w', 'wa', colors=['black', 'red'], 
          filled=True, alphas = [0.8, 0.7, 0.6], 
          legend_loc='upper right')
gg.add_legend(['Original', 'FFNN',
                               'FFNN+MC-DO'])

gg.add_x_marker(-1, color='green', lw=3.0)
gg.add_y_marker(0, color='green', lw=3.0)
plt.text(-2.2, -2.7, 'Datasets: CC', fontsize=25)
plt.text(-2.2, -2.2, 'CPL', fontsize=25)

plt.savefig('postHDwowa.png')

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})

gg.settings.lab_fontsize = 25
gg.settings.x_label_rotation= 45
gg.settings.legend_fontsize = 25
gg.settings.axes_fontsize = 25 

# plt.figure(figsize=(10,8))
gg.plot_2d(roots_HD, 'h', 'w', colors=['black', 'red'], 
          filled=True, alphas = [0.8, 0.7, 0.6], 
          legend_loc='upper right')
gg.add_legend(['Original ', 'FFNN',
                               'FFNN+MC-DO'])

# gg.add_x_marker(-1, color='green', lw=3.0)
# gg.add_y_marker(0, color='green', lw=3.0)
plt.text(0.45, -2, 'CPL', fontsize=25)
plt.text(0.45, -2.2, 'Datasets: CC', fontsize=25)

plt.savefig('postHDhwo.png')

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})

# plt.figure(figsize=(10,8))
gg.settings.lab_fontsize = 25
gg.settings.x_label_rotation= 45
gg.settings.legend_fontsize = 25
gg.settings.axes_fontsize = 25
gg.plot_2d(roots_HD_planck, 'w', 'wa', colors=['black', 'red'], 
          filled=True, alphas = [0.8, 0.7, 0.6], 
          legend_loc='upper right')
gg.add_legend(['Original ', 'FFNN',
                               'FFNN+MC-DO'])

gg.add_x_marker(-1, color='green', lw=3.0)
gg.add_y_marker(0, color='green', lw=3.0)
plt.text(-2, -2, 'CPL', fontsize=25)
plt.text(-2, -2.3, 'Datasets: CC', fontsize=25)
plt.savefig('postHDplanckwowa.png')

# %% [markdown]
# # $f_{\sigma_8}$ data

# %%
g= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
#g.settings.axes_fontsize = 5
g.settings.lab_fontsize = 15
g.settings.x_label_rotation= 45
#g.settings.alpha_filled_add = 0.9
g.settings.legend_fontsize = 12
g.settings.axes_fontsize = 12     
# g.settings.lw1 = 0.5

# g.triangle_plot(roots_fs8, ['Om', 'Obh2', 'h', 'w', 'wa'],
g.triangle_plot(roots_fs8, ['h', 'w', 'wa', 's8'], 
                diag1d_kwargs={'colors':['black', 'red','blue','black', 'yellow'], 
                               'alphas':[0.6,0.6,0.6]},
                colors=['black', 'red','blue',  'black', 'yellow'],
                alphas = [0.6, 0.5, 0.4],
                legend_labels=['22 original data points', '50 synthetic data points from FFNN',
                               '50 synthetic data points from FFNN+dropout'],
#                 legend_labels=['31 original data points ', '31 synthetic data points from AE+FFNN',
#                                '31 synthetic data points from AE+FFNN+dropout'],
                legend_loc='upper right',
                filled = True,
                normalized=False, shaded=False)
        
#plt.show()
plt.savefig('Trianglefs8_filled', dpi=50)

# %%
plt.figure(figsize=(10, 10), dpi=100)

g2= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
g2.settings.lab_fontsize = 25
g2.settings.legend_fontsize = 25
g2.settings.axes_fontsize = 25  

g2.plot_2d(roots_fs8, 's8', 'wa', colors=['black', 'red'], filled=True, 
           alphas = [0.6, 0.5, 0.4], 
          legend_loc='upper right')

g2.add_legend(['Original', 'FFNN',
                               'FFNN+MC-DO'])


# g2.add_x_marker(-1, color='green', lw=3.0)
# g2.add_y_marker(0, color='green', lw=3.0)
plt.text(0.55, -1.9, 'CPL', fontsize=25)
plt.text(0.9, -1.9, 'Datasets: $f_{\sigma_8}$', fontsize=25)


plt.savefig('postFS8s8wa.png')

# %%
plt.figure(figsize=(10, 10), dpi=100)

g2= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
g2.settings.lab_fontsize = 25
g2.settings.legend_fontsize = 25
g2.settings.axes_fontsize = 25    

g2.plot_2d(roots_fs8, 'w', 'wa', colors=['black', 'red'], filled=True, 
           alphas = [0.6, 0.5, 0.4], 
          legend_loc='upper right')

g2.add_legend(['Original', 'FFNN',
                               'FFNN+MC-DO'])


g2.add_x_marker(-1, color='green', lw=3.0)
g2.add_y_marker(0, color='green', lw=3.0)
plt.text(-1.5, -1.5, 'CPL', fontsize=25)
plt.text(-1.5, -1.9, 'Datasets: $f_{\sigma_8}$', fontsize=25)


plt.savefig('postFS8wowa.png')

# %%
roots_fs8_lcdm = [
          'LCDM_phy_fs8_nested_dynesty_multi',
          'LCDM_phy_fs8_nested_dynesty_multi_new',
          'LCDM_phy_fs8_nested_dynesty_multi_new_new',
          ]

g2= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
g2.settings.lab_fontsize = 20
g2.settings.legend_fontsize = 18
g2.settings.axes_fontsize = 20    

g2.plot_2d(roots_fs8_lcdm, 'h', 's8', colors=['black', 'red'], filled=True, 
           alphas = [0.8, 0.5, 0.5], 
           legend_loc='upper right')

g2.add_legend(['Original $f_{\sigma_8}$ data', 'From FFNN',
                               'From FFNN+MC-DO'])


g2.add_x_marker(-1, color='green', lw=3.0)
g2.add_y_marker(0, color='green', lw=3.0)
plt.text(0.2, 0.2, '$\Lambda$CDM', fontsize=20)

plt.savefig('postFS8hs8.png')

# %%
plt.figure(figsize=(10, 10), dpi=100)

g2= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
g2.settings.lab_fontsize = 25
g2.settings.legend_fontsize = 25
g2.settings.axes_fontsize = 25  

g2.plot_2d(roots_fs8_planck, 'w', 'wa', colors=['black', 'red'], filled=True, 
           alphas = [0.6, 0.5, 0.4], 
          legend_loc='upper right')

g2.add_legend(['Original', 'FFNN',
                               'FFNN+MC-DO'])

g2.add_x_marker(-1, color='green', lw=3.0)
g2.add_y_marker(0, color='green', lw=3.0)
plt.text(-1.41, -1, 'CPL', fontsize=25)
plt.text(-1.41, -1.2, 'Datasets: $f_{\sigma_8}$', fontsize=25)
plt.savefig('postFS8planckwowa.png')

# %%
g2= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
g2.settings.lab_fontsize = 20
g2.settings.legend_fontsize = 18
g2.settings.axes_fontsize = 20    

g2.plot_1d(roots_fs8, 's8', param_renames={'s8':'s'},
           colors=['black', 'red'], filled=True, 
           alphas = [0.6, 0.5, 0.4], 
           legend_loc='upper right')

g2.add_legend(['Original $f_{\sigma_8}$ data', 'From FFNN',
                               'From FFNN+MC-DO'])

# g2.add_x_marker(-1, color='green', lw=3.0)
# g2.add_y_marker(0, color='green', lw=3.0)
plt.savefig('s8.png', dpi=50)

# %% [markdown]
# # JLA SN-type Ia

# %%
g = plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
#g.settings.axes_fontsize = 5

g2.settings.lab_fontsize = 20
g2.settings.legend_fontsize = 12
g2.settings.axes_fontsize = 20  
# g.settings.lw1 = 0.5

g.triangle_plot(roots_SN, ['Om', 'Obh2', 'h', 'w', 'wa'],
# g.triangle_plot(roots_SN, ['Om', 'Obh2', 'h'],
                diag1d_kwargs={'colors':['black', 'red','blue','black', 'yellow'], 
                               'alphas':[1.0,1.0,1.0]},
                colors=['black', 'red','blue',  'black', 'yellow'],
#                 alphas = [1.0, 0.7, 0.5],
                legend_labels=['original', 'FFNN+AE', 'FFNN+AE+DO'],
#                 legend_labels=['31 original data points ', '31 synthetic data points from AE+FFNN',
#                                '31 synthetic data points from AE+FFNN+dropout'],
                legend_loc='upper right',
                filled = False,
                normalized=False, shaded=False)
        
#plt.show()
plt.savefig('TriangleJLA', dpi=50)

# %%
g = plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
#g.settings.axes_fontsize = 5
g.settings.lab_fontsize = 15
g.settings.x_label_rotation= 45
#g.settings.alpha_filled_add = 0.9
g.settings.legend_fontsize = 12
g.settings.axes_fontsize = 12     
# g.settings.lw1 = 0.5

g.triangle_plot(roots_SN, ['w', 'wa'],
# g.triangle_plot(roots_SN, ['Om', 'Obh2', 'h'],
                diag1d_kwargs={'colors':['black', 'red','blue','black', 'yellow'], 
                               'alphas':[1.0,1.0,1.0]},
                colors=['black', 'red','blue',  'black', 'yellow'],
#                 alphas = [0.5, 0.5, 0.5],
                legend_labels=['31 JLA data points', '31 synthetic data points from FFNN+AE',
                               '31 synthetic data points from FFNN+AE+dropout'],
#                 legend_labels=['31 original data points ', '31 synthetic data points from AE+FFNN',
#                                '31 synthetic data points from AE+FFNN+dropout'],
                legend_loc='upper right',
                filled = False,
                normalized=False, shaded=False)

# plt.savefig('TriangleJLA', dpi=50)

# %%
g = plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
plt.figure(figsize=(10,8))
g.plot_1d(roots_SN, 'w', colors=['black', 'red'], filled=False, alphas = [1, 1, 1], 
          legend_loc='upper right')
g.add_x_marker(-1, color='green', lw=3.0)
g.add_legend(['31 original ', '31 synthetic data points from AE+FFNN',
                               '31 synthetic cc from AE+FFNN+dropout'])

# %%
g = plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
plt.figure(figsize=(10,8))
g.plot_1d(roots_SN, 'wa', colors=['black', 'red'], filled=False, alphas = [1, 1, 1], 
          legend_loc='upper right')
g.add_x_marker(0, color='green', lw=3.0)

g.add_legend(['31 original ', '31 synthetic data points from AE+FFNN',
                               '31 synthetic cc from AE+FFNN+dropout'])

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})

# gg.settings.lab_fontsize = 18
gg.settings.x_label_rotation= 45
gg.settings.lab_fontsize = 25
gg.settings.legend_fontsize = 20
gg.settings.axes_fontsize = 25  

# plt.figure(figsize=(10,8))
gg.plot_2d(roots_SN, 'w', 'wa', colors=['black', 'red'], 
          filled=True, alphas = [0.5,0.5,0.5],
          legend_loc='upper right')

gg.add_legend(['Original', 'FFNN+AE','FFNN+AE+MC-DO'])

gg.add_x_marker(-1, color='green', lw=3.0, label="$\Lambda CDM$")
gg.add_y_marker(0, color='green', lw=3.0)
plt.text(-2.2, -2, 'CPL', fontsize=25)
plt.text(-2.2, -2.3, 'Datasets: JLA', fontsize=25)

plt.savefig('postJLAwowa.png')

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})

# gg.settings.lab_fontsize = 18
gg.settings.x_label_rotation= 45
gg.settings.lab_fontsize = 25
gg.settings.legend_fontsize = 25
gg.settings.axes_fontsize = 25    



# plt.figure(figsize=(10,8))
gg.plot_2d(roots_SN_planck, 'w', 'wa', colors=['black', 'red'], 
           filled=True, alphas = [0.5,0.5,0.5],
           legend_loc='upper right')
gg.add_legend(['Original', 'FFNN+AE',
                               'FFNN+AE+MC-DO'])

gg.add_x_marker(-1, color='green', lw=3.0, label="$\Lambda CDM$")
gg.add_y_marker(0, color='green', lw=3.0)
plt.text(-1.6, -2, 'CPL', fontsize=25)
plt.text(-1.6, -2.3, 'JLA + Planck point', fontsize=25)

plt.savefig('postJLAplanckwowa.png')

# %% [markdown]
# ## MIX OF ALL

# %%
g = plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
#g.settings.axes_fontsize = 5
g.settings.lab_fontsize = 15
g.settings.x_label_rotation= 45
#g.settings.alpha_filled_add = 0.9
g.settings.legend_fontsize = 15
g.settings.axes_fontsize = 15   
# g.settings.lw1 = 0.5

g.triangle_plot(roots_all, ['Om', 'Obh2', 'h', 'w', 'wa', 's8'],
# g.triangle_plot(roots_SN, ['Om', 'Obh2', 'h'],
                diag1d_kwargs={'colors':['black', 'red','blue','black', 'yellow'], 
                               'alphas':[1.0,1.0,1.0]},
                colors=['black', 'red','blue',  'black', 'yellow'],
#                 alphas = [1.0, 0.7, 0.5],
                legend_labels=['Real JLA+fs8+CC', 'Synthetic JLA+fs8+CC from FFNN+AE',
                               'Synthetic JLA+fs8+CC FFNN+AE+MC-DO'],
#                 legend_labels=['31 original data points ', '31 synthetic data points from AE+FFNN',
#                                '31 synthetic data points from AE+FFNN+dropout'],
                legend_loc='upper right',
                filled = False,
                normalized=False, shaded=False)
plt.savefig('TriangleALL')

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})

# plt.figure(figsize=(10,8))
gg.settings.lab_fontsize = 25
gg.settings.legend_fontsize = 21
gg.settings.axes_fontsize = 25  
gg.plot_2d(roots_all, 'w', 'wa', colors=['black', 'red'], 
          filled=True, alphas = [0.8, 0.6, 0.4], 
          legend_loc='lower left')

gg.add_legend(['Original', 'FFNN+AE',
                               'FFNN+AE+MC-DO'])

gg.add_x_marker(-1, color='green', lw=3.0, label="$\Lambda CDM$")
gg.add_y_marker(0, color='green', lw=3.0)

plt.text(-0.9, -1.5, 'CPL', fontsize=25)
plt.text(-0.9, -1.7, 'Datasets: CC+fs8+JLA', fontsize=25)


# plt.legend()
plt.savefig('postALLwowa.png')

# %%
plt.figure(figsize=(10, 10), dpi=100)

g2= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
g2.settings.lab_fontsize = 25
g2.settings.legend_fontsize = 25
g2.settings.axes_fontsize = 25   

g2.plot_2d(roots_all, 'h', 'w', colors=['black', 'red'], filled=True, 
           alphas = [0.6, 0.5, 0.4], 
          legend_loc='upper right')

g2.add_legend(['Original', 'FFNN+AE',
                               'FFNN+AE+MC-DO'])

g2.add_x_marker(-1, color='green', lw=3.0)
g2.add_y_marker(0, color='green', lw=3.0)

plt.text(0.55, -1.2, 'Datasets: CC+fs8+JLA', fontsize=25)
plt.text(0.55, -1.1, 'CPL', fontsize=25)



plt.savefig('postALLwoh.png')

# %% [markdown]
# ## MIX OF ALL + Planck

# %%
g = plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
#g.settings.axes_fontsize = 5
g.settings.lab_fontsize = 15
g.settings.x_label_rotation= 45
#g.settings.alpha_filled_add = 0.9
g.settings.legend_fontsize = 12
g.settings.axes_fontsize = 12     
# g.settings.lw1 = 0.5

g.triangle_plot(roots_all_planck, ['Om', 'Obh2', 'h', 'w', 'wa', 's8'],
# g.triangle_plot(roots_SN, ['Om', 'Obh2', 'h'],
                diag1d_kwargs={'colors':['black', 'red','blue','black', 'yellow'], 
                               'alphas':[1.0,1.0,1.0]},
                colors=['black', 'red','blue',  'black', 'yellow'],
#                 alphas = [1.0, 0.7, 0.5],
                legend_labels=['Real JLA+$f_{\sigma_8}$+CC', 'Synthetic JLA+$f_{\sigma_8}$+CC from FFNN+AE',
                               'Synthetic JLA+$f_{\sigma_8}$+CC FFNN+AE+MC-DO'],
#                 legend_labels=['31 original data points ', '31 synthetic data points from AE+FFNN',
#                                '31 synthetic data points from AE+FFNN+dropout'],
                legend_loc='upper right',
                filled = False,
                normalized=False, shaded=False)
plt.savefig('TriangleALL_planck', dpi=50)

# %%
plt.figure(figsize=(10, 10), dpi=100)

g2= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
g2.settings.lab_fontsize = 25
g2.settings.legend_fontsize = 22
g2.settings.axes_fontsize = 25    

g2.plot_2d(roots_all_planck, 'h', 'w', colors=['black', 'red'], filled=True, 
           alphas = [0.6, 0.5, 0.4], 
          legend_loc='upper right')

g2.add_legend(['Original', 'FFNN+AE',
                               'FFNN+AE+MC-DO'])

g2.add_x_marker(-1, color='green', lw=3.0)
g2.add_y_marker(0, color='green', lw=3.0)

plt.text(0.601, -1.06, 'Datasets: CC+fs8+JLA', fontsize=24)
plt.text(0.601, -1.11, '          + Planck point', fontsize=24)

plt.text(0.601, -1, 'CPL', fontsize=25)

# plt.legend()
plt.savefig('postALLplanckwoh.png')

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})

# plt.figure(figsize=(10,8))
gg.settings.lab_fontsize = 25
gg.settings.legend_fontsize = 22
gg.settings.axes_fontsize = 25  
gg.plot_2d(roots_all_planck, 'w', 'wa', colors=['black', 'red'], 
          filled=True, alphas = [0.8, 0.6, 0.4], 
          legend_loc='upper right')
gg.add_legend(['Original', 'FFNN+AE',
                               'FFNN+AE+MC-DO'])

gg.add_x_marker(-1, color='green', lw=3.0, label="$\Lambda CDM$")
gg.add_y_marker(0, color='green', lw=3.0)

plt.text(-1.14,-1.1, 'CPL', fontsize=25)
plt.text(-1.14,-1.2, 'Datasets: CC+fs8+JLA', fontsize=25)
plt.text(-1.14,-1.3, '          + Planck point', fontsize=25)

plt.savefig('postALLplanckwowa.png')

# %% [markdown]
# # JLA+CC

# %%
plt.figure(figsize=(10, 10), dpi=100)
gg= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})

# plt.figure(figsize=(10,8))
gg.settings.lab_fontsize = 25
gg.settings.legend_fontsize = 22
gg.settings.axes_fontsize = 25 
gg.plot_2d(roots_cc_sn, 'w', 'wa', colors=['black', 'red'], 
          filled=True, alphas = [0.8, 0.6, 0.4], 
          legend_loc='upper right')
gg.add_legend(['Original', 'FFNN+AE',
                        'FFNN+AE+MC-DO'])

gg.add_x_marker(-1, color='green', lw=3.0, label="$\Lambda CDM$")
gg.add_y_marker(0, color='green', lw=3.0)
plt.text(-1.9,-2,'CPL', fontsize=25)
plt.text(-1.9,-2.3,'Datasets: CC+JLA', fontsize=25)

plt.savefig('postHDJLAwowa.png')

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})

# plt.figure(figsize=(10,8))
gg.settings.lab_fontsize = 25
gg.settings.legend_fontsize = 25
gg.settings.axes_fontsize = 25 
gg.plot_2d(roots_cc_sn_planck, 'w', 'wa', colors=['black', 'red'], 
          filled=True, alphas = [0.8, 0.6, 0.4], 
          legend_loc='upper right')
gg.add_legend(['Original', 'FFNN+AE',
                               'FFNN+AE+MC-DO'])

gg.add_x_marker(-1, color='green', lw=3.0, label="$\Lambda CDM$")
gg.add_y_marker(0, color='green', lw=3.0)

plt.text(-1.55, -1.6, 'CPL', fontsize=25)
plt.text(-1.55, -1.9, 'Datasets: CC+JLA', fontsize=25)
plt.text(-1.55, -2.2, '       + Planck point', fontsize=25)


plt.savefig('postHDJLAplanckwowa.png')

# %%
import fgivenx
from fgivenx import plot_contours, samples_from_getdist_chains

# %%
def eos(z, params):
    w0, wa = params
    return w0 + (z/(1+z))*wa

# %%
cmap_reversed = matplotlib.cm.get_cmap('Greens_r')

# %%
# k = np.logspace(-4,1,100)
file_root = dir_name + 'waCDM_phy_SN+HD+fs8_nested_dynesty_multi'
samples, weights = samples_from_getdist_chains(['w', 'wa'], file_root)
k = np.linspace(0,2,100)
cbar = plot_contours(eos, k, samples, weights=weights, colors=cmap_reversed)
cbar = plt.colorbar(cbar,ticks=[0,1,2,3])
cbar.set_ticklabels(['',r'$1\sigma$',r'$2\sigma$',r'$3\sigma$'])
plt.hlines(-1, xmin=0, xmax=2, colors='r',  linestyles='dashed', label='$\omega=-1$')
# plt.xscale('log')
plt.ylim(-2., -0.1)
plt.ylabel(r'$\omega(z)$')
plt.xlabel(r'$z$')
plt.tight_layout()
plt.legend()
plt.savefig('cplEoS.png')
# Out:
# WARNING:root:outlier fraction 0.15463165572574764
# /home/isidro/SimpleMC/chains/waCDM_phy_SN+HD+fs8_nested_dynesty_multi_1.txt
# Removed no burn in
# ...

# %%
file_root = dir_name + 'waCDM_phy_SN+HD+fs8_nested_dynesty_multi_new'
samples, weights = samples_from_getdist_chains(['w', 'wa'], file_root)
k = np.linspace(0,2,100)
cbar = plot_contours(eos, k, samples, weights=weights, colors=cmap_reversed)
cbar = plt.colorbar(cbar,ticks=[0,1,2,3])
cbar.set_ticklabels(['',r'$1\sigma$',r'$2\sigma$',r'$3\sigma$'])

# plt.xscale('log')
plt.ylim(-2., -0.1)
plt.ylabel(r'$\omega(z)$')

plt.xlabel(r'$z$')
plt.hlines(-1, xmin=0, xmax=2, colors='r',  linestyles='dashed', label='$\omega=-1$')
plt.tight_layout()
plt.legend()

plt.savefig('cplEoS_ann.png')
# Out:
# WARNING:root:outlier fraction 0.15486725663716813
# /home/isidro/SimpleMC/chains/waCDM_phy_SN+HD+fs8_nested_dynesty_multi_new_1.txt
# Removed no burn in
# ...

# %%
file_root = dir_name + 'waCDM_phy_SN+HD+fs8_nested_dynesty_multi_new_new_new'
samples, weights = samples_from_getdist_chains(['w', 'wa'], file_root)
k = np.linspace(0,2,100)
cbar = plot_contours(eos, k, samples, weights=weights, colors=cmap_reversed)
cbar = plt.colorbar(cbar,ticks=[0,1,2,3])
cbar.set_ticklabels(['',r'$1\sigma$',r'$2\sigma$',r'$3\sigma$'])
plt.hlines(-1, xmin=0, xmax=2, colors='r',  linestyles='dashed', label='$\omega=-1$')
# plt.xscale('log')
plt.legend()
plt.ylim(-2., -0.1)
plt.ylabel(r'$\omega(z)$')
plt.xlabel(r'$z$')
plt.tight_layout()
plt.savefig('cplEoS_ann_do.png')
# Out:
# WARNING:root:outlier fraction 0.18524212144504226
# /home/isidro/SimpleMC/chains/waCDM_phy_SN+HD+fs8_nested_dynesty_multi_new_new_new_1.txt
# Removed no burn in
# ...

# %% [markdown]
# ## POLYCDM

# %%
# plt.figure(figsize=(10, 10), dpi=100)

g= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
#g.settings.axes_fontsize = 5
g.settings.lab_fontsize = 15
g.settings.x_label_rotation= 45
#g.settings.alpha_filled_add = 0.9
g.settings.legend_fontsize = 15
g.settings.axes_fontsize = 15   
# g.settings.lw1 = 0.5

g.triangle_plot(roots_polycdm, ['Om', 'Obh2', 'h', 's8', 'Om1', 'Om2'],
# g.triangle_plot(roots, ['Om', 'Obh2', 'h'],
                diag1d_kwargs={'colors':['black', 'red','blue','black', 'yellow'], 
                               'alphas':[1.0,1.0,1.0]},
                colors=['black', 'red','blue',  'black', 'yellow'],
#                 alphas = [1.0, 0.7, 0.5],
                legend_labels=['31 original cc ', '50 synthetic cc from FFNN',
                               '50 synthetic data points from FFNN+MC dropout'],
#                 legend_labels=['31 original data points ', '31 synthetic data points from AE+FFNN',
#                                '31 synthetic data points from AE+FFNN+dropout'],
                legend_loc='upper right',
                filled = False,
                normalized=False, shaded=False)
        
#plt.show()
plt.savefig('Trianglewapolycdm', dpi=100)

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})

# plt.figure(figsize=(10,8))
gg.settings.lab_fontsize = 25
gg.settings.legend_fontsize = 25
gg.settings.axes_fontsize = 25  
gg.plot_2d(roots_polycdm, 'Om1', 'Om2', colors=['black', 'red'], 
          filled=True, alphas = [0.8, 0.6, 0.4], 
          legend_loc='upper right')
gg.add_legend(['Original', 'FFNN+AE',
                               'FFNN+AE+MC-DO'])

gg.add_x_marker(0, color='green', lw=3.0, label="$\Lambda CDM$")
gg.add_y_marker(0, color='green', lw=3.0)

plt.text(-1.39, -0.4, 'polyCDM', fontsize=25)
plt.text(-1.39, -0.6, 'Datasets: CC+fs8+JLA', fontsize=25)

plt.savefig('postpolycdm1.png')

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})

# plt.figure(figsize=(10,8))
gg.settings.lab_fontsize = 25
gg.settings.legend_fontsize = 21
gg.settings.axes_fontsize = 25  
gg.plot_2d(roots_polycdm, 'h', 'Om2', colors=['black', 'red'], 
          filled=True, alphas = [0.8, 0.6, 0.4], 
          legend_loc='upper right')
gg.add_legend(['Original', 'FFNN+AE',
                               'FFNN+AE+MC-DO'])

gg.add_x_marker(0, color='green', lw=3.0, label="$\Lambda CDM$")
gg.add_y_marker(0, color='green', lw=3.0)
plt.text(0.53, -0.6, 'Datasets:', fontsize=25 )
plt.text(0.53, -0.71, 'CC+fs8+JLA', fontsize=25)
plt.text(0.53, 1.1, 'polyCDM', fontsize=25)

plt.savefig('postpolycdm2.png')
