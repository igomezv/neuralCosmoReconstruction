# %%
import matplotlib.pyplot as plt
from getdist import plots, MCSamples
from getdist import *

# import planckStyle
import pylab
import numpy as np
import matplotlib
import tkinter

matplotlib.use('TkAgg')


# %matplotlib inline

# %% [markdown]
# ## Using CPL
#
# $ \frac{H(z)^2}{H_0^2} = \Omega_{m,0}(1+z)^3 + (1-\Omega_{m,0})(1+z)^{3(1+\omega_0+\omega_a)} e^{-\frac{3\omega_a z}{1+z}}$
#
# #### Defining file names for MCMC chains for posterior pdf sampling

# %%
# dir_name = '/home/isidro/Documents/gitHub/simplemc_tests/chains/'
dir_name = "/home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/"

dir_name_sn = dir_name + 'SN/'
dir_name_sn_planck = dir_name + 'SN+Planck/'
dir_name_cc = dir_name + 'HD/'
dir_name_cc_planck = dir_name + 'HD+Planck/'
dir_name_fs8 = dir_name + 'fs8/'
dir_name_fs8_planck = dir_name + 'fs8+Planck/'
dir_name_cc_sn = dir_name + 'SN+HD/'
dir_name_cc_sn_planck = dir_name + 'SN+HD+Planck/'
dir_name_all = dir_name + 'SN+HD+fs8/'
dir_name_all_planck = dir_name + 'SN+HD+fs8+Planck/'
dir_name_poly = dir_name + 'polyCDM/'
dir_name_poly_planck = dir_name + 'polycdm+planck/'


roots_fs8_planck = [
          'waCDM_phy_fs8+Planck_nested_dynesty_multi',
          'waCDM_phy_fs8+Planck_nested_dynesty_multi_new',
          'waCDM_phy_fs8+Planck_nested_dynesty_multi_new_new']

roots_fs8 = [
          'waCDM_phy_fs8_nested_dynesty_multi',
          'waCDM_phy_fs8_nested_dynesty_multi_new',
          'waCDM_phy_fs8_nested_dynesty_multi_new_new']


roots_HD = [
          'waCDM_phy_HD_nested_dynesty_multi',
          'waCDM_phy_HD_nested_dynesty_multi_new',
          'waCDM_phy_HD_nested_dynesty_multi_new_new']

roots_HD_planck = [
                  'waCDM_phy_HD+Planck_nested_dynesty_multi',
                  'waCDM_phy_HD+Planck_nested_dynesty_multi_new',
                   'waCDM_phy_HD+Planck_nested_dynesty_multi_new_new'
                   ]

roots_SN = [
            'waCDM_phy_SN_nested_dynesty_multi',
            'waCDM_phy_SN_nested_dynesty_multi_new',
            'waCDM_phy_SN_nested_dynesty_multi_new_new'
            ]


roots_SN_planck = [
                  'waCDM_phy_SN+Planck_nested_dynesty_multi',
                  'waCDM_phy_SN+Planck_nested_dynesty_multi_new',
                  'waCDM_phy_SN+Planck_nested_dynesty_multi_new_new',]

roots_cc_sn = [
                  'waCDM_phy_SN+HD_nested_dynesty_multi',
                  'waCDM_phy_SN+HD_nested_dynesty_multi_new',
                  'waCDM_phy_SN+HD_nested_dynesty_multi_new_new']

roots_cc_sn_planck = [
                      'waCDM_phy_SN+HD+Planck_nested_dynesty_multi',
                      'waCDM_phy_SN+HD+Planck_nested_dynesty_multi_new',
                      'waCDM_phy_SN+HD+Planck_nested_dynesty_multi_new_new']

roots_all = [
                  'waCDM_phy_SN+HD+fs8_nested_dynesty_multi',
                  'waCDM_phy_SN+HD+fs8_nested_dynesty_multi_new',
                  'waCDM_phy_SN+HD+fs8_nested_dynesty_multi_new_new']#_new
#                   'waCDM_phy_SN+HD+fs8_nested_dynesty_multi_new_new_new']


roots_all_planck = [
                  'waCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi',
                  'waCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi_new',
                  'waCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi_new_new_new']

roots_polycdm = [
                'PolyCDM_phy_SN+HD+fs8_nested_dynesty_multi',
                'PolyCDM_phy_SN+HD+fs8_nested_dynesty_multi_new',
                'PolyCDM_phy_SN+HD+fs8_nested_dynesty_multi_new_new'
                ]

roots_polycdm_planck = [
                'PolyCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi',
                'PolyCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi_new',
                'PolyCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi_new_new'
                ]

color_list = ['purple', 'orange', 'green']

# %% [markdown]
# # Cosmic chronometers
#
# ### Only HD data

# %%
g = plots.getSinglePlotter(chain_dir = dir_name_cc, width_inch= 10,
                          ratio = 0.9, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})

# %% [markdown]
# ### Full triangle plot

# %%
#g.settings.axes_fontsize = 5
g.settings.lab_fontsize = 15
g.settings.x_label_rotation= 45
#g.settings.alpha_filled_add = 0.9
g.settings.legend_fontsize = 15
g.settings.axes_fontsize = 15   
# g.settings.lw1 = 0.5

g.triangle_plot(roots_HD, ['Om', 'Obh2', 'h', 'w', 'wa'],
# g.triangle_plot(roots, ['Om', 'Obh2', 'h'],
                diag1d_kwargs={'colors':['black', 'red','blue','black', 'yellow'], 
                               'alphas':[1.0,1.0,1.0]},
                colors=['black', 'red','blue',  'black', 'yellow'],
#                 alphas = [1.0, 0.7, 0.5],
                legend_labels=['31 original cc ', '50 synthetic cc from FFNN',
                               '50 synthetic data points from FFNN+MC dropout'],
#                 legend_labels=['31 original data points ', '31 synthetic data points from AE+FFNN',
#                                '31 synthetic data points from AE+FFNN+dropout'],
                legend_loc='upper right',
                filled = False,
                normalized=False, shaded=False)
        
#plt.show()
#plt.savefig('TrianglewaCDMHz', dpi=80)

# %% [markdown]
# ### Posteriors pdf for only $\omega_0$ and $\omega_a$ :

# %%
#g.settings.axes_fontsize = 5
g.settings.lab_fontsize = 20
g.settings.x_label_rotation= 45
g.settings.legend_fontsize = 20
g.settings.axes_fontsize = 20

g.triangle_plot(roots_HD, ['w', 'wa'],
# g.triangle_plot(roots, ['Om', 'Obh2', 'h'],
                diag1d_kwargs={'colors':['black', 'yellow','blue','red', 'yellow'], 
                               'alphas':[1.0,1.0,1.0]},
                colors=['black', 'yellow','blue',  'red', 'yellow'],
#                 alphas = [1.0, 0.7, 0.5],

                legend_labels=['original data points ', 'points from FFNN',
                               'points from FFNN+dropout'],
                legend_loc='upper right',
                filled = False)
# plt.savefig('TriangleowaCDMfs8_b.png', dpi=50)

# %% [markdown]
# ### HD + Planck point

# %%
g = plots.getSinglePlotter(chain_dir = dir_name_cc_planck, width_inch= 10,
                          ratio = 0.9, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})

g.settings.lab_fontsize = 20
g.settings.x_label_rotation= 45
g.settings.legend_fontsize = 12
g.settings.axes_fontsize = 20     

g.triangle_plot(roots_HD_planck, ['Om', 'Obh2', 'h', 'w', 'wa'],
                diag1d_kwargs={'colors':['black', 'red','blue','black', 'yellow'], 
                               'alphas':[1.0,1.0,1.0]},
                colors=['black', 'red','blue',  'black', 'yellow'],
                legend_labels=['31 original cc ', '50 synthetic cc from FFNN',
                               '50 synthetic data points from FFNN+dropout'],
                legend_loc='upper right',
                filled = False,
                normalized=False, shaded=False)
        
#plt.show()
# plt.savefig('TriangleLCDMHz+Planck', dpi=100)

# %%
#g.settings.axes_fontsize = 5
g.settings.lab_fontsize = 20
g.settings.x_label_rotation= 45
g.settings.legend_fontsize = 10
g.settings.axes_fontsize = 15  

g.triangle_plot(roots_HD_planck, ['w', 'wa'],
                diag1d_kwargs={'colors':['black', 'red','blue','black', 'yellow'], 
                               'alphas':[1.0,1.0,1.0]},
                colors=['black', 'red','blue',  'black', 'yellow'],

                legend_labels=['22 original data points ', '50 synthetic data points from FFNN',
                               '50 synthetic data points from FFNN+dropout'],
                legend_loc='upper right',
                filled = False)
# plt.savefig('TriangleowaCDMfs8_b.png', dpi=50)

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name_cc, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})

gg.settings.lab_fontsize = 25
gg.settings.x_label_rotation= 45
gg.settings.legend_fontsize = 24
gg.settings.axes_fontsize = 25 

# plt.figure(figsize=(10,8))
# color_list = [[(84/255, 99/255, 255/255)], [(255/255, 195/255, 0)], [(1, 24/255, 24/255)]]

gg.plot_2d(roots_HD, 'w', 'wa', colors=color_list, 
          filled=True, alphas = [1, 1,0.8], 
          legend_loc='upper right')
gg.add_legend(['Original', 'FFNN', 'FFNN+MC-DO'])

gg.add_x_marker(-1, color='red', lw=3.0)
gg.add_y_marker(0, color='red', lw=3.0)
# plt.grid(True)

plt.ylim(-3.1,3.1)
plt.xlim(-2.5,0.5)
plt.text(-2.2, -2.7, 'Datasets: CC', fontsize=25)
plt.text(-2.2, -2.2, 'CPL', fontsize=25)

plt.savefig('postHDwowa.png')

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name_cc, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})

gg.settings.lab_fontsize = 25
gg.settings.x_label_rotation= 45
gg.settings.legend_fontsize = 25
gg.settings.axes_fontsize = 25 

# plt.figure(figsize=(10,8))
gg.plot_2d(roots_HD[0], 'h', 'w', colors=color_list,
          filled=True, alphas = [0.8, 0.7, 0.6], 
          legend_loc='upper right')
# gg.add_legend(['Original ', 'FFNN',
#                                'FFNN+MC-DO'])

# gg.add_x_marker(-1, color='green', lw=3.0)
gg.add_x_marker(0.7, color='green', lw=3.0, label='Mean')
gg.add_x_marker(0.72, color='red', lw=3.0, label = 'Best fit')
gg.add_y_marker(-1.22, color='green', lw=3.0)
gg.add_y_marker(-1.30, color='red', lw=3.0)
plt.legend()
# best -1.30220 red
# mean -1.22322 green
# plt.text(0.45, -2, 'CPL', fontsize=25)
# plt.text(0.45, -2.2, 'Datasets: CC', fontsize=25)

plt.savefig('postHDhwo.png')

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name_cc_planck, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})

# plt.figure(figsize=(10,8))
gg.settings.lab_fontsize = 25
gg.settings.x_label_rotation= 45
gg.settings.legend_fontsize = 25
gg.settings.axes_fontsize = 25
gg.plot_2d(roots_HD_planck, 'w', 'wa', colors=color_list,
          filled=True, alphas = [0.8, 0.7, 0.6], 
          legend_loc='upper right')
# gg.add_legend(['Original ', 'FFNN',
#                                'FFNN+MC-DO'])

gg.add_x_marker(-1, color='red', lw=3.0)
gg.add_y_marker(0, color='red', lw=3.0)
plt.ylim(-3.1,3.1)
plt.xlim(-2.5,0.5)

plt.text(-2.4, -2.3, 'CPL', fontsize=25)
plt.text(-2.4, -2.6, 'Datasets: CC + Planck', fontsize=25)
plt.savefig('postHDplanckwowa.png')

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name_cc_planck, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})

# plt.figure(figsize=(10,8))
gg.settings.lab_fontsize = 25
gg.settings.x_label_rotation= 45
gg.settings.legend_fontsize = 25
gg.settings.axes_fontsize = 25
gg.plot_2d(roots_HD_planck, 'h', 'w', colors=color_list, 
          filled=True, alphas = [1, 0.9, 0.7], 
          legend_loc='upper right')
# gg.add_legend(['Original ', 'FFNN',
#                                'FFNN+MC-DO'])

gg.add_x_marker(0.7324, color='purple', lw=3.0, ls='dotted')
gg.add_x_marker(0.674, color='black', lw=3.0, ls='dashdot')
gg.add_y_marker(-1, color='red', lw=3.0)


plt.text(0.8, -0.15, '·-·- $H_0 = 67.4$', fontsize=22, color='black')
plt.text(0.8, -0.3, '··· $H_0 = 73.24$', fontsize=22, color='purple')

plt.xlim(0.5, 0.9)
plt.ylim(-2.5,0.5)


plt.text(0.51, -2.0, 'CPL', fontsize=25)
plt.text(0.51, -2.2, 'Datasets: CC + Planck', fontsize=25)
plt.savefig('postHDplanckhwo.png')

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name_cc, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})

# plt.figure(figsize=(10,8))
gg.settings.lab_fontsize = 25
gg.settings.x_label_rotation= 45
gg.settings.legend_fontsize = 25
gg.settings.axes_fontsize = 25
gg.plot_2d(roots_HD, 'h', 'w', colors=color_list, 
          filled=True, alphas = [1, 0.8, 0.6], 
          legend_loc='upper right')
# gg.add_legend(['Original ', 'FFNN',
#                                'FFNN+MC-DO'])

gg.add_x_marker(0.7324, color='purple', lw=3.0, ls='dotted')
gg.add_x_marker(0.674, color='black', lw=3.0, ls='dashdot')
gg.add_y_marker(-1, color='red', lw=3.0)


plt.text(0.8, -0.15, '·-·- $H_0 = 67.4$', fontsize=22, color='black')
plt.text(0.8, -0.3, '··· $H_0 = 73.24$', fontsize=22, color='purple')

plt.xlim(0.5, 0.9)
plt.ylim(-2.5,0.5)

plt.text(0.52, -2, 'CPL', fontsize=25)
plt.text(0.52, -2.2, 'Datasets: CC', fontsize=25)
plt.savefig('postHDhwo.png')

# %%
# w
# -1.20742917
# best -1.20743
# mean -0.86670
# std dev 0.3259
# $-0.867 \pm 0.326$
# ----------------------------------------
# wa
# 0.68890504
# best 0.68891
# mean -0.32456
# std dev 0.8242

plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name_cc_planck, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})

# plt.figure(figsize=(10,8))
gg.settings.lab_fontsize = 25
gg.settings.x_label_rotation= 45
gg.settings.legend_fontsize = 25
gg.settings.axes_fontsize = 25
gg.plot_2d(roots_HD_planck[0], 'w', 'wa', colors=color_list, 
          filled=True, alphas = [1, 0.7, 0.6], 
          legend_loc='upper right')
gg.add_legend(['Original ', 'FFNN',
                               'FFNN+MC-DO'])

gg.add_x_marker( -0.86670, color='green', lw=3.0, label='Mean')
gg.add_y_marker(-0.32456, color='green', lw=3.0)

gg.add_x_marker( -1.20743, color='red', lw=3.0, label='Best fit')
gg.add_y_marker( 0.68891, color='red', lw=3.0)
plt.legend()

plt.ylim(-3.1,3.1)
plt.xlim(-2.5,0.5)

plt.text(-2.35, -2, 'CPL', fontsize=25)
plt.text(-2.35, -2.3, 'Datasets: CC + Planck', fontsize=25)
# Out:
# Text(-2.35, -2.3, 'Datasets: CC + Planck')

# %% [markdown]
# # $f_{\sigma_8}$ data

# %%
g= plots.getSinglePlotter(chain_dir = dir_name_fs8, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
#g.settings.axes_fontsize = 5
g.settings.lab_fontsize = 15
g.settings.x_label_rotation= 45
#g.settings.alpha_filled_add = 0.9
g.settings.legend_fontsize = 12
g.settings.axes_fontsize = 12     
# g.settings.lw1 = 0.5

# g.triangle_plot(roots_fs8, ['Om', 'Obh2', 'h', 'w', 'wa'],
g.triangle_plot(roots_fs8, ['h', 'w', 'wa', 's8'], 
                diag1d_kwargs={'colors':['black', 'red','blue','black', 'yellow'], 
                               'alphas':[0.6,0.6,0.6]},
                colors=['black', 'red','blue',  'black', 'yellow'],
                alphas = [0.6, 0.5, 0.4],
                legend_labels=['22 original data points', '50 synthetic data points from FFNN',
                               '50 synthetic data points from FFNN+dropout'],
#                 legend_labels=['31 original data points ', '31 synthetic data points from AE+FFNN',
#                                '31 synthetic data points from AE+FFNN+dropout'],
                legend_loc='upper right',
                filled = True,
                normalized=False, shaded=False)
        
#plt.show()
plt.savefig('Trianglefs8_filled', dpi=50)
# Out:
# WARNING:root:outlier fraction 0.21444201312910285
# WARNING:root:outlier fraction 0.23542116630669546
# WARNING:root:outlier fraction 0.22950819672131148
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/fs8/waCDM_phy_fs8_nested_dynesty_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/fs8/waCDM_phy_fs8_nested_dynesty_multi_new_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/fs8/waCDM_phy_fs8_nested_dynesty_multi_new_new_1.txt
# Removed 0.1 as burn in

# %%
plt.figure(figsize=(10, 10), dpi=100)

g2= plots.getSinglePlotter(chain_dir = dir_name_fs8, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})
g2.settings.lab_fontsize = 25
g2.settings.legend_fontsize = 25
g2.settings.axes_fontsize = 25  

g2.plot_2d(roots_fs8, 's8', 'wa', colors=color_list, filled=True, 
           alphas = [1, 0.8, 0.7], 
          legend_loc='upper right')

# g2.add_legend(['Original', 'FFNN',
#                                'FFNN+MC-DO'])


g2.add_x_marker(0.8, color='red', lw=3.0)
g2.add_y_marker(0, color='red', lw=3.0)
plt.text(0.55, -1.9, 'CPL', fontsize=25)
plt.text(0.9, -1.9, 'Datasets: $f \sigma_8}$', fontsize=25)
# plt.grid(True)


plt.savefig('postFS8s8wa.png')

# %%
plt.figure(figsize=(10, 10), dpi=100)

g2= plots.getSinglePlotter(chain_dir = dir_name_fs8, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})
g2.settings.lab_fontsize = 25
g2.settings.legend_fontsize = 25
g2.settings.axes_fontsize = 25    

g2.plot_2d(roots_fs8, 'w', 'wa', colors=color_list, filled=True, 
           alphas = [1, 0.9, 0.7],
           legend_loc='upper right')

# g2.add_legend(['Original', 'FFNN',
#                                'FFNN+MC-DO'])


g2.add_x_marker(-1, color='red', lw=3.0)
g2.add_y_marker(0, color='red', lw=3.0)
plt.xlim(-1.6,0.5)
plt.ylim(-2.2,1.5)
plt.text(-1.55, -1.5, 'CPL', fontsize=25)
plt.text(-1.55, -1.9, 'Datasets: $f \sigma_8$', fontsize=25)


plt.savefig('postFS8wowa.png')

# %%
roots_fs8_lcdm = [
          'LCDM_phy_fs8_nested_dynesty_multi',
          'LCDM_phy_fs8_nested_dynesty_multi_new',
          'LCDM_phy_fs8_nested_dynesty_multi_new_new',
          ]

g2= plots.getSinglePlotter(chain_dir = dir_name_fs8, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
g2.settings.lab_fontsize = 20
g2.settings.legend_fontsize = 18
g2.settings.axes_fontsize = 20    

g2.plot_2d(roots_fs8_lcdm, 'h', 's8', colors=color_list, filled=True, 
           alphas = [1, 0.7, 0.7], 
           legend_loc='upper right')

# g2.add_legend(['Original $f \sigma_8$ data', 'From FFNN',
#                                'From FFNN+MC-DO'])


g2.add_x_marker(-1, color='green', lw=3.0)
g2.add_y_marker(0, color='green', lw=3.0)
# plt.text(0.2, 0.2, '$\Lambda$CDM', fontsize=20)

plt.savefig('postFS8hs8.png')
# Out:
# WARNING:root:outlier fraction 0.2187902187902188
# WARNING:root:outlier fraction 0.21215880893300249
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/fs8/LCDM_phy_fs8_nested_dynesty_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/fs8/LCDM_phy_fs8_nested_dynesty_multi_new_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/fs8/LCDM_phy_fs8_nested_dynesty_multi_new_new_1.txt
# WARNING:root:outlier fraction 0.2202970297029703
# Removed 0.1 as burn in

# %%
plt.figure(figsize=(10, 10), dpi=100)

g2= plots.getSinglePlotter(chain_dir = dir_name_fs8_planck, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})
g2.settings.lab_fontsize = 25
g2.settings.legend_fontsize = 25
g2.settings.axes_fontsize = 25  

g2.plot_2d(roots_fs8_planck, 's8', 'wa', colors=color_list, filled=True, 
           alphas = [1, 0.8, 0.8], 
          legend_loc='upper right')

# g2.add_legend(['Original', 'FFNN',
#                                'FFNN+MC-DO'])

g2.add_x_marker(0.8, color='red', lw=3.0)
g2.add_y_marker(0, color='red', lw=3.0)
plt.xlim(0.5,1.2)
plt.ylim(-2, 1)
# plt.text(-1.41, -1.1, 'CPL', fontsize=25)
# plt.text(-1.41, -1.3, 'Datasets: $f_{\sigma_8}$ + Planck', fontsize=25)
plt.text(0.53, -1.75, 'CPL', fontsize=25)
plt.text(0.53, -1.95, 'Datasets: $f \sigma_8$+Planck', fontsize=25)
plt.savefig('postFS8plancks8wa.png')
# Out:
# WARNING:root:outlier fraction 0.2578947368421053
# WARNING:root:outlier fraction 0.23639455782312926
# WARNING:root:outlier fraction 0.22735042735042735
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/fs8+Planck/waCDM_phy_fs8+Planck_nested_dynesty_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/fs8+Planck/waCDM_phy_fs8+Planck_nested_dynesty_multi_new_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/fs8+Planck/waCDM_phy_fs8+Planck_nested_dynesty_multi_new_new_1.txt
# Removed 0.1 as burn in

# %%
plt.figure(figsize=(10, 10), dpi=100)

g2= plots.getSinglePlotter(chain_dir = dir_name_fs8, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})
g2.settings.lab_fontsize = 25
g2.settings.legend_fontsize = 25
g2.settings.axes_fontsize = 25  

g2.plot_2d(roots_fs8, 's8', 'wa', colors=color_list, filled=True, 
           alphas = [1, 0.8, 0.7], 
          legend_loc='upper right')

# g2.add_legend(['Original', 'FFNN',
#                                'FFNN+MC-DO'])

g2.add_x_marker(0.8, color='red', lw=3.0)
g2.add_y_marker(0, color='red', lw=3.0)
plt.xlim(0.5,1.2)
plt.ylim(-2, 1)
# plt.text(-1.41, -1.1, 'CPL', fontsize=25)
# plt.text(-1.41, -1.3, 'Datasets: $f_{\sigma_8}$ + Planck', fontsize=25)
plt.text(0.53, -1.75, 'CPL', fontsize=25)
plt.text(0.53, -1.95, 'Datasets: $f \sigma_8$', fontsize=25)
plt.savefig('postFS8s8wa.png')

# %%
plt.figure(figsize=(10, 10), dpi=100)

g2= plots.getSinglePlotter(chain_dir = dir_name_fs8_planck, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})
g2.settings.lab_fontsize = 25
g2.settings.legend_fontsize = 25
g2.settings.axes_fontsize = 25  

g2.plot_2d(roots_fs8_planck, 'w', 'wa', colors=color_list, filled=True, 
           alphas = [1, 0.8, 0.8], 
          legend_loc='upper right')

# g2.add_legend(['Original', 'FFNN',
#                                'FFNN+MC-DO'])

g2.add_x_marker(-1, color='red', lw=3.0)
g2.add_y_marker(0, color='red', lw=3.0)
plt.xlim(-1.6,0.5)
plt.ylim(-2.2,1.5)
# plt.text(-1.41, -1.1, 'CPL', fontsize=25)
# plt.text(-1.41, -1.3, 'Datasets: $f_{\sigma_8}$ + Planck', fontsize=25)
plt.text(-1.55, -1.5, 'CPL', fontsize=25)
plt.text(-1.55, -1.9, 'Datasets: $f \sigma_8$ + Planck', fontsize=25)
plt.savefig('postFS8planckwowa.png')

# %%
g2= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
g2.settings.lab_fontsize = 20
g2.settings.legend_fontsize = 18
g2.settings.axes_fontsize = 20    

g2.plot_1d(roots_fs8, 's8', param_renames={'s8':'s'},
           colors=['black', 'red'], filled=True, 
           alphas = [0.6, 0.5, 0.4], 
           legend_loc='upper right')

g2.add_legend(['Original $f \sigma_8$ data', 'From FFNN',
                               'From FFNN+MC-DO'])

# g2.add_x_marker(-1, color='green', lw=3.0)
# g2.add_y_marker(0, color='green', lw=3.0)
plt.savefig('s8.png', dpi=50)

# %% [markdown]
# # JLA SN-type Ia

# %%
g2 = plots.getSinglePlotter(chain_dir = dir_name_sn, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
#g.settings.axes_fontsize = 5

g2.settings.lab_fontsize = 20
g2.settings.legend_fontsize = 12
g2.settings.axes_fontsize = 20  
# g.settings.lw1 = 0.5

g2.triangle_plot(roots_SN, ['Om', 'Obh2', 'h', 'w', 'wa'],
# g2.triangle_plot(roots_SN, ['Om', 'Obh2', 'h'],
                diag1d_kwargs={'colors':['black', 'red','blue','black', 'yellow'], 
                               'alphas':[1.0,1.0,1.0]},
                colors=['black', 'red','blue',  'black', 'yellow'],
#                 alphas = [1.0, 0.7, 0.5],
                legend_labels=['original', 'FFNN+AE', 'FFNN+AE+DO'],
#                 legend_labels=['31 original data points ', '31 synthetic data points from AE+FFNN',
#                                '31 synthetic data points from AE+FFNN+dropout'],
                legend_loc='upper right',
                filled = False,
                normalized=False, shaded=False)
        
#plt.show()
#plt.savefig('TriangleJLA', dpi=50)

# %%
g = plots.getSinglePlotter(chain_dir = dir_name_sn, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
#g.settings.axes_fontsize = 5
g.settings.lab_fontsize = 15
g.settings.x_label_rotation= 45
#g.settings.alpha_filled_add = 0.9
g.settings.legend_fontsize = 12
g.settings.axes_fontsize = 12     
# g.settings.lw1 = 0.5

g.triangle_plot(roots_SN, ['w', 'wa'],
# g.triangle_plot(roots_SN, ['Om', 'Obh2', 'h'],
                diag1d_kwargs={'colors':['black', 'red','blue','black', 'yellow'], 
                               'alphas':[1.0,1.0,1.0]},
                colors=['black', 'red','blue',  'black', 'yellow'],
#                 alphas = [0.5, 0.5, 0.5],
                legend_labels=['31 JLA data points', '31 synthetic data points from FFNN+AE',
                               '31 synthetic data points from FFNN+AE+dropout'],
#                 legend_labels=['31 original data points ', '31 synthetic data points from AE+FFNN',
#                                '31 synthetic data points from AE+FFNN+dropout'],
                legend_loc='upper right',
                filled = False,
                normalized=False, shaded=False)

# plt.savefig('TriangleJLA', dpi=50)

# %%
g = plots.getSinglePlotter(chain_dir = dir_name_sn, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
plt.figure(figsize=(10,8))
g.plot_1d(roots_SN, 'w', colors=['black', 'red'], filled=False, alphas = [1, 1, 1], 
          legend_loc='upper right')
g.add_x_marker(-1, color='green', lw=3.0)
g.add_legend(['31 original ', '31 synthetic data points from AE+FFNN',
                               '31 synthetic cc from AE+FFNN+dropout'])

# %%
g = plots.getSinglePlotter(chain_dir = dir_name_sn, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
plt.figure(figsize=(10,8))
g.plot_1d(roots_SN, 'wa', colors=['black', 'red'], filled=False, alphas = [1, 1, 1], 
          legend_loc='upper right')
g.add_x_marker(0, color='green', lw=3.0)

g.add_legend(['31 original ', '31 synthetic data points from AE+FFNN',
                               '31 synthetic cc from AE+FFNN+dropout'])

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name_sn, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})

# gg.settings.lab_fontsize = 18
gg.settings.x_label_rotation= 45
gg.settings.lab_fontsize = 25
gg.settings.legend_fontsize = 20
gg.settings.axes_fontsize = 25  

# plt.figure(figsize=(10,8))
gg.plot_2d(roots_SN, 'w', 'wa', colors=color_list, 
          filled=True, alphas = [1,0.8,0.7],
          legend_loc='upper right')

# gg.add_legend(['Original', 'FFNN+AE','FFNN+AE+MC-DO'])

gg.add_x_marker(-1, color='red', lw=3.0, label="$\Lambda CDM$")
gg.add_y_marker(0, color='red', lw=3.0)
plt.xlim(-2.3,0)
plt.ylim(-2.5,2.5)
plt.text(-2.2, -2, 'CPL', fontsize=25)
plt.text(-2.2, -2.3, 'Datasets: JLA', fontsize=25)

plt.savefig('postJLAwowa.png')

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name_sn, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})

# gg.settings.lab_fontsize = 18
gg.settings.x_label_rotation= 45
gg.settings.lab_fontsize = 25
gg.settings.legend_fontsize = 20
gg.settings.axes_fontsize = 25  

# plt.figure(figsize=(10,8))
gg.plot_2d(roots_SN, 'h', 'w', colors=color_list, 
          filled=True, alphas = [1, 0.8, 0.8],
          legend_loc='upper right')

# gg.add_legend(['Original', 'FFNN+AE','FFNN+AE+MC-DO'])


gg.add_x_marker(0.7324, color='purple', lw=3.0, ls='dotted')
gg.add_x_marker(0.674, color='black', lw=3.0, ls='dashdot')
gg.add_y_marker(-1, color='red', lw=3.0)


plt.text(0.8, -1.8, '·-·- $H_0 = 67.4$', fontsize=22, color='black')
plt.text(0.8, -1.95, '··· $H_0 = 73.24$', fontsize=22, color='purple')

plt.xlim(0.3, 1)
plt.ylim(-2.0,-0.15)

plt.text(0.31, -1.8, 'CPL', fontsize=25)
plt.text(0.31, -1.95, 'Datasets: JLA', fontsize=25)
plt.savefig('postJLAhwo.png')

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name_sn_planck, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})

# gg.settings.lab_fontsize = 18
gg.settings.x_label_rotation= 45
gg.settings.lab_fontsize = 25
gg.settings.legend_fontsize = 20
gg.settings.axes_fontsize = 25  

# plt.figure(figsize=(10,8))
gg.plot_2d(roots_SN_planck, 'h', 'w', colors=color_list, 
          filled=True, alphas = [1, 0.8, 0.8],
          legend_loc='upper right')

# gg.add_legend(['Original', 'FFNN+AE','FFNN+AE+MC-DO'])


gg.add_x_marker(0.7324, color='purple', lw=3.0, ls='dotted')
gg.add_x_marker(0.674, color='black', lw=3.0, ls='dashdot')
gg.add_y_marker(-1, color='red', lw=3.0)

plt.text(0.8, -1.8, '·-·- $H_0 = 67.4$', fontsize=22, color='black')
plt.text(0.8, -1.95, '··· $H_0 = 73.24$', fontsize=22, color='purple')

plt.xlim(0.3, 1)
plt.ylim(-2.0,-0.2)

plt.text(0.31, -1.8, 'CPL', fontsize=25)
plt.text(0.31, -1.95, 'Datasets: JLA+Planck', fontsize=25)
plt.savefig('postJLAplanckhwo.png')

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name_sn_planck, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})

# gg.settings.lab_fontsize = 18
gg.settings.x_label_rotation= 45
gg.settings.lab_fontsize = 25
gg.settings.legend_fontsize = 20
gg.settings.axes_fontsize = 25    



# plt.figure(figsize=(10,8))
gg.plot_2d(roots_SN_planck, 'w', 'wa', colors=color_list, 
           filled=True, alphas = [1, 0.8, 0.8],
           legend_loc='upper right')
# gg.add_legend(['Original', 'FFNN+AE',
#                                'FFNN+AE+MC-DO'])

gg.add_x_marker(-1, color='red', lw=3.0, label="$\Lambda CDM$")
gg.add_y_marker(0, color='red', lw=3.0)
plt.xlim(-2.3,0)
plt.ylim(-2.5,2.5)
plt.text(-2.2, -2, 'CPL', fontsize=25)
plt.text(-2.2, -2.3, 'Datasets: JLA+Planck', fontsize=25)

plt.savefig('postJLAplanckwowa.png')

# %% [markdown]
# ## MIX OF ALL

# %%
g = plots.getSinglePlotter(chain_dir = dir_name_all, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
#g.settings.axes_fontsize = 5
g.settings.lab_fontsize = 15
g.settings.x_label_rotation= 45
#g.settings.alpha_filled_add = 0.9
g.settings.legend_fontsize = 15
g.settings.axes_fontsize = 15   
# g.settings.lw1 = 0.5

g.triangle_plot(roots_all, ['Om', 'Obh2', 'h', 'w', 'wa', 's8'],
# g.triangle_plot(roots_SN, ['Om', 'Obh2', 'h'],
                diag1d_kwargs={'colors':['black', 'red','blue','black', 'yellow'], 
                               'alphas':[1.0,1.0,1.0]},
                colors=['black', 'red','blue',  'black', 'yellow'],
#                 alphas = [1.0, 0.7, 0.5],
                legend_labels=['Real JLA+fs8+CC', 'Synthetic JLA+fs8+CC from FFNN+AE',
                               'Synthetic JLA+fs8+CC FFNN+AE+MC-DO'],
#                 legend_labels=['31 original data points ', '31 synthetic data points from AE+FFNN',
#                                '31 synthetic data points from AE+FFNN+dropout'],
                legend_loc='upper right',
                filled = False,
                normalized=False, shaded=False)
plt.savefig('TriangleALL')
# Out:
# WARNING:root:outlier fraction 0.17179902755267423
# WARNING:root:outlier fraction 0.1721311475409836
# WARNING:root:outlier fraction 0.173512154233026
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/SN+HD+fs8/waCDM_phy_SN+HD+fs8_nested_dynesty_multi_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/SN+HD+fs8/waCDM_phy_SN+HD+fs8_nested_dynesty_multi_new_1.txt
# Removed 0.1 as burn in
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/SN+HD+fs8/waCDM_phy_SN+HD+fs8_nested_dynesty_multi_new_new_1.txt
# Removed 0.1 as burn in

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name_all, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})

# plt.figure(figsize=(10,8))
gg.settings.lab_fontsize = 25
gg.settings.legend_fontsize = 21
gg.settings.axes_fontsize = 25  
gg.plot_2d(roots_all, 'w', 'wa', colors=color_list, 
          filled=True, alphas = [1, 0.8, 0.8], 
          legend_loc='lower left')

# gg.add_legend(['Original', 'FFNN+AE',
#                                'FFNN+AE+MC-DO'])

gg.add_x_marker(-1, color='red', lw=3.0, label="$\Lambda CDM$")
gg.add_y_marker(0, color='red', lw=3.0)

plt.ylim(-1.8,1.8)
plt.xlim(-1.2,-0.5)
plt.text(-0.9, -1.5, 'CPL', fontsize=25)
plt.text(-0.9, -1.7, 'Datasets: CC+$f \sigma_8$+JLA', fontsize=25)


# plt.legend()
plt.savefig('postALLwowa.png')

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg2= plots.getSinglePlotter(chain_dir = dir_name_all, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.2})
gg2.settings.lab_fontsize = 25
gg2.settings.legend_fontsize = 25
g2.settings.axes_fontsize = 25   

gg2.plot_2d(roots_all, 'h', 'w', colors=color_list, filled=True, 
           alphas = [1, 0.8, 0.8], 
          legend_loc='upper right')

# g2.add_legend(['Original', 'FFNN+AE',
#                                'FFNN+AE+MC-DO'])

gg2.add_x_marker(-1, color='red', lw=3.0)
gg2.add_y_marker(0, color='green', lw=3.0)

plt.text(0.56, -1.1, 'CPL', fontsize=25)
plt.text(0.56, -1.14, 'Datasets: CC+$f \sigma_8$+JLA', fontsize=25)


# old boundaries
# plt.xlim(0.6, 0.8)
# plt.ylim(-1.15, -0.67)
plt.xlim(0.55, 0.8)
plt.ylim(-1.15, -0.53)



gg2.add_x_marker(0.7324, color='purple', lw=3.0, ls='dotted')
gg2.add_x_marker(0.674, color='black', lw=3.0, ls='dashdot')
gg2.add_y_marker(-1, color='red', lw=3.0)


plt.text(0.74, -0.62, '·-·- $H_0 = 67.4$', fontsize=22, color='black')
plt.text(0.74, -0.57, '··· $H_0 = 73.24$', fontsize=22, color='purple')


plt.savefig('postALLwoh.png')
# Out:
# WARNING:root:outlier fraction 0.19325432999088424
# WARNING:root:outlier fraction 0.1935483870967742
# WARNING:root:outlier fraction 0.1950989632422243
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/SN+HD+fs8/waCDM_phy_SN+HD+fs8_nested_dynesty_multi_1.txt
# Removed 0.2 as burn in
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/SN+HD+fs8/waCDM_phy_SN+HD+fs8_nested_dynesty_multi_new_1.txt
# Removed 0.2 as burn in
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/SN+HD+fs8/waCDM_phy_SN+HD+fs8_nested_dynesty_multi_new_new_1.txt
# Removed 0.2 as burn in

# %% [markdown]
# ## MIX OF ALL + Planck

# %%
g = plots.getSinglePlotter(chain_dir = dir_name_all_planck, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
#g.settings.axes_fontsize = 5
g.settings.lab_fontsize = 15
g.settings.x_label_rotation= 45
#g.settings.alpha_filled_add = 0.9
g.settings.legend_fontsize = 12
g.settings.axes_fontsize = 12     
# g.settings.lw1 = 0.5

g.triangle_plot(roots_all_planck, ['Om', 'Obh2', 'h', 'w', 'wa', 's8'],
# g.triangle_plot(roots_SN, ['Om', 'Obh2', 'h'],
                diag1d_kwargs={'colors':['black', 'red','blue','black', 'yellow'], 
                               'alphas':[1.0,1.0,1.0]},
                colors=['black', 'red','blue',  'black', 'yellow'],
#                 alphas = [1.0, 0.7, 0.5],
                legend_labels=['Real JLA+$f \sigma_8$+CC', 'Synthetic JLA+$f_{\sigma_8}$+CC from FFNN+AE',
                               'Synthetic JLA+$f_{\sigma_8}$+CC FFNN+AE+MC-DO'],
#                 legend_labels=['31 original data points ', '31 synthetic data points from AE+FFNN',
#                                '31 synthetic data points from AE+FFNN+dropout'],
                legend_loc='upper right',
                filled = False,
                normalized=False, shaded=False)
plt.savefig('TriangleALL_planck', dpi=50)

# %%
plt.figure(figsize=(10, 10), dpi=100)

g2= plots.getSinglePlotter(chain_dir = dir_name_all_planck, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.4,
                                             'smooth_scale_1D': 0.4, 
                                             'ignore_rows': 0.1})
g2.settings.lab_fontsize = 25
g2.settings.legend_fontsize = 22
g2.settings.axes_fontsize = 25    

g2.plot_2d(roots_all_planck, 's8', 'h', colors=color_list, filled=True, 
           alphas = [1, 0.8, 0.8], 
          legend_loc='upper right')

# g2.add_legend(['Original', 'FFNN+AE',
#                                'FFNN+AE+MC-DO'])

g2.add_y_marker(0.7324, color='purple', lw=3.0, ls='dotted')
g2.add_y_marker(0.674, color='black', lw=3.0, ls='dashdot')
g2.add_x_marker(0.8, color='red', lw=3.0)

plt.text(0.55, 0.61, 'Datasets: CC+$f \sigma_8$+JLA+Planck', fontsize=24)
# plt.text(0.601, -1.11, '          + Planck ', fontsize=24)

plt.text(0.94, 0.735, '·-·- $H_0 = 67.4$', fontsize=22, color='black')
plt.text(0.94, 0.725, '··· $H_0 = 73.24$', fontsize=22, color='purple')
plt.text(0.94, 0.715, '--- $\sigma_8 = 0.8$', fontsize=22, color='red')
plt.text(1, 0.61, 'CPL', fontsize=25)

# plt.legend()
plt.savefig('postALLplancksigmah.png')

# %%
plt.figure(figsize=(10, 10), dpi=100)

g2= plots.getSinglePlotter(chain_dir = dir_name_all_planck, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})
g2.settings.lab_fontsize = 25
g2.settings.legend_fontsize = 22
g2.settings.axes_fontsize = 25    

g2.plot_2d(roots_all_planck, 'h', 'w', colors=color_list, filled=True, 
           alphas = [1, 0.8, 0.8], 
          legend_loc='upper right')

# g2.add_legend(['Original', 'FFNN+AE',
#                                'FFNN+AE+MC-DO'])
plt.text(0.61, -1.1, 'CPL', fontsize=25)
plt.text(0.61, -1.14, 'Datasets: CC+$f \sigma_8$+JLA + Planck', fontsize=25)


plt.xlim(0.6, 0.8)
plt.ylim(-1.15, -0.61)

g2.add_x_marker(0.7324, color='purple', lw=3.0, ls='dotted')
g2.add_x_marker(0.674, color='black', lw=3.0, ls='dashdot')
g2.add_y_marker(-1, color='red', lw=3.0)


plt.text(0.75, -0.67, '·-·- $H_0 = 67.4$', fontsize=22, color='black')
plt.text(0.75, -0.71, '··· $H_0 = 73.24$', fontsize=22, color='purple')


# plt.legend()
plt.savefig('postALLplanckwoh.png')

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name_all_planck, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})

# plt.figure(figsize=(10,8))
gg.settings.lab_fontsize = 25
gg.settings.legend_fontsize = 22
gg.settings.axes_fontsize = 25  
gg.plot_2d(roots_all_planck, 'w', 'wa', colors=color_list, 
          filled=True, alphas = [1, 0.8, 0.8], 
          legend_loc='upper right')
# gg.add_legend(['Original', 'FFNN+AE',
#                                'FFNN+AE+MC-DO'])

gg.add_x_marker(-1, color='red', lw=3.0, label="$\Lambda CDM$")
gg.add_y_marker(0, color='red', lw=3.0)

# plt.text(-1.15,-1.1, 'CPL', fontsize=25)
# plt.text(-1.15,-1.2, 'Datasets: CC+$f_{\sigma_8}$+JLA+Planck', fontsize=25)
# plt.text(-1.14,-1.3, '          + Planck point', fontsize=25)
plt.ylim(-1.8,1.8)
plt.xlim(-1.2,-0.5)
plt.text(-0.97, -1.5, 'CPL', fontsize=25)
plt.text(-0.97, -1.7, 'Datasets: CC+$f\sigma_8$+JLA+Planck', fontsize=25)
plt.savefig('postALLplanckwowa.png')

# %% [markdown]
# # JLA+CC

# %%
plt.figure(figsize=(10, 10), dpi=100)
gg= plots.getSinglePlotter(chain_dir = dir_name_cc_sn, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.7,
                                             'smooth_scale_1D': 0.7, 
                                             'ignore_rows': 0.1})

# plt.figure(figsize=(10,8))
gg.settings.lab_fontsize = 25
gg.settings.legend_fontsize = 22
gg.settings.axes_fontsize = 25 
gg.plot_2d(roots_cc_sn, 'w', 'wa', colors=color_list, 
          filled=True, alphas = [1, 0.9, 0.8], 
          legend_loc='upper right')
# gg.add_legend(['Original', 'FFNN+AE',
#                         'FFNN+AE+MC-DO'])

gg.add_x_marker(-1, color='red', lw=3.0, label="$\Lambda CDM$")
gg.add_y_marker(0, color='red', lw=3.0)

plt.xlim(-1.75, 0)
plt.ylim(-2.5,2.5)
# gg.add_y_marker(-2, color='green', lw=3.0)
plt.text(-1.7,-2,'CPL', fontsize=25)
plt.text(-1.7,-2.3,'Datasets: CC+JLA', fontsize=25)

plt.savefig('postHDJLAwowa.png')

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name_cc_sn_planck, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})

# plt.figure(figsize=(10,8))
gg.settings.lab_fontsize = 25
gg.settings.legend_fontsize = 25
gg.settings.axes_fontsize = 25 
gg.plot_2d(roots_cc_sn_planck, 'w', 'wa', colors=color_list, 
          filled=True, alphas = [0.9, 0.9, 0.8], 
          legend_loc='upper right')
# gg.add_legend(['Original', 'FFNN+AE',
#                                'FFNN+AE+MC-DO'])

gg.add_x_marker(-1, color='red', lw=3.0, label="$\Lambda CDM$")
gg.add_y_marker(0, color='red', lw=3.0)
# gg.add_y_marker(-2, color='green', lw=3.0)

plt.xlim(-1.75, 0)
plt.ylim(-2.5,2.5)
plt.text(-1.7, -2, 'CPL', fontsize=25)
plt.text(-1.7, -2.3, 'Datasets: CC+JLA+Planck', fontsize=25)
# plt.text(-1.55, -2.2, '       + Planck point', fontsize=25)


plt.savefig('postHDJLAplanckwowa.png')

# %%
import fgivenx
from fgivenx import plot_contours, samples_from_getdist_chains

# %%
def eos(z, params):
    w0, wa = params
    return w0 + (z/(1+z))*wa

# %%
cmap_reversed = matplotlib.cm.get_cmap('Greens_r')

# %%
file_root = dir_name_all + 'waCDM_phy_SN+HD+fs8_nested_dynesty_multi'

samples, weights = samples_from_getdist_chains(['w', 'wa'], file_root)
k = np.linspace(0,2,100)

cbar = plot_contours(eos, k, samples, weights=weights, colors=cmap_reversed, contour_line_levels=[1,2],  
                     linewidths=[2,1.5])
cbar = plt.colorbar(cbar,ticks=[0,1,2,3])
cbar.set_ticklabels(['',r'$1\sigma$',r'$2\sigma$',r'$3\sigma$'])

plt.hlines(-1, xmin=0, xmax=2, colors='r',  linestyles='dashed', label='$w=-1$', lw=2)
plt.ylabel(r'$w(z)$')
plt.xlabel(r'$z$')

plt.tight_layout()

plt.legend(loc='lower left')
plt.text(0,-1.6, 'CC+JLA+$f\sigma_8$', fontsize=13)
plt.savefig('cplEoS.png')
# Out:
# WARNING:root:outlier fraction 0.15463165572574764
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/SN+HD+fs8/waCDM_phy_SN+HD+fs8_nested_dynesty_multi_1.txt
# Removed no burn in
# ...
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
file_root = dir_name_all_planck + 'waCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi'

samples, weights = samples_from_getdist_chains(['w', 'wa'], file_root)
k = np.linspace(0,2,100)

cbar = plot_contours(eos, k, samples, weights=weights, colors=cmap_reversed,  contour_line_levels=[1,2],  
                     linewidths=[2,1.5])
cbar = plt.colorbar(cbar,ticks=[0,1,2,3])
cbar.set_ticklabels(['',r'$1\sigma$',r'$2\sigma$',r'$3\sigma$'])

plt.hlines(-1, xmin=0, xmax=2, colors='r',  linestyles='dashed', label='$w=-1$', lw=2)
plt.ylabel(r'$w(z)$')
plt.xlabel(r'$z$')

plt.tight_layout()

plt.legend(loc='lower left')
plt.text(0.02,-1.35, 'CC+JLA+$f\sigma_8+Planck$', fontsize=13)
plt.savefig('cplEoS_planck.png')
# Out:
# WARNING:root:outlier fraction 0.1627565982404692
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/SN+HD+fs8+Planck/waCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi_1.txt
# Removed no burn in
# ...
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
file_root = dir_name_all + 'waCDM_phy_SN+HD+fs8_nested_dynesty_multi_new'

samples, weights = samples_from_getdist_chains(['w', 'wa'], file_root)
k = np.linspace(0,2,100)

cbar = plot_contours(eos, k, samples, weights=weights, colors=cmap_reversed,  contour_line_levels=[1,2],  
                     linewidths=[2,1.5])
cbar = plt.colorbar(cbar,ticks=[0,1,2,3])
cbar.set_ticklabels(['',r'$1\sigma$',r'$2\sigma$',r'$3\sigma$'])

plt.ylabel(r'$w(z)$')
plt.xlabel(r'$z$')
plt.hlines(-1, xmin=0, xmax=2, colors='r',  linestyles='dashed', label='$w=-1$', lw=2)

plt.tight_layout()

plt.legend(loc='lower left')
plt.text(0.2,-1.38, 'CC+JLA+$f\sigma_8$', fontsize=13)
plt.savefig('cplEoS_ann.png')
# Out:
# WARNING:root:outlier fraction 0.15486725663716813
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/SN+HD+fs8/waCDM_phy_SN+HD+fs8_nested_dynesty_multi_new_1.txt
# Removed no burn in
# ...
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
file_root = dir_name_all_planck + 'waCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi_new'

samples, weights = samples_from_getdist_chains(['w', 'wa'], file_root)
k = np.linspace(0,2,100)

cbar = plot_contours(eos, k, samples, weights=weights, colors=cmap_reversed,  contour_line_levels=[1,2],  
                     linewidths=[2,1.5])
cbar = plt.colorbar(cbar,ticks=[0,1,2,3])
cbar.set_ticklabels(['',r'$1\sigma$',r'$2\sigma$',r'$3\sigma$'])

plt.ylabel(r'$w(z)$')
plt.xlabel(r'$z$')
plt.hlines(-1, xmin=0, xmax=2, colors='r',  linestyles='dashed', label='$w=-1$', lw=2)

plt.tight_layout()

plt.legend(loc='lower left')
plt.text(0.02,-1.455, 'CC+JLA+$f\sigma_8+Planck$', fontsize=13)
plt.savefig('cplEoS_ann_planck.png')
# Out:
# WARNING:root:outlier fraction 0.1588785046728972
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/SN+HD+fs8+Planck/waCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi_new_1.txt
# Removed no burn in
# ...
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
file_root = dir_name_all + 'waCDM_phy_SN+HD+fs8_nested_dynesty_multi_new_new'

samples, weights = samples_from_getdist_chains(['w', 'wa'], file_root)
k = np.linspace(0,2,100)

cbar = plot_contours(eos, k, samples, weights=weights, colors=cmap_reversed,  contour_line_levels=[1,2],  
                     linewidths=[2,1.5])
cbar = plt.colorbar(cbar,ticks=[0,1,2,3])
cbar.set_ticklabels(['',r'$1\sigma$',r'$2\sigma$',r'$3\sigma$'])

plt.ylabel(r'$w(z)$')
plt.xlabel(r'$z$')
plt.hlines(-1, xmin=0, xmax=2, colors='r',  linestyles='dashed', label='$w=-1$', lw=2)

plt.tight_layout()

plt.legend(loc='lower left')
plt.text(0.02,-1.4, 'CC+JLA+$f\sigma_8$', fontsize=13)
plt.savefig('cplEoS_ann_do.png')
# Out:
# WARNING:root:outlier fraction 0.15610859728506787
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/SN+HD+fs8/waCDM_phy_SN+HD+fs8_nested_dynesty_multi_new_new_1.txt
# Removed no burn in
# ...
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
file_root = dir_name_all_planck + 'waCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi_new_new_new'

samples, weights = samples_from_getdist_chains(['w', 'wa'], file_root, settings={'ignore_rows':0.0})
k = np.linspace(0,2,100)

cbar = plot_contours(eos, k, samples, weights=weights, colors=cmap_reversed,  contour_line_levels=[1,2],  
                     linewidths=[2,1.5])
cbar = plt.colorbar(cbar,ticks=[0,1,2,3])
cbar.set_ticklabels(['',r'$1\sigma$',r'$2\sigma$',r'$3\sigma$'])

plt.ylabel(r'$w(z)$')
plt.xlabel(r'$z$')
plt.hlines(-1, xmin=0, xmax=2, colors='r',  linestyles='dashed', label='$w=-1$', lw=2)

plt.tight_layout()

plt.legend(loc='lower left')
plt.text(0.02,-1.25, 'CC+JLA+$f\sigma_8+Planck$', fontsize=13)
plt.savefig('cplEoS_ann_do_planck.png')
# Out:
# WARNING:root:outlier fraction 0.16076487252124647
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/SN+HD+fs8+Planck/waCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi_new_new_new_1.txt
# Removed no burn in
# ...
#   0%|          | 0/100 [00:00<?, ?it/s]

# %% [markdown]
# ## POLYCDM

# %%
# plt.figure(figsize=(10, 10), dpi=100)

g= plots.getSinglePlotter(chain_dir = dir_name_poly, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.9,
                                             'smooth_scale_1D': 0.9, 
                                             'ignore_rows': 0.1})
#g.settings.axes_fontsize = 5]
g.settings.lab_fontsize = 15
g.settings.x_label_rotation= 45
#g.settings.alpha_filled_add = 0.9
g.settings.legend_fontsize = 15
g.settings.axes_fontsize = 15   
# g.settings.lw1 = 0.5

g.triangle_plot(roots_polycdm, ['Om', 'Obh2', 'h', 's8', 'Om1', 'Om2'],
# g.triangle_plot(roots, ['Om', 'Obh2', 'h'],
                diag1d_kwargs={'colors':['black', 'red','blue','black', 'yellow'], 
                               'alphas':[1.0,1.0,1.0]},
                colors=['black', 'red','blue',  'black', 'yellow'],
#                 alphas = [1.0, 0.7, 0.5],
                legend_labels=['31 original cc ', '50 synthetic cc from FFNN',
                               '50 synthetic data points from FFNN+MC dropout'],
#                 legend_labels=['31 original data points ', '31 synthetic data points from AE+FFNN',
#                                '31 synthetic data points from AE+FFNN+dropout'],
                legend_loc='upper right',
                filled = False,
                normalized=False, shaded=False)
        
#plt.show()
plt.savefig('Trianglewapolycdm', dpi=100)

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name_poly, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})

# plt.figure(figsize=(10,8))
gg.settings.lab_fontsize = 25
gg.settings.legend_fontsize = 25
gg.settings.axes_fontsize = 25  
gg.plot_2d(roots_polycdm, 'Om1', 'Om2', colors=color_list, 
          filled=True, alphas = [0.8, 0.8, 0.8], 
          legend_loc='upper right')
# gg.add_legend(['Original', 'FFNN+AE',
#                                'FFNN+AE+MC-DO'])

gg.add_x_marker(0, color='red', lw=3.0, label="$\Lambda CDM$")
gg.add_y_marker(0, color='red', lw=3.0)

plt.xlim(-1.1, 1.5)
plt.ylim(-0.7,1.0)
plt.text(-0.95, -0.4, 'PolyCDM', fontsize=25)
plt.text(-0.95, -0.6, 'Datasets: CC+$f\sigma_8$+JLA', fontsize=25)

plt.savefig('postpolycdm1.png')

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name_poly, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})

# plt.figure(figsize=(10,8))
gg.settings.lab_fontsize = 25
gg.settings.legend_fontsize = 21
gg.settings.axes_fontsize = 25  
gg.plot_2d(roots_polycdm, 'h', 'Om1', colors=color_list, 
          filled=True, alphas = [1, 0.8, 0.7], 
          legend_loc='upper right')
# gg.add_legend(['Original', 'FFNN+AE',
#                                'FFNN+AE+MC-DO'])

gg.add_x_marker(0, color='red', lw=3.0, label="$\Lambda CDM$")
gg.add_y_marker(0, color='red', lw=3.0)
plt.xlim(0.6,0.8)
plt.ylim(-1.5,2)
plt.text(0.61, -0.9,  'PolyCDM', fontsize=25)
plt.text(0.61, -1.31, 'Datasets: CC+$f \sigma_8$+JLA', fontsize=25)


plt.savefig('postpolycdm3.png')

# %%
plt.figure(figsize=(10, 10), dpi=100)

gg= plots.getSinglePlotter(chain_dir = dir_name_poly_planck, width_inch= 10,
                          ratio = 0.8, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})

# plt.figure(figsize=(10,8))
gg.settings.lab_fontsize = 25
gg.settings.legend_fontsize = 25
gg.settings.axes_fontsize = 25  
gg.plot_2d(roots_polycdm_planck, 'Om1', 'Om2', colors=color_list, 
          filled=True, alphas = [1, 1, 0.9], 
          legend_loc='upper right')
# gg.add_legend(['Original', 'FFNN+AE',
#                                'FFNN+AE+MC-DO'])

gg.add_x_marker(0, color='red', lw=3.0, label="$\Lambda CDM$")
gg.add_y_marker(0, color='red', lw=3.0)
plt.xlim(-1.1, 1.5)
plt.ylim(-0.7, 1)
# plt.text(-0.65, -0.2, 'polyCDM', fontsize=25)
# plt.text(-0.65, -0.3, 'Datasets: CC+$f_{\sigma_8}$+JLA+Planck', fontsize=25)
plt.text(-0.95, -0.5, 'PolyCDM', fontsize=25)
plt.text(-0.95, -0.6, 'Datasets: CC+$f \sigma_8$+JLA+Planck', fontsize=25)

plt.savefig('postpolycdm2.png')

# %% [markdown]
# # Statistics

# %% [markdown]
# # CC
#
# 1 -> original, 2 -> FFNN, 3->FFNN+MCDO

# %%
roots_lcdmcc = ['LCDM_phy_HD_nested_dynesty_multi', 'LCDM_phy_HD_nested_dynesty_multi_new', 
                'LCDM_phy_HD_nested_dynesty_multi_new_new']

mc_CC_lcdm1 = mcsamples.loadMCSamples(dir_name_cc+'/'+roots_lcdmcc[0], settings={'ignore_rows':0.0})
mc_CC_lcdm2 = mcsamples.loadMCSamples(dir_name_cc+'/'+roots_lcdmcc[1], settings={'ignore_rows':0.0})
mc_CC_lcdm3 = mcsamples.loadMCSamples(dir_name_cc+'/'+roots_lcdmcc[2], settings={'ignore_rows':0.0})

mc_CC1 = mcsamples.loadMCSamples(dir_name_cc+'/'+roots_HD[0], settings={'ignore_rows':0.0})
mc_CC2 = mcsamples.loadMCSamples(dir_name_cc+'/'+roots_HD[1], settings={'ignore_rows':0.0})
mc_CC3 = mcsamples.loadMCSamples(dir_name_cc+'/'+roots_HD[2], settings={'ignore_rows':0.0})

mc_CCplanck1 = mcsamples.loadMCSamples(dir_name_cc_planck+'/'+roots_HD_planck[0], settings={'ignore_rows':0.0})
mc_CCplanck2 = mcsamples.loadMCSamples(dir_name_cc_planck+'/'+roots_HD_planck[1], settings={'ignore_rows':0.0})
mc_CCplanck3 = mcsamples.loadMCSamples(dir_name_cc_planck+'/'+roots_HD_planck[2], settings={'ignore_rows':0.0})

# %%
# mcsamplefile = mc_CC_lcdm3
# mcsamplefile = mc_CC3
mcsamplefile = mc_CCplanck3
mcstats = mcsamplefile.getLikeStats()
mcstats.likeSummary()
# Out:
# 'Best fit sample -log(Like) = 0.404179\nmean(-Ln(like)) = 2.015835\n-Ln(mean like)  = 1.553031\n'

# %%
l = round(2*mcstats.logLike_sample, 3)
print("${}$".format(l))
# Out:
# $0.808$

# %%
for i in [2,3,4]:
    print(mcstats.list()[i])
#     top = mcstats.names[i].ND_limit_top[1]
#     low = mcstats.names[i].ND_limit_bot[1]
    best = mcstats.names[i].bestfit_sample
    print(best)
    #print(top)
    #print(low)
    print("best %4.5f"%(best))
    print("mean %4.5f"%(mcsamplefile.getMeans()[i]))
#     print("%4.3f + %4.3f - %4.3f"%(best, (top-best), (best-low)))
    print("std dev %5.4f"%(mcsamplefile.std(mcstats.list()[i])))
#     print("$  {%4.3f} \pm $"%(mcsamplefile.getMeans()[i]))
    print("${:.3f} \pm {:.3f}$".format(mcsamplefile.getMeans()[i], mcsamplefile.std(mcstats.list()[i])))
    print("--"*20)
# Out:
# h
# 0.71351422
# best 0.71351
# mean 0.72645
# std dev 0.0626
# $0.726 \pm 0.063$
# ----------------------------------------
# w
# -0.99896874
# best -0.99897
# mean -1.02944
# std dev 0.3548
# $-1.029 \pm 0.355$
# ----------------------------------------
# wa
# -0.27420455
# best -0.27420
# mean -0.37664
# std dev 0.8971
# $-0.377 \pm 0.897$
# ----------------------------------------

# %% [markdown]
# # FS8

# %%
roots_lcdmfs8 = ['LCDM_phy_fs8_nested_dynesty_multi', 'LCDM_phy_fs8_nested_dynesty_multi_new', 
                'LCDM_phy_fs8_nested_dynesty_multi_new_new']

mc_fs8_lcdm1 = mcsamples.loadMCSamples(dir_name_fs8+'/'+roots_lcdmfs8[0], settings={'ignore_rows':0.0})
mc_fs8_lcdm2 = mcsamples.loadMCSamples(dir_name_fs8+'/'+roots_lcdmfs8[1], settings={'ignore_rows':0.0})
mc_fs8_lcdm3 = mcsamples.loadMCSamples(dir_name_fs8+'/'+roots_lcdmfs8[2], settings={'ignore_rows':0.0})

mc_fs81 = mcsamples.loadMCSamples(dir_name_fs8+'/'+roots_fs8[0], settings={'ignore_rows':0.0})
mc_fs82 = mcsamples.loadMCSamples(dir_name_fs8+'/'+roots_fs8[1], settings={'ignore_rows':0.0})
mc_fs83 = mcsamples.loadMCSamples(dir_name_fs8+'/'+roots_fs8[2], settings={'ignore_rows':0.0})

mc_fs8planck1 = mcsamples.loadMCSamples(dir_name_fs8_planck+'/'+roots_fs8_planck[0], settings={'ignore_rows':0.0})
mc_fs8planck2 = mcsamples.loadMCSamples(dir_name_fs8_planck+'/'+roots_fs8_planck[1], settings={'ignore_rows':0.0})
mc_fs8planck3 = mcsamples.loadMCSamples(dir_name_fs8_planck+'/'+roots_fs8_planck[2], settings={'ignore_rows':0.0})
# Out:
# WARNING:root:outlier fraction 0.23174971031286212
# WARNING:root:outlier fraction 0.21875
# WARNING:root:outlier fraction 0.23496659242761692
# WARNING:root:outlier fraction 0.21161417322834647
# WARNING:root:outlier fraction 0.22643343051506318
# WARNING:root:outlier fraction 0.2222222222222222
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/fs8//LCDM_phy_fs8_nested_dynesty_multi_1.txt
# Removed no burn in
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/fs8//LCDM_phy_fs8_nested_dynesty_multi_new_1.txt
# Removed no burn in
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/fs8//LCDM_phy_fs8_nested_dynesty_multi_new_new_1.txt
# Removed no burn in
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/fs8//waCDM_phy_fs8_nested_dynesty_multi_1.txt
# Removed no burn in
# ...

# %%
# mcsamplefile = mc_fs8_lcdm3
# mcsamplefile = mc_fs83
mcsamplefile = mc_fs8planck3
mcstats = mcsamplefile.getLikeStats()
mcstats.likeSummary()
# Out:
# 'Best fit sample -log(Like) = 0.518903\nmean(-Ln(like)) = 2.537293\n-Ln(mean like)  = 1.960212\n'

# %%
l = round(2*mcstats.logLike_sample, 3)
print("${}$".format(l))
# Out:
# $1.038$

# %%
for i in [2,3,4,5]:
    print(mcstats.list()[i])
#     top = mcstats.names[i].ND_limit_top[1]
#     low = mcstats.names[i].ND_limit_bot[1]
    best = mcstats.names[i].bestfit_sample
    print(best)
    #print(top)
    #print(low)
    print("best %4.5f"%(best))
    print("mean %4.5f"%(mcsamplefile.getMeans()[i]))
#     print("%4.3f + %4.3f - %4.3f"%(best, (top-best), (best-low)))
    print("std dev %5.4f"%(mcsamplefile.std(mcstats.list()[i])))
#     print("$  {%4.3f} \pm $"%(mcsamplefile.getMeans()[i]))
    print("${:.3f} \pm {:.3f}$".format(mcsamplefile.getMeans()[i], mcsamplefile.std(mcstats.list()[i])))
    print("--"*20)
# Out:
# h
# 0.58794856
# best 0.58795
# mean 0.62203
# std dev 0.0461
# $0.622 \pm 0.046$
# ----------------------------------------
# s8
# 0.67039736
# best 0.67040
# mean 0.75616
# std dev 0.1029
# $0.756 \pm 0.103$
# ----------------------------------------
# w
# -0.52425423
# best -0.52425
# mean -0.67344
# std dev 0.1828
# $-0.673 \pm 0.183$
# ----------------------------------------
# wa
# -0.45734272
# best -0.45734
# mean -0.36447
# std dev 0.2206
# $-0.364 \pm 0.221$
# ----------------------------------------

# %% [markdown]
# # JLA

# %%
roots_lcdmsn = ['LCDM_phy_SN_nested_dynesty_multi', 'LCDM_phy_SN_nested_dynesty_multi_new', 
                'LCDM_phy_SN_nested_dynesty_multi_new_new']

mc_sn_lcdm1 = mcsamples.loadMCSamples(dir_name_sn +'/'+roots_lcdmsn[0], settings={'ignore_rows':0.0})
mc_sn_lcdm2 = mcsamples.loadMCSamples(dir_name_sn +'/'+roots_lcdmsn[1], settings={'ignore_rows':0.0})
mc_sn_lcdm3 = mcsamples.loadMCSamples(dir_name_sn +'/'+roots_lcdmsn[2], settings={'ignore_rows':0.0})

mc_sn1 = mcsamples.loadMCSamples(dir_name_sn+'/'+roots_SN[0], settings={'ignore_rows':0.0})
mc_sn2 = mcsamples.loadMCSamples(dir_name_sn+'/'+roots_SN[1], settings={'ignore_rows':0.0})
mc_sn3 = mcsamples.loadMCSamples(dir_name_sn+'/'+roots_SN[2], settings={'ignore_rows':0.0})

mc_snplanck1 = mcsamples.loadMCSamples(dir_name_sn_planck+'/'+roots_SN_planck[0], settings={'ignore_rows':0.0})
mc_snplanck2 = mcsamples.loadMCSamples(dir_name_sn_planck+'/'+roots_SN_planck[1], settings={'ignore_rows':0.0})
mc_snplanck3 = mcsamples.loadMCSamples(dir_name_sn_planck+'/'+roots_SN_planck[2], settings={'ignore_rows':0.0})

# %%
mcsamplefile = mc_sn_lcdm3
# mcsamplefile = mc_sn3
# mcsamplefile = mc_snplanck3
mcstats = mcsamplefile.getLikeStats()
mcstats.likeSummary()
# Out:
# 'Best fit sample -log(Like) = 23.803257\nmean(-Ln(like)) = 24.739653\n-Ln(mean like)  = 24.466980\n'

# %%
l = round(2*mcstats.logLike_sample, 3)
print("${}$".format(l))
# Out:
# $47.607$

# %%
for i in [0,2,3,4,5]:
# for i in [0,1,2,3]:
    print(mcstats.list()[i])
#     top = mcstats.names[i].ND_limit_top[1]
#     low = mcstats.names[i].ND_limit_bot[1]
    best = mcstats.names[i].bestfit_sample
    print(best)
    #print(top)
    #print(low)
    print("best %4.5f"%(best))
    print("mean %4.5f"%(mcsamplefile.getMeans()[i]))
#     print("%4.3f + %4.3f - %4.3f"%(best, (top-best), (best-low)))
    print("std dev %5.4f"%(mcsamplefile.std(mcstats.list()[i])))
#     print("$  {%4.3f} \pm $"%(mcsamplefile.getMeans()[i]))
    print("${:.3f} \pm {:.3f}$".format(mcsamplefile.getMeans()[i], mcsamplefile.std(mcstats.list()[i])))
    print("--"*20)
# Out:
# Om
# 0.34963736
# best 0.34964
# mean 0.35537
# std dev 0.0336
# $0.355 \pm 0.034$
# ----------------------------------------
# h
# 0.74161196
# best 0.74161
# mean 0.64357
# std dev 0.1445
# $0.644 \pm 0.144$
# ----------------------------------------
# BetouleSN_like
# -23.80304711167561
# best -23.80305
# mean -24.26724
# std dev 0.6623
# $-24.267 \pm 0.662$
# ----------------------------------------
# theory_prior
# -0.0004826945210877
# best -0.00048
# mean -0.48237
# std dev 0.6742
# $-0.482 \pm 0.674$
# ----------------------------------------
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-245-04af24788ec6> in <module>
#       1 for i in [0,2,3,4,5]:
#       2 # for i in [0,1,2,3]:
# ----> 3     print(mcstats.list()[i])
#       4 #     top = mcstats.names[i].ND_limit_top[1]
#       5 #     low = mcstats.names[i].ND_limit_bot[1]
#
# ...

# %% [markdown]
# # CC+JLA

# %%
roots_lcdmccsn = ['LCDM_phy_SN+HD_nested_dynesty_multi', 'LCDM_phy_SN+HD_nested_dynesty_multi_new', 
                'LCDM_phy_SN+HD_nested_dynesty_multi_new_new']

mc_ccsn_lcdm1 = mcsamples.loadMCSamples(dir_name_cc_sn +'/'+roots_lcdmccsn[0], settings={'ignore_rows':0.0})
mc_ccsn_lcdm2 = mcsamples.loadMCSamples(dir_name_cc_sn +'/'+roots_lcdmccsn[1], settings={'ignore_rows':0.0})
mc_ccsn_lcdm3 = mcsamples.loadMCSamples(dir_name_cc_sn +'/'+roots_lcdmccsn[2], settings={'ignore_rows':0.0})

mc_ccsn1 = mcsamples.loadMCSamples(dir_name_cc_sn+'/'+roots_cc_sn[0], settings={'ignore_rows':0.0})
mc_ccsn2 = mcsamples.loadMCSamples(dir_name_cc_sn+'/'+roots_cc_sn[1], settings={'ignore_rows':0.0})
mc_ccsn3 = mcsamples.loadMCSamples(dir_name_cc_sn+'/'+roots_cc_sn[2], settings={'ignore_rows':0.0})

mc_ccsnplanck1 = mcsamples.loadMCSamples(dir_name_cc_sn_planck+'/'+roots_cc_sn_planck[0], settings={'ignore_rows':0.0})
mc_ccsnplanck2 = mcsamples.loadMCSamples(dir_name_cc_sn_planck+'/'+roots_cc_sn_planck[1], settings={'ignore_rows':0.0})
mc_ccsnplanck3 = mcsamples.loadMCSamples(dir_name_cc_sn_planck+'/'+roots_cc_sn_planck[2], settings={'ignore_rows':0.0})

# %%
# mcsamplefile = mc_ccsn_lcdm3
# mcsamplefile = mc_ccsn3
mcsamplefile = mc_ccsnplanck3
mcstats = mcsamplefile.getLikeStats()
mcstats.likeSummary()
# Out:
# 'Best fit sample -log(Like) = 24.123827\nmean(-Ln(like)) = 26.218450\n-Ln(mean like)  = 25.625069\n'

# %%
l = round(2*mcstats.logLike_sample, 3)
print("${}$".format(l))
# Out:
# $48.248$

# %%
for i in [2,3,4,5]:
    print(mcstats.list()[i])
#     top = mcstats.names[i].ND_limit_top[1]
#     low = mcstats.names[i].ND_limit_bot[1]
    best = mcstats.names[i].bestfit_sample
    print(best)
    #print(top)
    #print(low)
    print("best %4.5f"%(best))
    print("mean %4.5f"%(mcsamplefile.getMeans()[i]))
#     print("%4.3f + %4.3f - %4.3f"%(best, (top-best), (best-low)))
    print("std dev %5.4f"%(mcsamplefile.std(mcstats.list()[i])))
#     print("$  {%4.3f} \pm $"%(mcsamplefile.getMeans()[i]))
    print("${:.3f} \pm {:.3f}$".format(mcsamplefile.getMeans()[i], mcsamplefile.std(mcstats.list()[i])))
    print("--"*20)
# Out:
# h
# 0.66395791
# best 0.66396
# mean 0.66074
# std dev 0.0156
# $0.661 \pm 0.016$
# ----------------------------------------
# w
# -0.73351418
# best -0.73351
# mean -0.74892
# std dev 0.1927
# $-0.749 \pm 0.193$
# ----------------------------------------
# wa
# -0.66681247
# best -0.66681
# mean -0.62546
# std dev 0.7020
# $-0.625 \pm 0.702$
# ----------------------------------------
# BetouleSN_like
# -23.441995571523822
# best -23.44200
# mean -24.05775
# std dev 0.6426
# $-24.058 \pm 0.643$
# ----------------------------------------

# %% [markdown]
# # ALL

# %%
roots_lcdmall = ['LCDM_phy_HD+SN+fs8_nested_dynesty_multi', 'LCDM_phy_HD+SN+fs8_nested_dynesty_multi_new', 
                'LCDM_phy_HD+SN+fs8_nested_dynesty_multi_new_new']

mc_all_lcdm1 = mcsamples.loadMCSamples(dir_name_all +'/'+roots_lcdmall[0], settings={'ignore_rows':0.0})
mc_all_lcdm2 = mcsamples.loadMCSamples(dir_name_all +'/'+roots_lcdmall[1], settings={'ignore_rows':0.0})
mc_all_lcdm3 = mcsamples.loadMCSamples(dir_name_all +'/'+roots_lcdmall[2], settings={'ignore_rows':0.0})

mc_all1 = mcsamples.loadMCSamples(dir_name_all+'/'+roots_all[0], settings={'ignore_rows':0.0})
mc_all2 = mcsamples.loadMCSamples(dir_name_all+'/'+roots_all[1], settings={'ignore_rows':0.0})
mc_all3 = mcsamples.loadMCSamples(dir_name_all+'/'+roots_all[2], settings={'ignore_rows':0.0})

mc_allplanck1 = mcsamples.loadMCSamples(dir_name_all_planck+'/'+roots_all_planck[0], settings={'ignore_rows':0.0})
mc_allplanck2 = mcsamples.loadMCSamples(dir_name_all_planck+'/'+roots_all_planck[1], settings={'ignore_rows':0.0})
mc_allplanck3 = mcsamples.loadMCSamples(dir_name_all_planck+'/'+roots_all_planck[2], settings={'ignore_rows':0.0})
# Out:
# WARNING:root:outlier fraction 0.19859402460456943
# WARNING:root:outlier fraction 0.1723849372384937
# WARNING:root:outlier fraction 0.15270935960591134
# WARNING:root:outlier fraction 0.15463165572574764
# WARNING:root:outlier fraction 0.15486725663716813
# WARNING:root:outlier fraction 0.15610859728506787
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/SN+HD+fs8//LCDM_phy_HD+SN+fs8_nested_dynesty_multi_1.txt
# Removed no burn in
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/SN+HD+fs8//LCDM_phy_HD+SN+fs8_nested_dynesty_multi_new_1.txt
# Removed no burn in
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/SN+HD+fs8//LCDM_phy_HD+SN+fs8_nested_dynesty_multi_new_new_1.txt
# Removed no burn in
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/SN+HD+fs8//waCDM_phy_SN+HD+fs8_nested_dynesty_multi_1.txt
# Removed no burn in
# ...

# %%
# mcsamplefile = mc_all_lcdm3
# mcsamplefile = mc_all3
mcsamplefile = mc_allplanck3
mcstats = mcsamplefile.getLikeStats()
mcstats.likeSummary()
# Out:
# 'Best fit sample -log(Like) = 24.815241\nmean(-Ln(like)) = 27.268237\n-Ln(mean like)  = 26.578384\n'

# %%
l = round(2*mcstats.logLike_sample, 3)
print("${}$".format(l))
# Out:
# $49.63$

# %%
for i in [2,3,4,5]:
    print(mcstats.list()[i])
#     top = mcstats.names[i].ND_limit_top[1]
#     low = mcstats.names[i].ND_limit_bot[1]
    best = mcstats.names[i].bestfit_sample
    print(best)
    #print(top)
    #print(low)
    print("best %4.5f"%(best))
    print("mean %4.5f"%(mcsamplefile.getMeans()[i]))
#     print("%4.3f + %4.3f - %4.3f"%(best, (top-best), (best-low)))
    print("std dev %5.4f"%(mcsamplefile.std(mcstats.list()[i])))
#     print("$  {%4.3f} \pm $"%(mcsamplefile.getMeans()[i]))
    print("${:.3f} \pm {:.3f}$".format(mcsamplefile.getMeans()[i], mcsamplefile.std(mcstats.list()[i])))
    print("--"*20)
# Out:
# h
# 0.66317075
# best 0.66317
# mean 0.65862
# std dev 0.0164
# $0.659 \pm 0.016$
# ----------------------------------------
# s8
# 0.62334747
# best 0.62335
# mean 0.73774
# std dev 0.0986
# $0.738 \pm 0.099$
# ----------------------------------------
# w
# -0.83024837
# best -0.83025
# mean -0.82440
# std dev 0.0736
# $-0.824 \pm 0.074$
# ----------------------------------------
# wa
# -0.3226135
# best -0.32261
# mean -0.26896
# std dev 0.2181
# $-0.269 \pm 0.218$
# ----------------------------------------

# %% [markdown]
# # PolyCDM

# %%
mc_poly1 = mcsamples.loadMCSamples(dir_name_poly+'/'+roots_polycdm[0], settings={'ignore_rows':0.0})
mc_poly2 = mcsamples.loadMCSamples(dir_name_poly+'/'+roots_polycdm[1], settings={'ignore_rows':0.0})
mc_poly3 = mcsamples.loadMCSamples(dir_name_poly+'/'+roots_polycdm[2], settings={'ignore_rows':0.0})

mc_polyplanck1 = mcsamples.loadMCSamples(dir_name_poly_planck+'/'+roots_polycdm_planck[0], settings={'ignore_rows':0.0})
mc_polyplanck2 = mcsamples.loadMCSamples(dir_name_poly_planck+'/'+roots_polycdm_planck[1], settings={'ignore_rows':0.0})
mc_polyplanck3 = mcsamples.loadMCSamples(dir_name_poly_planck+'/'+roots_polycdm_planck[2], settings={'ignore_rows':0.0})
# Out:
# WARNING:root:outlier fraction 0.15420200462606015
# WARNING:root:outlier fraction 0.1772831926323868
# WARNING:root:outlier fraction 0.15135135135135136
# WARNING:root:outlier fraction 0.14878397711015737
# WARNING:root:outlier fraction 0.1437908496732026
# WARNING:root:outlier fraction 0.14093484419263455
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/polyCDM//PolyCDM_phy_SN+HD+fs8_nested_dynesty_multi_1.txt
# Removed no burn in
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/polyCDM//PolyCDM_phy_SN+HD+fs8_nested_dynesty_multi_new_1.txt
# Removed no burn in
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/polyCDM//PolyCDM_phy_SN+HD+fs8_nested_dynesty_multi_new_new_1.txt
# Removed no burn in
# /home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/polycdm+planck//PolyCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi_1.txt
# Removed no burn in
# ...

# %%
# mcsamplefile = mc_poly1
mcsamplefile = mc_polyplanck3
mcstats = mcsamplefile.getLikeStats()
mcstats.likeSummary()
# Out:
# 'Best fit sample -log(Like) = 24.871420\nmean(-Ln(like)) = 27.231661\n-Ln(mean like)  = 26.534868\n'

# %%
l = round(2*mcstats.logLike_sample, 3)
print("${}$".format(l))
# Out:
# $49.743$

# %%
for i in [2,3,4,5]:
    print(mcstats.list()[i])
#     top = mcstats.names[i].ND_limit_top[1]
#     low = mcstats.names[i].ND_limit_bot[1]
    best = mcstats.names[i].bestfit_sample
    print(best)
    #print(top)
    #print(low)
    print("best %4.5f"%(best))
    print("mean %4.5f"%(mcsamplefile.getMeans()[i]))
#     print("%4.3f + %4.3f - %4.3f"%(best, (top-best), (best-low)))
    print("std dev %5.4f"%(mcsamplefile.std(mcstats.list()[i])))
#     print("$  {%4.3f} \pm $"%(mcsamplefile.getMeans()[i]))
    print("${:.3f} \pm {:.3f}$".format(mcsamplefile.getMeans()[i], mcsamplefile.std(mcstats.list()[i])))
    print("--"*20)
# Out:
# h
# 0.67763551
# best 0.67764
# mean 0.67673
# std dev 0.0182
# $0.677 \pm 0.018$
# ----------------------------------------
# s8
# 0.67038695
# best 0.67039
# mean 0.77215
# std dev 0.1099
# $0.772 \pm 0.110$
# ----------------------------------------
# Om1
# 0.60055593
# best 0.60056
# mean 0.55239
# std dev 0.2390
# $0.552 \pm 0.239$
# ----------------------------------------
# Om2
# -0.11402209
# best -0.11402
# mean -0.10153
# std dev 0.0676
# $-0.102 \pm 0.068$
# ----------------------------------------

# %% [markdown]
# # Test with VAE waCDM JLA

# %%
# roots_testjla = ['waCDM_phy_SN_nested_dynesty_multi',
#                  'waCDM_phy_SN_nested_dynesty_multi_new',
#                  'waCDM_phy_SN_nested_dynesty_multi_new_new',
# #                  'waCDM_phy_SN_nested_dynesty_multi_new_new_new'
                 
#                 ]
                 

# dir_name_jla = '/home/isidro/Documents/gitHub/neuralCosmoReconstruction/notebooks/chains/testjla'

# # dir_name_jla = '/home/cosmocicatais/simpleMC/chains/'
# ggg = plots.getSinglePlotter(chain_dir = dir_name_jla, 
#                              width_inch= 12,
#                               ratio = 0.8, 
                             
#                               analysis_settings={'smooth_scale_2D': 0.9,
#                                              'smooth_scale_1D': 0.9, 
#                                              'ignore_rows': 0.1})
# #g.settings.axes_fontsize = 5
# ggg.settings.lab_fontsize = 15
# ggg.settings.x_label_rotation= 45
# #g.settings.alpha_filled_add = 0.9
# ggg.settings.legend_fontsize = 12
# ggg.settings.axes_fontsize = 12     
# ggg.settings.lw1 = 4

# ggg.triangle_plot(roots_testjla, ['Om', 'Obh2', 'h', 'w', 'wa'],
# # g.triangle_plot(roots_SN, ['Om', 'Obh2', 'h'],
#                 diag1d_kwargs={'colors':['black', 'red','blue','green', 'purple', 'brown'], 
#                                'alphas':[1.0,1.0,1.0]},
#                 colors=['black', 'red','blue',  'green', 'purple', 'brown'],
# #                 alphas = [1.0, 0.7, 0.5],
#                 legend_labels=['Original', 
# #                                'Diag(cov matrix)',
# #                                'Synthetic data with original cov matrix',
#                                'Synthetic data with cov matrix from VAE',
#                                'Synthetic data with cov matrix from VAE and MC-DO',
                             

#                               ],
# #                 legend_labels=['31 original data points ', '31 synthetic data points from AE+FFNN',
# #                                '31 synthetic data points from AE+FFNN+dropout'],
#                 legend_loc='upper right',
#                 filled = False,
#                 normalized=False, shaded=False)

# # plt.savefig('Triangle_CPL_VAE_original_z_2.png', dpi=100)
# # plt.show()

# %%
# mc_testjla1 = mcsamples.loadMCSamples(dir_name_jla+'/'+roots_testjla[0], settings={'ignore_rows':0.0})
# mc_testjla2 = mcsamples.loadMCSamples(dir_name_jla+'/'+roots_testjla[1], settings={'ignore_rows':0.0})
# mc_testjla3 = mcsamples.loadMCSamples(dir_name_jla+'/'+roots_testjla[2], settings={'ignore_rows':0.0})

# %%
# mcsamplefile = mc_testjla2
# mcstats = mcsamplefile.getLikeStats()
# mcstats.likeSummary()

# %%
# 2* 16.177

# %%
# for i in [2,3,4,5]:
#     print(mcstats.list()[i])
# #     top = mcstats.names[i].ND_limit_top[1]
# #     low = mcstats.names[i].ND_limit_bot[1]
#     best = mcstats.names[i].bestfit_sample
#     print(best)
#     #print(top)
#     #print(low)
#     print("best %4.5f"%(best))
#     print("mean %4.5f"%(mcsamplefile.getMeans()[i]))
# #     print("%4.3f + %4.3f - %4.3f"%(best, (top-best), (best-low)))
#     print("std dev %5.4f"%(mcsamplefile.std(mcstats.list()[i])))
# #     print("$  {%4.3f} \pm $"%(mcsamplefile.getMeans()[i]))
#     print("${:.3f} \pm {:.3f}$".format(mcsamplefile.getMeans()[i], mcsamplefile.std(mcstats.list()[i])))
#     print("--"*20)

# %%
# roots_testjla_lcdm = ['LCDM_phy_SN_nested_dynesty_multi',
#                  'LCDM_phy_SN_nested_dynesty_multi_new',
#                  'LCDM_phy_SN_nested_dynesty_multi_new_new',
# #                  'waCDM_phy_SN_nested_dynesty_multi_new_new_new'
                 
#                 ]
                 

# dir_name_jla = '/home/cosmocicatais/simpleMC/chains/testjla'
# ggg = plots.getSinglePlotter(chain_dir = dir_name_jla, 
#                              width_inch= 12,
#                               ratio = 0.8, 
                             
#                               analysis_settings={'smooth_scale_2D': 0.9,
#                                              'smooth_scale_1D': 0.9, 
#                                              'ignore_rows': 0.1})
# #g.settings.axes_fontsize = 5
# ggg.settings.lab_fontsize = 15
# ggg.settings.x_label_rotation= 45
# #g.settings.alpha_filled_add = 0.9
# ggg.settings.legend_fontsize = 12
# ggg.settings.axes_fontsize = 12     
# ggg.settings.lw1 = 4

# ggg.triangle_plot(roots_testjla_lcdm, ['Om', 'Obh2', 'h'],
# # g.triangle_plot(roots_SN, ['Om', 'Obh2', 'h'],
#                 diag1d_kwargs={'colors':['black', 'red','blue','green', 'purple', 'brown'], 
#                                'alphas':[1.0,1.0,1.0]},
#                 colors=['black', 'red','blue',  'green', 'purple', 'brown'],
# #                 alphas = [1.0, 0.7, 0.5],
#                 legend_labels=['Original', 
# #                                'Diag(cov matrix)',
# #                                'Synthetic data with original cov matrix',
#                                'Synthetic data with cov matrix from VAE',
#                                'Synthetic data with cov matrix from VAE and MC-DO',
                             

#                               ],
# #                 legend_labels=['31 original data points ', '31 synthetic data points from AE+FFNN',
# #                                '31 synthetic data points from AE+FFNN+dropout'],
#                 legend_loc='upper right',
#                 filled = False,
#                 normalized=False, shaded=False)

# # plt.savefig('Triangle_CPL_VAE_original_z_2.png', dpi=100)
# # plt.show()

# %%
dir_lcdm_all = '/home/cosmocicatais/simpleMC/chains/lcdm_all'
roots_lcdm_all = ['LCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi',
                  'LCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi_new',
                  'LCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi_new_new']

# mc_all_lcdm1 = mcsamples.loadMCSamples(dir_lcdm_all+'/'+roots_lcdm_all[0], settings={'ignore_rows':0.0})
# mc_all_lcdm2 = mcsamples.loadMCSamples(dir_lcdm_all+'/'+roots_lcdm_all[1], settings={'ignore_rows':0.0})
# mc_all_lcdm3 = mcsamples.loadMCSamples(dir_lcdm_all+'/'+roots_lcdm_all[2], settings={'ignore_rows':0.0})

# %%
# mcsamplefile = mc_all_lcdm3
# mcstats = mcsamplefile.getLikeStats()
# mcstats.likeSummary()

# %%
# 2* 10.421

# %%
# for i in [2,3,4]:
#     print(mcstats.list()[i])
# #     top = mcstats.names[i].ND_limit_top[1]
# #     low = mcstats.names[i].ND_limit_bot[1]
#     best = mcstats.names[i].bestfit_sample
#     print(best)
#     #print(top)
#     #print(low)
#     print("best %4.5f"%(best))
#     print("mean %4.5f"%(mcsamplefile.getMeans()[i]))
# #     print("%4.3f + %4.3f - %4.3f"%(best, (top-best), (best-low)))
#     print("std dev %5.4f"%(mcsamplefile.std(mcstats.list()[i])))
# #     print("$  {%4.3f} \pm $"%(mcsamplefile.getMeans()[i]))
#     print("${:.3f} \pm {:.3f}$".format(mcsamplefile.getMeans()[i], mcsamplefile.std(mcstats.list()[i])))
#     print("--"*20)

# %%
# dir_reduced_all = '/home/cosmocicatais/simpleMC/chains/reducedPriorsWithPlanck'
# roots_reduced_all = [ 'LCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi',
#                   'LCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi_new',
#                   'LCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi_new_new',
                 
#                   'waCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi',
#                   'waCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi_new',
#                   'waCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi_new_new',
                  
#                   'PolyCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi',
#                   'PolyCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi_new',
#                   'PolyCDM_phy_SN+HD+fs8+Planck_nested_dynesty_multi_new_new']

# mc_all_lcdm_red_1 = mcsamples.loadMCSamples(dir_reduced_all+'/'+roots_reduced_all[0], settings={'ignore_rows':0.0})
# mc_all_lcdm_red_2 = mcsamples.loadMCSamples(dir_reduced_all+'/'+roots_reduced_all[1], settings={'ignore_rows':0.0})
# mc_all_lcdm_red_3 = mcsamples.loadMCSamples(dir_reduced_all+'/'+roots_reduced_all[2], settings={'ignore_rows':0.0})


# mc_all_wacdm_red_1 = mcsamples.loadMCSamples(dir_reduced_all+'/'+roots_reduced_all[3], settings={'ignore_rows':0.0})
# mc_all_wacdm_red_2 = mcsamples.loadMCSamples(dir_reduced_all+'/'+roots_reduced_all[4], settings={'ignore_rows':0.0})
# mc_all_wacdm_red_3 = mcsamples.loadMCSamples(dir_reduced_all+'/'+roots_reduced_all[5], settings={'ignore_rows':0.0})

# mc_all_polycdm_red_1 = mcsamples.loadMCSamples(dir_reduced_all+'/'+roots_reduced_all[6], settings={'ignore_rows':0.0})
# mc_all_polycdm_red_2 = mcsamples.loadMCSamples(dir_reduced_all+'/'+roots_reduced_all[7], settings={'ignore_rows':0.0})
# mc_all_polycdm_red_3 = mcsamples.loadMCSamples(dir_reduced_all+'/'+roots_reduced_all[8], settings={'ignore_rows':0.0})

# %%
# # mcsamplefile = mc_all_lcdm_red_1
# # mcsamplefile = mc_all_wacdm_red_3
# mcsamplefile = mc_all_polycdm_red_3
# mcstats = mcsamplefile.getLikeStats()
# mcstats.likeSummary()

# %%
# 2* 9.468

# %%
# for i in [2,3,4,5]:
#     print(mcstats.list()[i])
# #     top = mcstats.names[i].ND_limit_top[1]
# #     low = mcstats.names[i].ND_limit_bot[1]
#     best = mcstats.names[i].bestfit_sample
#     print(best)
#     #print(top)
#     #print(low)
#     print("best %4.5f"%(best))
#     print("mean %4.5f"%(mcsamplefile.getMeans()[i]))
# #     print("%4.3f + %4.3f - %4.3f"%(best, (top-best), (best-low)))
#     print("std dev %5.4f"%(mcsamplefile.std(mcstats.list()[i])))
# #     print("$  {%4.3f} \pm $"%(mcsamplefile.getMeans()[i]))
#     print("${:.3f} \pm {:.3f}$".format(mcsamplefile.getMeans()[i], mcsamplefile.std(mcstats.list()[i])))
#     print("--"*20)
