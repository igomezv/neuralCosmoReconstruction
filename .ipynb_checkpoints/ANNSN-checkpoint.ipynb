# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1" #model will be trained on GPU 1

# %%
import tensorflow.keras
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
import gzip
# %matplotlib inline
from tensorflow.keras.layers import Input,Conv2D,MaxPooling2D,UpSampling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import Constant, RandomNormal
import seaborn as sns

# %%
file = 'data/jla_lcparams.txt'
data = pd.read_csv(file, sep = " " ,usecols=['zcmb', 'mb', 'dmb'])
print(data['dmb'])
syscov = np.loadtxt('data/jla_v0_covmatrix.dat',skiprows=1).reshape((740,740))
diag = np.diag(syscov)
# data['dmb'] = np.sqrt(diag + data['dmb']**2)
print(data['dmb'])
sns.pairplot(data, diag_kind="kde")
plt.savefig("distSNPantheon.png")
data = np.sort(data.values, axis=0)
data[739, :]
# Out:
# 0      0.088031
# 1      0.090132
# 2      0.088110
# 3      0.087263
# 4      0.098356
#          ...
# 735    0.141685
# 736    0.143429
# 737    0.144315
# 738    0.144350
# 739    0.144685
# Name: dmb, Length: 740, dtype: float64
# 0      0.088031
# 1      0.090132
# 2      0.088110
# 3      0.087263
# 4      0.098356
#          ...
# 735    0.141685
# 736    0.143429
# 737    0.144315
# 738    0.144350
# 739    0.144685
# Name: dmb, Length: 740, dtype: float64
# array([ 1.299106, 26.046776,  0.174566])

# %%
# randomize = np.random.permutation(len(data.values))
# randomize
shuffle = [x for x in range(len(data)) if x%2==1]
even = [x for x in range(len(data)) if x%2==0]
shuffle.extend(even)
np.max(shuffle)
# Out:
# 739

# %% [markdown]
# Let's prepare our input data.

# %%
print(data[739, 0])
data = data[shuffle]
# Out:
# 1.2991059999999999

# %%
X = data[:, 0]
y = data[:, 1:]
X.shape, y.shape

scaler = StandardScaler()
# # scaler = MinMaxScaler(feature_range=(-1,1))
# # fit scaler on data
scaler.fit(X.reshape(-1,1))
# # apply transform
Xsc = scaler.transform(X.reshape(-1,1))
# # X

# %%
split = 0.8
ntrain = int(split * len(X))
indx = [ntrain]
X_train, X_test = np.split(X, indx)
y_train, y_test = np.split(y, indx)

# %%
def model(input_z):
    efirst = Dense(200, activation='relu', input_shape=(1,))(input_z)
    ehidden2 = Dense(100, activation='relu')(efirst)
    ehidden3 = Dense(100, activation='relu')(ehidden2)
    elast = Dense(2, activation='linear')(ehidden3)
       
    return elast

# %%
batch_size = 32
epochs = 300
input_z = Input(shape = (1,))

# %%
snmodel = Model(input_z, model(input_z))
snmodel.compile(loss='mean_squared_error', optimizer = 'adam')

# %%
snmodel.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 1)]               0
# _________________________________________________________________
# dense (Dense)                (None, 200)               400
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 202
# =================================================================
# Total params: 30,802
# Trainable params: 30,802
# Non-trainable params: 0
# _________________________________________________________________

# %%
callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min',
                                   min_delta=0.001,
                                   patience=10,
                                   restore_best_weights=True)]

# %%
snmodel_train = snmodel.fit(X_train, y_train, batch_size=batch_size,epochs=epochs,verbose=1, 
                            validation_data=(X_test, y_test))
# Out:
# Epoch 1/300
# 19/19 [==============================] - 0s 6ms/step - loss: 199.6935 - val_loss: 240.0664
# Epoch 2/300
# 19/19 [==============================] - 0s 1ms/step - loss: 147.2726 - val_loss: 120.5451
# Epoch 3/300
# 19/19 [==============================] - 0s 1ms/step - loss: 42.1399 - val_loss: 30.1032
# Epoch 4/300
# 19/19 [==============================] - 0s 1ms/step - loss: 19.8434 - val_loss: 19.8850
# Epoch 5/300
# 19/19 [==============================] - 0s 1ms/step - loss: 10.8119 - val_loss: 12.2420
# Epoch 6/300
# 19/19 [==============================] - 0s 1ms/step - loss: 7.0536 - val_loss: 7.9715
# Epoch 7/300
# 19/19 [==============================] - 0s 1ms/step - loss: 4.7773 - val_loss: 6.6990
# Epoch 8/300
# 19/19 [==============================] - 0s 1ms/step - loss: 3.5481 - val_loss: 4.7515
# Epoch 9/300
# 19/19 [==============================] - 0s 1ms/step - loss: 2.7159 - val_loss: 3.7297
# Epoch 10/300
# 19/19 [==============================] - 0s 1ms/step - loss: 2.2040 - val_loss: 2.9625
# Epoch 11/300
# 19/19 [==============================] - 0s 1ms/step - loss: 1.7606 - val_loss: 2.3260
# Epoch 12/300
# 19/19 [==============================] - 0s 1ms/step - loss: 1.4338 - val_loss: 1.6918
# Epoch 13/300
# 19/19 [==============================] - 0s 1ms/step - loss: 1.1552 - val_loss: 1.2692
# Epoch 14/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.9247 - val_loss: 1.0119
# Epoch 15/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.7189 - val_loss: 0.6113
# Epoch 16/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.5502 - val_loss: 0.4659
# Epoch 17/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.4433 - val_loss: 0.3180
# Epoch 18/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3477 - val_loss: 0.1920
# Epoch 19/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.2759 - val_loss: 0.1600
# Epoch 20/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.2394 - val_loss: 0.1313
# Epoch 21/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.2229 - val_loss: 0.1166
# Epoch 22/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.2154 - val_loss: 0.1069
# Epoch 23/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.2070 - val_loss: 0.1053
# Epoch 24/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.1950 - val_loss: 0.1090
# Epoch 25/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.1890 - val_loss: 0.0960
# Epoch 26/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.1830 - val_loss: 0.0923
# Epoch 27/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.1720 - val_loss: 0.0909
# Epoch 28/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.1592 - val_loss: 0.0767
# Epoch 29/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.1535 - val_loss: 0.0831
# Epoch 30/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.1503 - val_loss: 0.0638
# Epoch 31/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.1365 - val_loss: 0.0597
# Epoch 32/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.1260 - val_loss: 0.0570
# Epoch 33/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.1202 - val_loss: 0.0557
# Epoch 34/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.1136 - val_loss: 0.0558
# Epoch 35/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.1097 - val_loss: 0.0461
# Epoch 36/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.1040 - val_loss: 0.0437
# Epoch 37/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0978 - val_loss: 0.0480
# Epoch 38/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0953 - val_loss: 0.0508
# Epoch 39/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0919 - val_loss: 0.0385
# Epoch 40/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0882 - val_loss: 0.0377
# Epoch 41/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0830 - val_loss: 0.0349
# Epoch 42/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0876 - val_loss: 0.0411
# Epoch 43/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0851 - val_loss: 0.0342
# Epoch 44/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0753 - val_loss: 0.0415
# Epoch 45/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0762 - val_loss: 0.0327
# Epoch 46/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0720 - val_loss: 0.0436
# Epoch 47/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0698 - val_loss: 0.0384
# Epoch 48/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0684 - val_loss: 0.0375
# Epoch 49/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0666 - val_loss: 0.0384
# Epoch 50/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0680 - val_loss: 0.0324
# Epoch 51/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0645 - val_loss: 0.0354
# Epoch 52/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0635 - val_loss: 0.0301
# Epoch 53/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0628 - val_loss: 0.0304
# Epoch 54/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0602 - val_loss: 0.0277
# Epoch 55/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0586 - val_loss: 0.0264
# Epoch 56/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0559 - val_loss: 0.0344
# Epoch 57/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0589 - val_loss: 0.0215
# Epoch 58/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0545 - val_loss: 0.0300
# Epoch 59/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0517 - val_loss: 0.0243
# Epoch 60/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0504 - val_loss: 0.0232
# Epoch 61/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0510 - val_loss: 0.0190
# Epoch 62/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0493 - val_loss: 0.0225
# Epoch 63/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0485 - val_loss: 0.0180
# Epoch 64/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0473 - val_loss: 0.0216
# Epoch 65/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0496 - val_loss: 0.0271
# Epoch 66/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0456 - val_loss: 0.0216
# Epoch 67/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0439 - val_loss: 0.0135
# Epoch 68/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0430 - val_loss: 0.0107
# Epoch 69/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0416 - val_loss: 0.0107
# Epoch 70/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0393 - val_loss: 0.0153
# Epoch 71/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0402 - val_loss: 0.0117
# Epoch 72/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0383 - val_loss: 0.0133
# Epoch 73/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0440 - val_loss: 0.0128
# Epoch 74/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0381 - val_loss: 0.0143
# Epoch 75/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0384 - val_loss: 0.0070
# Epoch 76/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0342 - val_loss: 0.0049
# Epoch 77/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0330 - val_loss: 0.0047
# Epoch 78/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0329 - val_loss: 0.0056
# Epoch 79/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0326 - val_loss: 0.0070
# Epoch 80/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0333 - val_loss: 0.0039
# Epoch 81/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0320 - val_loss: 0.0057
# Epoch 82/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0304 - val_loss: 0.0057
# Epoch 83/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0297 - val_loss: 0.0066
# Epoch 84/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0317 - val_loss: 0.0060
# Epoch 85/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0289 - val_loss: 0.0110
# Epoch 86/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0284 - val_loss: 0.0032
# Epoch 87/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0273 - val_loss: 0.0063
# Epoch 88/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0277 - val_loss: 0.0041
# Epoch 89/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0273 - val_loss: 0.0025
# Epoch 90/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0255 - val_loss: 0.0026
# Epoch 91/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0253 - val_loss: 0.0036
# Epoch 92/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0273 - val_loss: 0.0044
# Epoch 93/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0264 - val_loss: 0.0019
# Epoch 94/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0252 - val_loss: 0.0025
# Epoch 95/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0254 - val_loss: 0.0067
# Epoch 96/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0244 - val_loss: 0.0024
# Epoch 97/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0237 - val_loss: 0.0023
# Epoch 98/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0233 - val_loss: 0.0033
# Epoch 99/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0221 - val_loss: 0.0021
# Epoch 100/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0228 - val_loss: 0.0042
# Epoch 101/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0224 - val_loss: 0.0017
# Epoch 102/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0217 - val_loss: 0.0043
# Epoch 103/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0242 - val_loss: 0.0056
# Epoch 104/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0233 - val_loss: 0.0032
# Epoch 105/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0210 - val_loss: 0.0015
# Epoch 106/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0202 - val_loss: 0.0022
# Epoch 107/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0208 - val_loss: 0.0024
# Epoch 108/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0203 - val_loss: 0.0021
# Epoch 109/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0202 - val_loss: 0.0090
# Epoch 110/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0197 - val_loss: 0.0016
# Epoch 111/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0192 - val_loss: 0.0021
# Epoch 112/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0215 - val_loss: 0.0031
# Epoch 113/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0230 - val_loss: 0.0207
# Epoch 114/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0278 - val_loss: 0.0170
# Epoch 115/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0224 - val_loss: 0.0090
# Epoch 116/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0211 - val_loss: 0.0041
# Epoch 117/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0210 - val_loss: 0.0050
# Epoch 118/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0192 - val_loss: 0.0124
# Epoch 119/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0211 - val_loss: 0.0312
# Epoch 120/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0181 - val_loss: 0.0028
# Epoch 121/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0170 - val_loss: 0.0048
# Epoch 122/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0160 - val_loss: 0.0017
# Epoch 123/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0182 - val_loss: 0.0057
# Epoch 124/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0184 - val_loss: 0.0016
# Epoch 125/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0161 - val_loss: 0.0029
# Epoch 126/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0193 - val_loss: 0.0141
# Epoch 127/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0165 - val_loss: 0.0014
# Epoch 128/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0159 - val_loss: 0.0022
# Epoch 129/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0168 - val_loss: 0.0032
# Epoch 130/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0161 - val_loss: 0.0015
# Epoch 131/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0148 - val_loss: 0.0033
# Epoch 132/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0180 - val_loss: 0.0050
# Epoch 133/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0149 - val_loss: 0.0024
# Epoch 134/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0153 - val_loss: 0.0060
# Epoch 135/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0148 - val_loss: 0.0015
# Epoch 136/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0137 - val_loss: 0.0018
# Epoch 137/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0145 - val_loss: 0.0021
# Epoch 138/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0146 - val_loss: 0.0051
# Epoch 139/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0139 - val_loss: 0.0059
# Epoch 140/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0074
# Epoch 141/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0150 - val_loss: 0.0172
# Epoch 142/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0151 - val_loss: 0.0090
# Epoch 143/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0014
# Epoch 144/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0018
# Epoch 145/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0121 - val_loss: 0.0024
# Epoch 146/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0020
# Epoch 147/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0016
# Epoch 148/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0021
# Epoch 149/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0119 - val_loss: 0.0049
# Epoch 150/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0140 - val_loss: 0.0165
# Epoch 151/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0134 - val_loss: 0.0030
# Epoch 152/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0038
# Epoch 153/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0151 - val_loss: 0.0029
# Epoch 154/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0017
# Epoch 155/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0119 - val_loss: 0.0038
# Epoch 156/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0110 - val_loss: 0.0036
# Epoch 157/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0113 - val_loss: 0.0020
# Epoch 158/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0012
# Epoch 159/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0098 - val_loss: 0.0012
# Epoch 160/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0050
# Epoch 161/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0012
# Epoch 162/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0116 - val_loss: 0.0028
# Epoch 163/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0108 - val_loss: 0.0045
# Epoch 164/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0103 - val_loss: 0.0014
# Epoch 165/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0026
# Epoch 166/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0137 - val_loss: 0.0056
# Epoch 167/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0109 - val_loss: 0.0022
# Epoch 168/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0126 - val_loss: 0.0014
# Epoch 169/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0092 - val_loss: 0.0017
# Epoch 170/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0097 - val_loss: 0.0168
# Epoch 171/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0099 - val_loss: 0.0021
# Epoch 172/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0099 - val_loss: 0.0088
# Epoch 173/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0089 - val_loss: 0.0017
# Epoch 174/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0107 - val_loss: 0.0011
# Epoch 175/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0106 - val_loss: 0.0012
# Epoch 176/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0081 - val_loss: 0.0033
# Epoch 177/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0095 - val_loss: 0.0036
# Epoch 178/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0088 - val_loss: 0.0022
# Epoch 179/300
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0093 - val_loss: 0.0018
# Epoch 180/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0078 - val_loss: 0.0011
# Epoch 181/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0081 - val_loss: 0.0011
# Epoch 182/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0072 - val_loss: 0.0080
# Epoch 183/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0089 - val_loss: 0.0022
# Epoch 184/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0017
# Epoch 185/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.0011
# Epoch 186/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0074 - val_loss: 0.0022
# Epoch 187/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0078 - val_loss: 0.0016
# Epoch 188/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0066 - val_loss: 0.0019
# Epoch 189/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0080 - val_loss: 0.0042
# Epoch 190/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0105 - val_loss: 0.0022
# Epoch 191/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0076 - val_loss: 0.0072
# Epoch 192/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0089 - val_loss: 0.0092
# Epoch 193/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0086 - val_loss: 0.0059
# Epoch 194/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0089 - val_loss: 0.0011
# Epoch 195/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0063 - val_loss: 0.0024
# Epoch 196/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0087 - val_loss: 0.0143
# Epoch 197/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0093 - val_loss: 0.0013
# Epoch 198/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0067 - val_loss: 0.0013
# Epoch 199/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0058 - val_loss: 0.0034
# Epoch 200/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0068 - val_loss: 0.0023
# Epoch 201/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 0.0326
# Epoch 202/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0109 - val_loss: 0.0136
# Epoch 203/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0112 - val_loss: 0.0243
# Epoch 204/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0098 - val_loss: 0.0033
# Epoch 205/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0102 - val_loss: 0.0094
# Epoch 206/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0079 - val_loss: 0.0016
# Epoch 207/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0070 - val_loss: 0.0232
# Epoch 208/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0094 - val_loss: 0.0195
# Epoch 209/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0099 - val_loss: 0.0014
# Epoch 210/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0073 - val_loss: 0.0096
# Epoch 211/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0066 - val_loss: 0.0022
# Epoch 212/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0072 - val_loss: 0.0025
# Epoch 213/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0059 - val_loss: 0.0076
# Epoch 214/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0056 - val_loss: 0.0011
# Epoch 215/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0066 - val_loss: 0.0026
# Epoch 216/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0069 - val_loss: 0.0125
# Epoch 217/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0062 - val_loss: 0.0016
# Epoch 218/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0052 - val_loss: 0.0011
# Epoch 219/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0051 - val_loss: 0.0018
# Epoch 220/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0072 - val_loss: 0.0012
# Epoch 221/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0061 - val_loss: 0.0058
# Epoch 222/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0052 - val_loss: 0.0020
# Epoch 223/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0054 - val_loss: 0.0020
# Epoch 224/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0067 - val_loss: 0.0044
# Epoch 225/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0072 - val_loss: 0.0062
# Epoch 226/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.0021
# Epoch 227/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0057 - val_loss: 0.0018
# Epoch 228/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0060 - val_loss: 0.0034
# Epoch 229/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0050 - val_loss: 0.0022
# Epoch 230/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0049 - val_loss: 0.0036
# Epoch 231/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0048 - val_loss: 0.0024
# Epoch 232/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0077 - val_loss: 0.0186
# Epoch 233/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0071 - val_loss: 0.0010
# Epoch 234/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0060 - val_loss: 0.0011
# Epoch 235/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 236/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0039 - val_loss: 0.0050
# Epoch 237/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0048 - val_loss: 0.0022
# Epoch 238/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0041 - val_loss: 9.1012e-04
# Epoch 239/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0048 - val_loss: 0.0011
# Epoch 240/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 9.5080e-04
# Epoch 241/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0045 - val_loss: 0.0016
# Epoch 242/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0072 - val_loss: 0.0049
# Epoch 243/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0053 - val_loss: 0.0030
# Epoch 244/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0026
# Epoch 245/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0044 - val_loss: 9.7414e-04
# Epoch 246/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0046 - val_loss: 0.0013
# Epoch 247/300
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0027
# Epoch 248/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0043 - val_loss: 0.0038
# Epoch 249/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0054 - val_loss: 0.0036
# Epoch 250/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0081 - val_loss: 0.0025
# Epoch 251/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0100 - val_loss: 0.0163
# Epoch 252/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0144 - val_loss: 0.0139
# Epoch 253/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0057 - val_loss: 0.0020
# Epoch 254/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0056 - val_loss: 0.0020
# Epoch 255/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0019
# Epoch 256/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0061 - val_loss: 0.0052
# Epoch 257/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0056 - val_loss: 0.0012
# Epoch 258/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0035 - val_loss: 0.0023
# Epoch 259/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0035
# Epoch 260/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0053 - val_loss: 0.0049
# Epoch 261/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0040 - val_loss: 0.0014
# Epoch 262/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0045 - val_loss: 0.0025
# Epoch 263/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0046 - val_loss: 0.0045
# Epoch 264/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0070 - val_loss: 0.0118
# Epoch 265/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0095 - val_loss: 0.0314
# Epoch 266/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0098 - val_loss: 0.0056
# Epoch 267/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0045 - val_loss: 0.0036
# Epoch 268/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0055 - val_loss: 0.0054
# Epoch 269/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0084 - val_loss: 0.0130
# Epoch 270/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0076 - val_loss: 0.0094
# Epoch 271/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0072 - val_loss: 0.0075
# Epoch 272/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0044 - val_loss: 0.0032
# Epoch 273/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0068 - val_loss: 0.0145
# Epoch 274/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0074 - val_loss: 0.0189
# Epoch 275/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0038 - val_loss: 0.0027
# Epoch 276/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0034 - val_loss: 0.0043
# Epoch 277/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0057
# Epoch 278/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0047 - val_loss: 0.0109
# Epoch 279/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0046 - val_loss: 0.0041
# Epoch 280/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0062 - val_loss: 0.0043
# Epoch 281/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0116 - val_loss: 0.0141
# Epoch 282/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0049 - val_loss: 0.0265
# Epoch 283/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0106 - val_loss: 0.0036
# Epoch 284/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0051 - val_loss: 9.8170e-04
# Epoch 285/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0050 - val_loss: 0.0023
# Epoch 286/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0060 - val_loss: 0.0022
# Epoch 287/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0052 - val_loss: 0.0023
# Epoch 288/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0039 - val_loss: 0.0021
# Epoch 289/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0039 - val_loss: 0.0021
# Epoch 290/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 9.8994e-04
# Epoch 291/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0029 - val_loss: 9.1578e-04
# Epoch 292/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0033 - val_loss: 0.0012
# Epoch 293/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0040 - val_loss: 0.0073
# Epoch 294/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0069 - val_loss: 0.0114
# Epoch 295/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0064 - val_loss: 0.0018
# Epoch 296/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0052 - val_loss: 0.0021
# Epoch 297/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0071 - val_loss: 0.0023
# Epoch 298/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0060 - val_loss: 0.0028
# Epoch 299/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0050 - val_loss: 0.0091
# Epoch 300/300
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0042 - val_loss: 0.0064

# %%
plt.plot(snmodel_train.history['loss'], color='r', )
plt.plot(snmodel_train.history['val_loss'], color='g')
# plt.title('model loss function')
plt.ylabel('MSE')
plt.xlabel('Epochs')
plt.legend(['train', 'val'], loc='upper left')
# plt.savefig("loss_sn.png", dpi=200)

# %%
pred = snmodel.predict(X_test)
pred.shape
# Out:
# (148, 2)

# %%
# r = np.random.uniform(np.min(data[:,0]), np.max(data[:,0]), size=1000)
r = np.linspace(np.min(data[:,0]), np.max(data[:,0]), 1000)
# scaler2 = StandardScaler()
# scaler.fit(r.reshape(-1,1))
r = scaler.transform(r.reshape(-1,1))
# X
print(np.max(X), len(X), X[739])
# Out:
# 1.2991059999999999 740 [1.265901]

# %%
pred_random = snmodel.predict(r)
# pred_random
# X = scaler.inverse_transform(Xinv)
r = scaler.inverse_transform(r)

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
plt.errorbar(X, y[:,0], y[:,1], fmt='g.', markersize=1, label='Observations', alpha=0.8)
plt.errorbar(r, pred_random[:,0], pred_random[:,1], fmt='r*', markersize=3, label='Synthetic', alpha=0.01)
plt.xlabel("Redshift z")
plt.ylabel("$D_L(z)$")
ax.set_xscale('log')
# plt.ylim(34, 40)
# plt.xlim(np.min(X), 2.4)
plt.legend()
# plt.savefig("syntheticSN.png", dpi=300)

# %%
# Cosmological constants
Om = 0.27

# %%
def Hlcdm(z, H0=73.24):
    return H0 * np.sqrt(Om*(1+z)**3 + 1 - Om)

# %%
# z = np.linspace(0, 2.2, 1000)
# # plt.scatter(data[:, 0], data[:, 1], c='g')
# yupp = pred_random[:,0]+pred_random[:,1]
# ylow = pred_random[:,0]-pred_random[:,1]
# plt.errorbar(X, y[:,0], y[:,1], fmt='g.', markersize=10, label='Observations')
# plt.errorbar(r, pred_random[:,0], pred_random[:,1], fmt='r.', markersize=1, label='Synthetic data with errors', alpha=0.01, )
# plt.plot(z, Hlcdm(z), label='$\Lambda CDM$ $H_0 = 73.24$', c='k')
# plt.plot(z, Hlcdm(z, H0=64.4), label='$\Lambda CDM$ $H_0 = 64.4$', c='b')
# plt.xlabel("Redshift z")
# plt.ylabel("$H(z)$")
# plt.xlim(0,2.2)
# plt.legend()

# plt.savefig("SyntheticHD.png",dpi=800)

# %%
# pred_random.shape, r.shape

# %%
# rr = np.random.uniform(0, 2.3, size=500)
rr = np.linspace(0, 2.3, num=500)
print(len(rr))
pred_random = snmodel.predict(rr)
mookSN = np.concatenate((rr.reshape(-1,1), pred_random), axis=1)
np.savetxt("neuralSN.dat",mookSN, delimiter=" ")

# %%
rr
